# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import pickle
import os
import shutil
import random
from tqdm import tqdm
from random import seed
import matplotlib
import matplotlib.pyplot as plt
import missingno as msno
  
seed(1121)

# %% [markdown]
# ## Load data

# %%
# !mkdir -p ../datasets/MIMICIII/adults/adults_all

# %%
# !rsync -a ../datasets/MIMICIII/adults/processed_sepsis/ ../datasets/MIMICIII/adults/adults_all/
# !rsync -a ../datasets/MIMICIII/adults/processed_non_sepsis/ ../datasets/MIMICIII/adults/adults_all/
# !ls -1U ../datasets/MIMICIII/adults/processed_sepsis/ | wc -l
# !ls -1U ../datasets/MIMICIII/adults/processed_non_sepsis/ | wc -l
# !ls -1U ../datasets/MIMICIII/adults/adults_all/ | wc -l
# Out:
#     1886
#     3380
#     5266

# %%
path_all = '../datasets/MIMICIII/adults/adults_all/'
path_sepsis = '../datasets/MIMICIII/adults/processed_sepsis/'
path_non_sepsis = '../datasets/MIMICIII/adults/processed_non_sepsis/'

# %%
patient_id = sorted(os.listdir(path_all))
patient_id = list(filter(lambda x: x !="index.html" and x != ".DS_Store", patient_id))
print('Total patient number: ',len(patient_id))

patient_id_sepsis = sorted(os.listdir(path_sepsis))
patient_id_sepsis = list(filter(lambda x: x !="index.html" and x != ".DS_Store", patient_id_sepsis))
print('Sepsis patient number: ',len(patient_id_sepsis))

patient_id_non_sepsis = sorted(os.listdir(path_non_sepsis))
patient_id_non_sepsis = list(filter(lambda x: x !="index.html" and x != ".DS_Store", patient_id_non_sepsis))
print('Non-sepsis patient number: ',len(patient_id_non_sepsis))
# Out:
# Total patient number:  5266
# Sepsis patient number:  1886
# Non-sepsis patient number:  3380

# %% [markdown]
# ## Train-Val-Test Split

# %%
id_sepsis = patient_id_sepsis
id_nonsepsis = patient_id_non_sepsis

# %%
len_train_sepsis = round(0.7*len(id_sepsis))
print(len_train_sepsis)
len_val_sepsis = round(0.15*len(id_sepsis))
print(len_val_sepsis)
len_test_sepsis = round(0.15*len(id_sepsis))
print(len_test_sepsis)
len_train_sepsis + len_val_sepsis + len_test_sepsis == len(id_sepsis)
# Out:
# 1320
# 283
# 283
# True

# %%
len_train_nonsepsis = round(0.8*(len(id_nonsepsis)-len_test_sepsis))
print(len_train_nonsepsis)
len_val_nonsepsis = round(0.2*(len(id_nonsepsis)-len_test_sepsis))
print(len_val_nonsepsis)
len_test_nonsepsis = len_test_sepsis
print(len_test_nonsepsis)
len_train_nonsepsis + len_val_nonsepsis + len_test_nonsepsis == len(id_nonsepsis)
# Out:
# 2478
# 619
# 283
# True

# %%
len_train = len_train_sepsis + len_train_nonsepsis
print(len_train)
len_val = len_val_sepsis + len_val_nonsepsis
print(len_val)
len_test = len_test_sepsis + len_test_nonsepsis
print(len_test)
len_train + len_val + len_test == len(patient_id)
# Out:
# 3798
# 902
# 566
# True

# %%
train_id_sepsis = random.sample(id_sepsis, len_train_sepsis)
val_id_sepsis = random.sample(set(id_sepsis) - set(train_id_sepsis), len_val_sepsis)
test_id_sepsis = set(id_sepsis) - set(train_id_sepsis) - set(val_id_sepsis)

# %%
train_id_nonsepsis = random.sample(id_nonsepsis, len_train_nonsepsis)
val_id_nonsepsis = random.sample(set(id_nonsepsis) - set(train_id_nonsepsis), len_val_nonsepsis)
test_id_nonsepsis = set(id_nonsepsis) - set(train_id_nonsepsis) - set(val_id_nonsepsis)

# %%
train_id = train_id_sepsis+ train_id_nonsepsis
val_id = val_id_sepsis + val_id_nonsepsis
test_id = list(test_id_sepsis) + list(test_id_nonsepsis)

sepsis_id = train_id_sepsis + val_id_sepsis
nonsepsis_id = train_id_nonsepsis + val_id_nonsepsis

# %%
np.save('../models_adults/data/data_mimiciii/test_set.npy',test_id)
np.save('../models_adults/data/data_mimiciii/train_sepsis.npy',sepsis_id)
np.save('../models_adults/data/data_mimiciii/train_nonsepsis.npy',nonsepsis_id)

# %% [markdown]
# ## Pre-process dataset

# %% [markdown]
# ### Helper Functions

# %% [markdown]
# Function 1: Fill the missing value

# %%
# function to fill missing values
def impute_missing_vals(df, attributes):

    """
    function that imputes missing values.
    
    @param df: dataframe that has missing values to be
               imputed
           attributes: list of String, attributes of dataframe
    @return df_clean: dataframe without missing values

    """
    
    """
    fill missing values by the closest values first
    ffill to fill missing values in the tail
    bfill to fill missing values in the head
    """
    # copy df
    df_clean = df.copy()
    for att in attributes:
        if df_clean[att].isnull().sum() == len(df_clean):
            df_clean[att] = df_clean[att].fillna(0)
        elif df_clean[att].isnull().sum() == len(df_clean) - 1:
            df_clean[att] = df_clean[att].ffill().bfill()
        else:
            df_clean[att] = df_clean[att].interpolate(method='nearest', limit_direction='both')
            df_clean[att] = df_clean[att].ffill().bfill()
    
    return df_clean

# %% [markdown]
# Function 2: Generate new feature columns

# %%
# function to add new columns containing as mang features as possible
def new_features(df):
  #attributes that are worked on: HR, Resp, Temp

  #copy df
  df_dev = df.copy()

  # three standard deviation for HR -> HR_dev_1, HR_dev_2, HR_dev_3
  hr = df_dev['HR']
  hr_len = len(hr)
  hr_dev_1 = hr.copy()
  hr_dev_2 = hr.copy()
  hr_dev_3 = hr.copy()
  for i, j in hr_dev_1.iteritems():
    if i > hr_len - 5:
      hr_dev_1[i] = hr[i:hr_len].std()
    else:
      hr_dev_1[i] = hr[i:i+5].std()
  hr_dev_1[hr_len-1] = hr_dev_1[hr_len-2]
  df_dev['HR_dev_1'] = hr_dev_1

  for i, j in hr_dev_2.iteritems():
    if i > hr_len - 10:
      hr_dev_2[i] = hr[i:hr_len].std()
    else:
      hr_dev_2[i] = hr[i:i+10].std()
  hr_dev_2[hr_len-1] = hr_dev_2[hr_len-2]
  df_dev['HR_dev_2'] = hr_dev_2

  for i, j in hr_dev_3.iteritems():
    if i > hr_len - 20:
      hr_dev_3[i] = hr[i:hr_len].std()
    else:
      hr_dev_3[i] = hr[i:i+20].std()
  hr_dev_3[hr_len-1] = hr_dev_3[hr_len-2]
  df_dev['HR_dev_3'] = hr_dev_3


  # three standard deviation for Resp -> Resp_dev_1, Resp_dev_2, Resp_dev_3
  rr = df_dev['RR']
  rr_len = len(rr)
  rr_dev_1 = rr.copy()
  rr_dev_2 = rr.copy()
  rr_dev_3 = rr.copy()
  for i, j in rr_dev_1.iteritems():
    if i < rr_len -5:
      rr_dev_1[i] = rr[i:rr_len].std()
    else:
      rr_dev_1[i] = rr[i:i+5].std()
  rr_dev_1[rr_len-1] = rr_dev_1[rr_len-2]
  df_dev['RR_dev_1'] = rr_dev_1

  for i, j in rr_dev_2.iteritems():
    if i < rr_len -10:
      rr_dev_2[i] = rr[i:rr_len].std()
    else:
      rr_dev_2[i] = rr[i:i+10].std()
  rr_dev_2[rr_len-1] = rr_dev_2[rr_len-2]
  df_dev['RR_dev_2'] = rr_dev_2

  for i, j in rr_dev_3.iteritems():
    if i < rr_len -20:
      rr_dev_3[i] = rr[i:rr_len].std()
    else:
      rr_dev_3[i] = rr[i:i+20].std()
  rr_dev_3[rr_len-1] = rr_dev_3[rr_len-2]
  df_dev['RR_dev_3'] = rr_dev_3

  # three standard deviation for Temp -> Temp_dev_1, Temp_dev_2, Temp_dev_3
  t = df_dev['Temp']
  t_len = len(t)
  t_dev_1 = t.copy()
  t_dev_2 = t.copy()
  t_dev_3 = t.copy()
  for i, j in t_dev_1.iteritems():
    if i < t_len - 5:
      t_dev_1[i] = t[i:t_len].std()
    else:
      t_dev_1[i] = t[i:i+5].std()
  t_dev_1[t_len-1] = t_dev_1[t_len-2]
  df_dev['Temp_dev_1'] = t_dev_1

  for i, j in t_dev_2.iteritems():
    if i < t_len - 10:
      t_dev_2[i] = t[i:t_len].std()
    else:
      t_dev_2[i] = t[i:i+10].std()
  t_dev_2[t_len-1] = t_dev_2[t_len-2]
  df_dev['Temp_dev_2'] = t_dev_2

  for i, j in t_dev_3.iteritems():
    if i < t_len - 20:
      t_dev_3[i] = t[i:t_len].std()
    else:
      t_dev_3[i] = t[i:i+20].std()
  t_dev_3[t_len-1] = t_dev_3[t_len-2]
  df_dev['Temp_dev_3'] = t_dev_3

  # features for indicating bradycardia and tachycardia
  brady = hr.copy()
  tachy = hr.copy()
  for i,j in brady.iteritems():
    if hr[i] < 60:
      brady[i] = True
    else:
      brady[i] = False
    if hr[i] > 100:
      tachy[i] = True
    else:
      tachy[i] = False
  df_dev['Bradycardia'] = brady
  df_dev['Tachycardia'] = tachy

  # features for indicating Hypothermia, Hyperthermia(Fever) and Hyperpyrexia
  hypothermia = t.copy()
  fever = t.copy()
  hyperpyrexia = t.copy()
  for i,j in t.iteritems():
    if t[i] <35:
      hypothermia[i] = True
    else:
      hypothermia[i] = False
    if t[i] >37.5:
      fever[i] = True
    else:
      fever[i] = False
    if t[i] >40:
      hyperpyrexia[i] = True
    else:
      hyperpyrexia[i] = False
  df_dev['Hypothermia'] = hypothermia
  df_dev['Fever'] = fever
  df_dev['Hyperpyrexia'] = hyperpyrexia

  return df_dev

# %% [markdown]
# Function 3: re-label 6 hours ahead

# %%
def relabel_positive(patient):
  df = patient
  df_len = len(df)
  if df.iloc[df_len-1].sepsis == 1:
    for i in range(7):
      df.loc[df_len-1-i,'sepsis'] = 1
  return df

# %% [markdown]
# ### Generate Baseline Data

# %%
# !mkdir -p ../datasets/MIMICIII/adults/baseline_all

# %%
# impute missing values and create clean dfs for all patients
for p in tqdm(patient_id):
    
    # read in patient data
    df = pd.read_csv(path_all + p, sep = ",")

    # drop features that doesn't exist in Cinc2019
    df_dropped = df.drop(['Sodium'], axis = 1)
    
    # impute missing values
    attributes = df_dropped.columns
    df_filled = impute_missing_vals(df_dropped, attributes)

    # First to change the value of Temperature
    df_filled['Temp'] = df_filled['Temp'].apply(lambda x: (x-32)/1.8)

    # change the False/True into 0/1
    df_replace_label = df_filled.replace([True,False],[1,0]) # from the label
    df_replace_gender = df_replace_label.replace(['M','F'],[1,0]) #from the gender

    #re-label sepsis 6 hours ahead
    df_final = relabel_positive(df_replace_gender)
    
    # save new patient data
    save_path = '../datasets/MIMICIII/adults/baseline_all/'
    df_final.to_csv(save_path + p , sep=',', index = False)     

    if np.any(pd.isnull(df_final)): break
# Out:
# 100%|██████████| 5266/5266 [05:23<00:00, 16.28it/s]

# %%
# check the features in Cinc2019 and MIMIC-III are the same
attris_cinc2019 = list(pd.read_csv('../datasets/Cinc2019/baseline_all/p000001.csv').columns)
print(attris_cinc2019)
attris_mimiciii = list(pd.read_csv('../datasets/MIMICIII/adults/baseline_all/1000.csv').columns)
attris_mimiciii.remove('time')
print(attris_mimiciii)
sorted(attris_cinc2019) == sorted(attris_mimiciii)
# Out:
# ['HR', 'SaO2', 'Temp', 'SBP', 'MAP', 'DBP', 'RR', 'BaseExcess', 'HCO3', 'PH', 'BUN', 'Calcium', 'Chloride', 'Creatinine', 'Glucose', 'Lactic', 'Magnesium', 'Potassium', 'PTT', 'WBC', 'Platelet', 'age', 'gender', 'sepsis', 'subject_id']
# ['sepsis', 'subject_id', 'gender', 'age', 'SBP', 'DBP', 'MAP', 'Temp', 'HR', 'RR', 'BaseExcess', 'SaO2', 'PH', 'Magnesium', 'Lactic', 'Calcium', 'Potassium', 'HCO3', 'Creatinine', 'Chloride', 'Glucose', 'WBC', 'BUN', 'PTT', 'Platelet']
# True

# %% [markdown]
# ### Generate Engineered Data

# %%
# !mkdir -p ../datasets/MIMICIII/adults/engineered_all

# %%
# impute missing values and add new features for all patients
for p in tqdm(patient_id):
    
    # read in patient data
    df = pd.read_csv(path_all + p, sep = ",")

    # drop features that doesn't exist in Cinc2019
    df_dropped = df.drop(['Sodium'], axis = 1)
    
    # impute missing values
    attributes = df_dropped.columns
    df_filled = impute_missing_vals(df_dropped, attributes)

    # change temperature values
    df_filled['Temp'] = df_filled['Temp'].apply(lambda x: (x-32)/1.8)

    # change the False/True into 0/1
    df_replace_label = df_filled.replace([True,False],[1,0]) # from the label
    df_replace_gender = df_replace_label.replace(['M','F'],[1,0]) #from the gender

    # add new features
    df_new_f = new_features(df_replace_gender)

    #re-label sepsis 6 hours ahead
    df_final = relabel_positive(df_new_f)
    
    # save new patient data
    save_path = '../datasets/MIMICIII/adults/engineered_all/'
    df_final.to_csv(save_path + p , sep=',', index = False)     

    if np.any(pd.isnull(df_final)): break
# Out:
# 100%|██████████| 5266/5266 [08:39<00:00, 10.13it/s]

# %% [markdown]
# ### Prepare Test Data

# %%
def copy_file(src_file, dest):
    
    if os.path.isfile(src_file):
        shutil.copy(src_file, dest)

# %%
! mkdir -p ../models_adults/data/data_both/test_baseline
! mkdir -p ../models_adults/data/data_both/test_engineered

# %%
# set the path for test data
test_path_baseline = './data/data_both/test_baseline/'
test_path_engineered = './data/data_both/test_engineered/'

# read test data from Cinc2019
test_set_c = np.load('../models_adults/data/data_Cinc2019/test_set.npy')
baseline_data_path = '../datasets/Cinc2019/baseline_all/'
engineered_data_path = '../datasets/Cinc2019/engineered_all/'
for i in tqdm(test_set_c):
    i = i.replace('psv','csv')
    patient_path_baseline = baseline_data_path + i
    patient_path_engineered = engineered_data_path + i
    copy_file(patient_path_baseline,test_path_baseline)
    copy_file(patient_path_engineered,test_path_engineered)

# read data from MIMIC-III 
test_set_m = np.load('../models_adults/data/data_mimiciii/test_set.npy')
baseline_data_path = '../datasets/MIMICIII/adults/baseline_all/'
engineered_data_path = '../datasets/MIMICIII/adults/engineered_all/'
for i in tqdm(test_set_m):
    patient_path_baseline = baseline_data_path + i
    patient_path_engineered = engineered_data_path + i
    copy_file(patient_path_baseline,test_path_baseline)
    copy_file(patient_path_engineered,test_path_engineered)

# concatnate two test_sets
test_set_m = np.load('../models_adults/data/data_mimiciii/test_set.npy')
test_set = np.concatenate([test_set_c, test_set_m])
np.save('../models_adults/data/data_both/test_set.npy',test_set)
# Out:
# 100%|██████████| 880/880 [00:02<00:00, 341.88it/s]
# 100%|██████████| 566/566 [00:01<00:00, 379.95it/s]

# %% [markdown]
# ## Analyze Raw Data

# %% [markdown]
# ### Gather Data

# %%
#raw data of the whole dataset
raw_data_all = pd.DataFrame([])

for p in tqdm(patient_id):

    # read in patient data
    df = pd.read_csv('../datasets/MIMICIII/adults/adults_all/' + p, sep = ",")
    
    raw_data_all = pd.concat([raw_data_all, df], ignore_index=True)

filename = '../datasets/MIMICIII/adults/raw_data_all.pickle'
with open(filename, "wb") as f:
    pickle.dump(raw_data_all, f)
# Out:
# 100%|██████████| 5266/5266 [04:54<00:00, 17.91it/s]

# %%
# load data
filename = '../datasets/MIMICIII/adults/raw_data_all.pickle'
with open(filename, 'rb') as f:
    raw_data_all = pickle.load(f)

# %%
raw_data_all.columns
# Out:
# Index(['sepsis', 'subject_id', 'gender', 'age', 'SBP', 'DBP', 'MAP', 'Temp',
#        'HR', 'RR', 'BaseExcess', 'SaO2', 'PH', 'Magnesium', 'Lactic',
#        'Calcium', 'Sodium', 'Potassium', 'HCO3', 'Creatinine', 'Chloride',
#        'Glucose', 'WBC', 'BUN', 'PTT', 'Platelet', 'time'],
#       dtype='object')

# %%
# list out lab test features for imputation
labs=['BaseExcess','PH', 'Magnesium', 'Lactic',
       'Calcium', 'Sodium', 'Potassium', 'HCO3', 'Creatinine', 'Chloride',
       'Glucose', 'WBC', 'BUN', 'PTT', 'Platelet']

# list out vital signal features for imputation
vitals = ['HR','SaO2','Temp','SBP','MAP','DBP','RR']

# list out demographic features for imputation
demogs = ['age','gender']

# labels
labels = ['sepsis']

# %% [markdown]
# ### Sepsis Label Distribution

# %%
! mkdir ./data_figs/MIMICIII/

# %%
# sepsis ratio (label-wise)
sepsis_ratio = raw_data_all.groupby('sepsis').count()['subject_id']
sepsis_dis = sepsis_ratio.values
print(sepsis_dis)

plt.figure(figsize=(10,10))
plt.bar(['Negative', 'Positive'],sepsis_dis)
plt.title('Sepsis label distribution in MIMIC-III (adults)',size=16)
plt.ylabel('Count',size=14)
plt.xlabel('Sepsis Label',size=14)
plt.savefig('./data_figs/MIMICIII/sepsis_label_distribution_mimiciii.pdf')
# Out:
# [333673   1886]

# %% [markdown]
# ### Age Distribution

# %%
# age distribution
age_dis = raw_data_all.groupby('age').count()['subject_id']
age_dis = pd.DataFrame({'age':age_dis.index, 'number':age_dis.values})

new_age_dis = pd.DataFrame(columns=['age','number'])
for age in range(14,101):
    age_dis_part = age_dis[(age <= age_dis['age']) &  (age_dis['age']< (age+1))]
    total_num = age_dis_part['number'].sum()
    new_age_dis = new_age_dis.append({'age':age, 'number': total_num}, ignore_index  =True)

plt.figure(figsize=(20,10))
plt.bar(new_age_dis.age, new_age_dis.number)
plt.title('Age distribution in MIMIC-III (adults)',size=16)
plt.xlabel('Age',size=14)
plt.ylabel('Number',size=14)
plt.savefig('./data_figs/MIMICIII/age_distribution_mimiciii.pdf')

# %% [markdown]
# ### Empty Rate

# %%
# check empty rate
labs_df = raw_data_all[labs]
vitals_df = raw_data_all[vitals]
demogs_df = raw_data_all[demogs]

print('Empty rate in lab features:', np.mean((labs_df.isnull().sum() / labs_df.shape[0])))
print('Empty rate in vital sign features:', np.mean((vitals_df.isnull().sum() / vitals_df.shape[0])))
print('Empty rate in demographic features:', np.mean((demogs_df.isnull().sum() / demogs_df.shape[0])))
# Out:
# Empty rate in lab features: 0.9698336209131626
# Empty rate in vital sign features: 0.674114792672185
# Empty rate in demographic features: 0.0

# %%
plt.figure(figsize=(20,20))
msno.matrix(labs_df)
plt.title('Visualization of missing values in lab recordings', size=16)
plt.show()
# plt.savefig('./data_figs/lab_missing_Cinc2019.pdf')

# %%
plt.figure(figsize=(20,20))
msno.matrix(vitals_df)
plt.title('Visualization of missing values in vital signs', size=16)
plt.show()
# plt.savefig('./data_figs/lab_missing_Cinc2019.pdf')

# %%
plt.figure(figsize=(20,20))
msno.matrix(demogs_df)
plt.title('Visualization of missing values in demographic information', size=16)
plt.show()
# plt.savefig('./data_figs/lab_missing_Cinc2019.pdf')

# %%
#pick out the columns that contain null data
missingdata_df = raw_data_all.columns[raw_data_all.isnull().any()].tolist()
print('Number of featurs that contains null values',len(missingdata_df))

#re-arrange the order of columns and drop 'time'
raw_data_all = raw_data_all[['HR', 'Temp', 'SBP', 'MAP', 'DBP', 'RR', 
                            'BaseExcess', 'HCO3', 'PH', 'SaO2', 'BUN', 
                            'Calcium', 'Chloride', 'Creatinine', 'Glucose', 
                            'Lactic', 'Magnesium', 'Potassium', 'PTT',
                            'WBC', 'Platelet', 'Sodium', 
                            'age', 'gender','sepsis', 'subject_id']]

plt.figure(figsize=(20,10))
msno.bar(raw_data_all, color="blue", log=False)
plt.title('Available number of each feature in MIMIC-III (adults)', size=16)
plt.show()
# plt.savefig('./data_figs/lab_missing_Cinc2019.pdf')
# Out:
# Number of featurs that contains null values 22

# %% [markdown]
# ## Others?

# %% [markdown]
# Files -> Pickle

# %%
baseline_train_data = pd.DataFrame([])

for p in train_id:

    # read in patient data
    df = pd.read_csv('/content/baseline/train_baseline/' + p, sep = "|")

    attributes = df.columns[:-1]
    df['patient_id'] = int(p.replace('p', '').replace('.sv', ''))
    
    baseline_train_data = pd.concat([baseline_train_data, df], ignore_index=False)  #True or False
    
import pickle
filename = '/content/baseline_train_data.pickle'
with open(filename, "wb") as f:
    pickle.dump(baseline_train_data, f)

# %%
baseline_val_data = pd.DataFrame([])

for p in val_id:

    # read in patient data
    df = pd.read_csv('/content/baseline/val_baseline/' + p, sep = "|")

    attributes = df.columns[:-1]
    df['patient_id'] = int(p.replace('p', '').replace('.sv', ''))
    
    baseline_val_data = pd.concat([baseline_val_data, df], ignore_index=False)  #True or False
    
import pickle
filename = '/content/baseline_val_data.pickle'
with open(filename, "wb") as f:
    pickle.dump(baseline_val_data, f)

# %%
baseline_test_data = pd.DataFrame([])

for p in test_id:

    # read in patient data
    df = pd.read_csv('/content/baseline/test_baseline/' + p, sep = "|")

    attributes = df.columns[:-1]
    df['patient_id'] = int(p.replace('p', '').replace('.sv', ''))
    
    baseline_test_data = pd.concat([baseline_test_data, df], ignore_index=False)  #True or False
    
import pickle
filename = '/content/baseline_test_data.pickle'
with open(filename, "wb") as f:
    pickle.dump(baseline_test_data, f)

# %%
print(baseline_train_data.shape)
print(baseline_val_data.shape)
print(baseline_test_data.shape)
# Out:
# (1087546, 42)
# (231361, 42)
# (233303, 42)

# %% [markdown]
# Pickle -> CSV

# %%
filename = '/content/baseline_train_data.pickle'
with open(filename, 'rb') as f:
    baseline_train = pickle.load(f)

print(baseline_train.head())
# Out:
#      HR  O2Sat  Temp    SBP    MAP    DBP  Resp  BaseExcess  HCO3  FiO2  ...  \
# 0  73.0   95.0  36.7  173.5  146.0  136.5  15.5         0.0   0.0   0.0  ...
# 1  73.0   95.0  36.7  173.5  146.0  136.5  15.5         0.0   0.0   0.0  ...
# 2  93.5   94.5  36.7  160.0  112.0   99.5  15.5         0.0   0.0   0.0  ...
# 3  80.0  100.0  36.7  149.0  101.0   86.0  14.0         0.0   0.0   0.0  ...
# 4  97.0   98.0  36.7  148.0  120.0  110.0  16.0         0.0   0.0   0.0  ...
#
#    Platelets   Age  Gender  HospAdmTime  ICULOS  SepsisLabel     HR_dev  \
# 0      228.0  29.0       1        -6.33       1            0  11.344602
# 1      228.0  29.0       1        -6.33       2            0  10.968136
# 2      228.0  29.0       1        -6.33       3            0   7.141428
# 3      228.0  29.0       1        -6.33       4            0   7.368853
# 4      228.0  29.0       1        -6.33       5            0   1.095445
#
#    Resp_dev  Temp_dev  patient_id
# 0  0.758288  0.000000      119960
# 1  0.935414  0.044721      119960
# 2  1.024695  0.054772      119960
# 3  1.341641  0.054772      119960
# 4  1.140175  0.044721      119960
#
# [5 rows x 42 columns]

# %%
filename = '/content/baseline_val_data.pickle'
with open(filename, 'rb') as f:
    baseline_val = pickle.load(f)

print(baseline_val.head())
# Out:
#       HR  O2Sat  Temp   SBP   MAP   DBP  Resp  BaseExcess  HCO3  FiO2  ...  \
# 0    NaN    NaN   NaN   NaN   NaN   NaN   NaN         NaN   NaN   NaN  ...
# 1  106.0   96.0  36.0  72.0  65.0  60.0  22.0         NaN   NaN   NaN  ...
# 2  106.0    NaN   NaN  76.0  65.5  60.0  19.0         NaN   NaN   NaN  ...
# 3  106.0    NaN   NaN  81.0  67.0  57.0  22.0         NaN   NaN   NaN  ...
# 4  106.0   95.0  36.3  80.0  69.0  60.0  25.0         NaN   NaN   NaN  ...
#
#    Platelets   Age  Gender  HospAdmTime  ICULOS  SepsisLabel    HR_dev  \
# 0        NaN  40.0       1         -7.8       1            0  0.000000
# 1        NaN  40.0       1         -7.8       2            0  0.000000
# 2        NaN  40.0       1         -7.8       3            0  0.000000
# 3        NaN  40.0       1         -7.8       4            0  1.788854
# 4        NaN  40.0       1         -7.8       5            0  2.190890
#
#    Resp_dev  Temp_dev  patient_id
# 0  2.449490  0.212132      119576
# 1  2.167948  0.212132      119576
# 2  3.033150       NaN      119576
# 3  2.408319       NaN      119576
# 4  2.280351  0.282843      119576
#
# [5 rows x 42 columns]

# %%
filename = '/content/baseline_test_data.pickle'
with open(filename, 'rb') as f:
    baseline_test = pickle.load(f)

print(baseline_test.head())
# Out:
#      HR  O2Sat  Temp    SBP    MAP    DBP  Resp  BaseExcess  HCO3  FiO2  ...  \
# 0   NaN    NaN   NaN    NaN    NaN    NaN   NaN         NaN   NaN   NaN  ...
# 1  51.0   98.0   NaN  127.0  116.5  107.0  13.0         NaN   NaN   NaN  ...
# 2  44.0  100.0  36.2    NaN   72.0    NaN  11.0         NaN   NaN   NaN  ...
# 3  52.0  100.0   NaN    NaN   54.0    NaN  10.0         NaN   NaN   NaN  ...
# 4  48.0  100.0   NaN    NaN   63.0    NaN   NaN         NaN   NaN   NaN  ...
#
#    Platelets   Age  Gender  HospAdmTime  ICULOS  SepsisLabel    HR_dev  \
# 0        NaN  77.0       1        -6.59       1            0  3.593976
# 1        NaN  77.0       1        -6.59       2            0  3.114482
# 2      102.0  77.0       1        -6.59       3            0  3.435113
# 3        NaN  77.0       1        -6.59       4            0  4.494441
# 4        NaN  77.0       1        -6.59       5            0  4.358899
#
#    Resp_dev  Temp_dev  patient_id
# 0  1.527525       NaN      104921
# 1  3.559026       NaN      104921
# 2  4.349329  0.212132      104921
# 3  4.434712       NaN      104921
# 4  1.000000       NaN      104921
#
# [5 rows x 42 columns]

# %%
td_num = []
for i in range(len(train_id)):
    temp = int(train_id[i][1:7])
    td_num.append(temp)
print(td_num)
print(len(td_num))

# %%
baseline_train = baseline_train[baseline_train.patient_id.isin(td_num)]

# %%
baseline_train.to_csv('/content/baseline_train.csv', sep = '|', index = False)

# %%
pd.read_csv('/content/baseline_train.csv', sep = '|')
# Out:
#             HR  O2Sat  Temp    SBP    MAP    DBP  Resp  BaseExcess  HCO3  \
# 0          NaN    NaN   NaN    NaN    NaN    NaN   NaN         NaN   NaN
# 1         73.0   95.0   NaN  173.5  146.0  136.5  15.5         NaN   NaN
# 2         93.5   94.5  36.7  160.0  112.0   99.5  15.5         NaN   NaN
# 3         80.0  100.0   NaN  149.0  101.0   86.0  14.0         NaN   NaN
# 4         97.0   98.0   NaN  148.0  120.0  110.0  16.0         NaN   NaN
# ...        ...    ...   ...    ...    ...    ...   ...         ...   ...
# 1087541   82.0   99.0   NaN   98.0   66.0   48.0  13.0         NaN   NaN
# 1087542   88.0   98.0   NaN   94.0   64.0   48.0  15.0         NaN   NaN
# 1087543   97.0   98.0   NaN   96.0   64.0   46.0  13.5         NaN   NaN
# 1087544  102.0   99.0  36.0   91.0   63.0   46.0  14.0         NaN   NaN
# 1087545   94.0   99.0   NaN   82.0   68.0   52.0  16.0         NaN   NaN
#
#          FiO2  ...  Platelets   Age  Gender  HospAdmTime  ICULOS  SepsisLabel  \
# 0         NaN  ...        NaN  29.0       1        -6.33       1            0
# 1         NaN  ...        NaN  29.0       1        -6.33       2            0
# 2         NaN  ...        NaN  29.0       1        -6.33       3            0
# 3         NaN  ...        NaN  29.0       1        -6.33       4            0
# 4         NaN  ...        NaN  29.0       1        -6.33       5            0
# ...       ...  ...        ...   ...     ...          ...     ...          ...
# 1087541   NaN  ...        NaN  49.0       0      -172.37      47            0
# 1087542   NaN  ...        NaN  49.0       0      -172.37      48            0
# 1087543   NaN  ...        NaN  49.0       0      -172.37      49            0
# 1087544   NaN  ...        NaN  49.0       0      -172.37      50            0
# 1087545   NaN  ...        NaN  49.0       0      -172.37      51            0
#
#             HR_dev  Resp_dev  Temp_dev  patient_id
# 0        11.286976  0.866025       NaN      119960
# 1        10.968136  0.935414       NaN      119960
# 2         7.141428  1.024695       NaN      119960
# 3         7.368853  1.341641       NaN      119960
# 4         1.095445  1.140175       NaN      119960
# ...            ...       ...       ...         ...
# 1087541   7.797435  1.204159       NaN      101764
# 1087542   5.852350  1.108678       NaN      101764
# 1087543   4.041452  1.322876       NaN      101764
# 1087544   5.656854  1.414214       NaN      101764
# 1087545        NaN       NaN       NaN      101764
#
# [1087546 rows x 42 columns]

# %%
val_num = []
for i in range(len(val_id)):
    temp = int(val_id[i][1:7])
    val_num.append(temp)
    
baseline_val = baseline_val[baseline_val.patient_id.isin(val_num)]

# %%
baseline_val.to_csv('/content/baseline_val.csv', sep = '|', index = False)

# %%
pd.read_csv('/content/baseline_val.csv', sep = '|')
# Out:
#            HR  O2Sat   Temp    SBP   MAP   DBP  Resp  BaseExcess  HCO3  FiO2  \
# 0         NaN    NaN    NaN    NaN   NaN   NaN   NaN         NaN   NaN   NaN
# 1       106.0   96.0  36.00   72.0  65.0  60.0  22.0         NaN   NaN   NaN
# 2       106.0    NaN    NaN   76.0  65.5  60.0  19.0         NaN   NaN   NaN
# 3       106.0    NaN    NaN   81.0  67.0  57.0  22.0         NaN   NaN   NaN
# 4       106.0   95.0  36.30   80.0  69.0  60.0  25.0         NaN   NaN   NaN
# ...       ...    ...    ...    ...   ...   ...   ...         ...   ...   ...
# 232258   84.0   98.0  36.61   95.5  68.0  53.5  11.5         NaN   NaN   NaN
# 232259   77.5  100.0    NaN   93.5  72.0  59.5  13.0         NaN   NaN   NaN
# 232260   76.0  100.0    NaN  102.0  76.5  68.0  13.5         NaN   NaN   NaN
# 232261   80.0  100.0    NaN  108.5  76.0  67.5  17.0         NaN   NaN   NaN
# 232262   80.0   99.0  36.83  108.0  76.0  66.0  13.0         NaN   NaN   NaN
#
#         ...  Platelets    Age  Gender  HospAdmTime  ICULOS  SepsisLabel  \
# 0       ...        NaN  40.00       1        -7.80       1            0
# 1       ...        NaN  40.00       1        -7.80       2            0
# 2       ...        NaN  40.00       1        -7.80       3            0
# 3       ...        NaN  40.00       1        -7.80       4            0
# 4       ...        NaN  40.00       1        -7.80       5            0
# ...     ...        ...    ...     ...          ...     ...          ...
# 232258  ...        NaN  56.92       1        -3.98      17            0
# 232259  ...        NaN  56.92       1        -3.98      18            0
# 232260  ...        NaN  56.92       1        -3.98      19            0
# 232261  ...        NaN  56.92       1        -3.98      20            0
# 232262  ...        NaN  56.92       1        -3.98      21            0
#
#           HR_dev  Resp_dev  Temp_dev  patient_id
# 0       0.000000  2.449490  0.212132      119576
# 1       0.000000  2.167948  0.212132      119576
# 2       0.000000  3.033150       NaN      119576
# 3       1.788854  2.408319       NaN      119576
# 4       2.190890  2.280351  0.282843      119576
# ...          ...       ...       ...         ...
# 232258  3.041381  2.043282  0.155563       16885
# 232259  1.973787  1.931105       NaN       16885
# 232260  2.309401  2.179449       NaN       16885
# 232261  0.000000  2.828427       NaN       16885
# 232262       NaN       NaN       NaN       16885
#
# [232263 rows x 42 columns]

# %%
test_num = []
for i in range(len(test_id)):
    temp = int(list(test_id)[i][1:7])
    test_num.append(temp)
    
baseline_test = baseline_test[baseline_test.patient_id.isin(test_num)]

# %%
baseline_test.to_csv('/content/baseline_test.csv', sep = '|', index = False)

# %%
pd.read_csv('/content/baseline_test.csv', sep = '|')
# Out:
#           HR  O2Sat  Temp    SBP    MAP    DBP  Resp  BaseExcess  HCO3  FiO2  \
# 0        NaN    NaN   NaN    NaN    NaN    NaN   NaN         NaN   NaN   NaN
# 1       51.0   98.0   NaN  127.0  116.5  107.0  13.0         NaN   NaN   NaN
# 2       44.0  100.0  36.2    NaN   72.0    NaN  11.0         NaN   NaN   NaN
# 3       52.0  100.0   NaN    NaN   54.0    NaN  10.0         NaN   NaN   NaN
# 4       48.0  100.0   NaN    NaN   63.0    NaN   NaN         NaN   NaN   NaN
# ...      ...    ...   ...    ...    ...    ...   ...         ...   ...   ...
# 232396  78.0   94.0   NaN  180.0  113.0   66.0  16.0         NaN   NaN   NaN
# 232397  75.0   93.0  36.0  196.0  120.0   84.0  20.0         NaN   NaN   NaN
# 232398  70.0   96.0   NaN  177.0  110.0   77.0  16.0         NaN   NaN   NaN
# 232399  67.0   97.5  37.1  167.5  124.0   75.5  17.0         NaN   NaN   NaN
# 232400  74.0   96.0   NaN  144.0   90.0   63.0  16.0         NaN   NaN   NaN
#
#         ...  Platelets   Age  Gender  HospAdmTime  ICULOS  SepsisLabel  \
# 0       ...        NaN  77.0       1        -6.59       1            0
# 1       ...        NaN  77.0       1        -6.59       2            0
# 2       ...      102.0  77.0       1        -6.59       3            0
# 3       ...        NaN  77.0       1        -6.59       4            0
# 4       ...        NaN  77.0       1        -6.59       5            0
# ...     ...        ...   ...     ...          ...     ...          ...
# 232396  ...        NaN  67.0       0        -5.10      11            0
# 232397  ...        NaN  67.0       0        -5.10      12            0
# 232398  ...        NaN  67.0       0        -5.10      13            0
# 232399  ...        NaN  67.0       0        -5.10      14            0
# 232400  ...        NaN  67.0       0        -5.10      15            0
#
#           HR_dev  Resp_dev  Temp_dev  patient_id
# 0       3.593976  1.527525       NaN      104921
# 1       3.114482  3.559026       NaN      104921
# 2       3.435113  4.349329  0.212132      104921
# 3       4.494441  4.434712       NaN      104921
# 4       4.358899  1.000000       NaN      104921
# ...          ...       ...       ...         ...
# 232396  4.324350  1.732051  0.777817      100208
# 232397  3.696846  1.892969  0.777817      100208
# 232398  3.511885  0.577350       NaN      100208
# 232399  4.949747  0.707107       NaN      100208
# 232400       NaN       NaN       NaN      100208
#
# [232401 rows x 42 columns]

# %% [markdown]
# ### Engineered Split

# %% [markdown]
# New Directories for baseline dataset

# %%
# !mkdir -p /content/engineered/train_engineered
# !mkdir -p /content/engineered/val_engineered
# !mkdir -p /content/engineered/test_engineered

# %%
#function 2 test
df1 = pd.read_csv(path_all + '/' + 'p000001.psv', sep = '|')
print('Original: ',df1.head())
attributes = df1.columns[:-1]
# impute missing values
df_filled = impute_missing_vals(df1, attributes)
print('Filled: ',df_filled.head())
print(np.any(np.isnan(df_filled)))

df_eng = new_features(df_filled)
print('Engineered: ',df_eng.head())
print('Engineered: ',df_eng.tail())
print(np.any(pd.isnull(df_eng)))
# Out:
# Original:        HR  O2Sat  Temp    SBP    MAP  DBP  Resp  EtCO2  BaseExcess  HCO3  ...  \
# 0    NaN    NaN   NaN    NaN    NaN  NaN   NaN    NaN         NaN   NaN  ...
# 1   97.0   95.0   NaN   98.0  75.33  NaN  19.0    NaN         NaN   NaN  ...
# 2   89.0   99.0   NaN  122.0  86.00  NaN  22.0    NaN         NaN   NaN  ...
# 3   90.0   95.0   NaN    NaN    NaN  NaN  30.0    NaN        24.0   NaN  ...
# 4  103.0   88.5   NaN  122.0  91.33  NaN  24.5    NaN         NaN   NaN  ...
#
#    WBC  Fibrinogen  Platelets    Age  Gender  Unit1  Unit2  HospAdmTime  \
# 0  NaN         NaN        NaN  83.14       0    NaN    NaN        -0.03
# 1  NaN         NaN        NaN  83.14       0    NaN    NaN        -0.03
# 2  NaN         NaN        NaN  83.14       0    NaN    NaN        -0.03
# 3  NaN         NaN        NaN  83.14       0    NaN    NaN        -0.03
# 4  NaN         NaN        NaN  83.14       0    NaN    NaN        -0.03
#
#    ICULOS  SepsisLabel
# 0       1            0
# 1       2            0
# 2       3            0
# 3       4            0
# 4       5            0
#
# [5 rows x 41 columns]
# Filled:        HR  O2Sat   Temp    SBP    MAP  DBP  Resp  EtCO2  BaseExcess  HCO3  ...  \
# 0   97.0   95.0  36.11   98.0  75.33  0.0  19.0    0.0        24.0  45.0  ...
# 1   97.0   95.0  36.11   98.0  75.33  0.0  19.0    0.0        24.0  45.0  ...
# 2   89.0   99.0  36.11  122.0  86.00  0.0  22.0    0.0        24.0  45.0  ...
# 3   90.0   95.0  36.11  122.0  86.00  0.0  30.0    0.0        24.0  45.0  ...
# 4  103.0   88.5  36.11  122.0  91.33  0.0  24.5    0.0        24.0  45.0  ...
#
#    WBC  Fibrinogen  Platelets    Age  Gender  Unit1  Unit2  HospAdmTime  \
# 0  5.7         0.0      317.0  83.14       0    0.0    0.0        -0.03
# 1  5.7         0.0      317.0  83.14       0    0.0    0.0        -0.03
# 2  5.7         0.0      317.0  83.14       0    0.0    0.0        -0.03
# 3  5.7         0.0      317.0  83.14       0    0.0    0.0        -0.03
# 4  5.7         0.0      317.0  83.14       0    0.0    0.0        -0.03
#
#    ICULOS  SepsisLabel
# 0       1            0
# 1       2            0
# 2       3            0
# 3       4            0
# 4       5            0
#
# [5 rows x 41 columns]
# False
# Engineered:        HR  O2Sat   Temp    SBP    MAP  DBP  Resp  EtCO2  BaseExcess  HCO3  ...  \
# 0   97.0   95.0  36.11   98.0  75.33  0.0  19.0    0.0        24.0  45.0  ...
# 1   97.0   95.0  36.11   98.0  75.33  0.0  19.0    0.0        24.0  45.0  ...
# 2   89.0   99.0  36.11  122.0  86.00  0.0  22.0    0.0        24.0  45.0  ...
# 3   90.0   95.0  36.11  122.0  86.00  0.0  30.0    0.0        24.0  45.0  ...
# 4  103.0   88.5  36.11  122.0  91.33  0.0  24.5    0.0        24.0  45.0  ...
#
#    Resp_dev_2  Resp_dev_3  Temp_dev_1  Temp_dev_2  Temp_dev_3  Bradycardia  \
# 0    4.175860    4.175860    0.421154    0.421154    0.421154        False
# 1    4.142990    4.142990    0.418726    0.418726    0.418726        False
# 2    4.105647    4.105647    0.415931    0.415931    0.415931        False
# 3    4.127336    4.127336    0.412724    0.412724    0.412724        False
# 4    4.102314    4.102314    0.409055    0.409055    0.409055        False
#
#    Tachycardia  Hypothermia  Fever  Hyperpyrexia
# 0        False        False  False         False
# 1        False        False  False         False
# 2        False        False  False         False
# 3        False        False  False         False
# 4         True        False  False         False
#
# [5 rows x 55 columns]
# Engineered:        HR  O2Sat   Temp    SBP   MAP  DBP  Resp  EtCO2  BaseExcess  HCO3  ...  \
# 49  76.0   86.5  36.33   85.0  53.0  0.0  17.0    0.0        19.0  48.0  ...
# 50  81.0   99.0  36.33   99.0  51.0  0.0  17.0    0.0        19.0  48.0  ...
# 51  85.0  100.0  36.33  103.0  48.0  0.0  26.0    0.0        19.0  48.0  ...
# 52  86.0   93.0  36.33   87.0  44.0  0.0  22.0    0.0        19.0  48.0  ...
# 53  84.0   85.0  36.33   78.0  44.0  0.0  18.0    0.0        19.0  48.0  ...
#
#     Resp_dev_2  Resp_dev_3  Temp_dev_1  Temp_dev_2  Temp_dev_3  Bradycardia  \
# 49    3.937004    3.937004         0.0         0.0         0.0        False
# 50    4.112988    4.112988         0.0         0.0         0.0        False
# 51    4.000000    4.000000         0.0         0.0         0.0        False
# 52    2.828427    2.828427         0.0         0.0         0.0        False
# 53    2.828427    2.828427         0.0         0.0         0.0        False
#
#     Tachycardia  Hypothermia  Fever  Hyperpyrexia
# 49        False        False  False         False
# 50        False        False  False         False
# 51        False        False  False         False
# 52        False        False  False         False
# 53        False        False  False         False
#
# [5 rows x 55 columns]
# False

# %%
# impute missing values and create clean dfs for all patients
for p in patient_id:
    
    # read in patient data
    df = pd.read_csv(path_all + '/' + p, sep = "|")
    attributes = df.columns[:-1]
    
    # impute missing values
    df_filled = impute_missing_vals(df, attributes)
    # add features of deviation
    df_engineered = new_features(df_filled)
    
    # drop unit1 and unit2 with half missing values
    # because these two features have few information
    # drop EtCO2 with all missing values
    df_clean = df_engineered.drop(['Unit1', 'Unit2', 'EtCO2'], axis=1)
    
    # save new patient data
    if p in train_id:
        save_path = '/content/engineered/train_engineered/'
        df_clean.to_csv(save_path + p, sep='|', index = False)        
    
    elif p in val_id:
        save_path = '/content/engineered/val_engineered//'
        df_clean.to_csv(save_path + p, sep='|', index = False)        
    
    else:
        
        save_path = '/content/engineered/test_engineered//'
        df_clean.to_csv(save_path + p, sep='|', index = False)
    
    print(p)

# %% [markdown]
# Files -> Pickle

# %%
engineered_train_data = pd.DataFrame([])

for p in train_id:

    # read in patient data
    df = pd.read_csv('/content/engineered/train_engineered/' + p, sep = "|")

    attributes = df.columns[:-1]
    df['patient_id'] = int(p.replace('p', '').replace('.sv', ''))
    
    engineered_train_data = pd.concat([engineered_train_data, df], ignore_index=False)  #True or False
    
import pickle
filename = '/content/engineered_train_data.pickle'
with open(filename, "wb") as f:
    pickle.dump(engineered_train_data, f)

# %%
engineered_val_data = pd.DataFrame([])

for p in val_id:

    # read in patient data
    df = pd.read_csv('/content/engineered/val_engineered/' + p, sep = "|")

    attributes = df.columns[:-1]
    df['patient_id'] = int(p.replace('p', '').replace('.sv', ''))
    
    engineered_val_data = pd.concat([engineered_val_data, df], ignore_index=False)  #True or False
    
import pickle
filename = '/content/engineered_val_data.pickle'
with open(filename, "wb") as f:
    pickle.dump(engineered_val_data, f)

# %%
engineered_test_data = pd.DataFrame([])

for p in test_id:

    # read in patient data
    df = pd.read_csv('/content/engineered/test_engineered/' + p, sep = "|")

    attributes = df.columns[:-1]
    df['patient_id'] = int(p.replace('p', '').replace('.sv', ''))
    
    engineered_test_data = pd.concat([engineered_test_data, df], ignore_index=False)  #True or False
    
import pickle
filename = '/content/engineered_test_data.pickle'
with open(filename, "wb") as f:
    pickle.dump(engineered_test_data, f)

# %%
print(engineered_train_data.shape)
print(engineered_val_data.shape)
print(engineered_test_data.shape)
# Out:
# (1087546, 53)
# (233247, 53)
# (231417, 53)

# %% [markdown]
# Pickle -> CSV

# %%
filename = '/content/engineered_train_data.pickle'
with open(filename, 'rb') as f:
    engineered_train = pickle.load(f)

print(engineered_train.head())
# Out:
#      HR  O2Sat  Temp    SBP    MAP    DBP  Resp  BaseExcess  HCO3  FiO2  ...  \
# 0  73.0   95.0  36.7  173.5  146.0  136.5  15.5         0.0   0.0   0.0  ...
# 1  73.0   95.0  36.7  173.5  146.0  136.5  15.5         0.0   0.0   0.0  ...
# 2  93.5   94.5  36.7  160.0  112.0   99.5  15.5         0.0   0.0   0.0  ...
# 3  80.0  100.0  36.7  149.0  101.0   86.0  14.0         0.0   0.0   0.0  ...
# 4  97.0   98.0  36.7  148.0  120.0  110.0  16.0         0.0   0.0   0.0  ...
#
#    Resp_dev_3  Temp_dev_1  Temp_dev_2  Temp_dev_3  Bradycardia  Tachycardia  \
# 0    2.490531    0.258199    0.258199    0.258199        False        False
# 1    2.514364    0.260595    0.260595    0.260595        False        False
# 2    2.538894    0.263060    0.263060    0.263060        False        False
# 3    2.564157    0.265596    0.265596    0.265596        False        False
# 4    2.581251    0.268206    0.268206    0.268206        False        False
#
#    Hypothermia  Fever  Hyperpyrexia  patient_id
# 0        False  False         False      119960
# 1        False  False         False      119960
# 2        False  False         False      119960
# 3        False  False         False      119960
# 4        False  False         False      119960
#
# [5 rows x 53 columns]

# %%
filename = '/content/engineered_val_data.pickle'
with open(filename, 'rb') as f:
    engineered_val = pickle.load(f)

print(engineered_val.head())
# Out:
#      HR  O2Sat   Temp    SBP   MAP   DBP  Resp  BaseExcess  HCO3  FiO2  ...  \
# 0  72.0  100.0  35.40  105.0  62.5  44.5  15.5        -2.0  22.0   1.0  ...
# 1  80.0  100.0  35.85  117.5  70.5  52.0  14.0        -2.0  22.0   0.7  ...
# 2  80.0  100.0  36.75  112.0  69.0  52.0  16.0        -1.0  22.0   0.7  ...
# 3  80.0  100.0  36.95  104.5  66.5  51.5  16.0        -1.0  22.0   0.6  ...
# 4  80.0  100.0  36.90  100.0  65.0  51.0  16.0        -2.0  22.0   0.6  ...
#
#    Resp_dev_3  Temp_dev_1  Temp_dev_2  Temp_dev_3  Bradycardia  Tachycardia  \
# 0    2.797057    0.826306    0.826306    0.826306        False        False
# 1    2.878035    0.662799    0.662799    0.662799        False        False
# 2    2.913868    0.501224    0.501224    0.501224        False        False
# 3    3.014647    0.445836    0.445836    0.445836        False        False
# 4    3.126675    0.397390    0.397390    0.397390        False        False
#
#    Hypothermia  Fever  Hyperpyrexia  patient_id
# 0        False  False         False          61
# 1        False  False         False          61
# 2        False  False         False          61
# 3        False  False         False          61
# 4        False  False         False          61
#
# [5 rows x 53 columns]

# %%
filename = '/content/engineered_test_data.pickle'
with open(filename, 'rb') as f:
    engineered_test = pickle.load(f)

print(engineered_test.head())
# Out:
#       HR  O2Sat  Temp    SBP   MAP   DBP  Resp  BaseExcess  HCO3  FiO2  ...  \
# 0  112.0   99.0  36.8  116.0  81.0  59.0  10.0         0.0   0.0   0.0  ...
# 1  112.0   99.0  36.8  116.0  81.0  59.0  10.0         0.0   0.0   0.0  ...
# 2  105.0   99.5  36.8  119.0  82.0  60.0  11.0         0.0   0.0   0.0  ...
# 3  102.0  100.0  36.8  116.0  83.0  62.0   9.5         0.0   0.0   0.0  ...
# 4  100.0  100.0  36.8  116.0  78.0  56.0  10.0         0.0   0.0   0.0  ...
#
#    Resp_dev_3  Temp_dev_1  Temp_dev_2  Temp_dev_3  Bradycardia  Tachycardia  \
# 0    5.147994    0.125062    0.125062    0.125062        False         True
# 1    5.136883    0.124881    0.124881    0.124881        False         True
# 2    5.116659    0.124493    0.124493    0.124493        False         True
# 3    5.127753    0.123849    0.123849    0.123849        False         True
# 4    5.059809    0.122882    0.122882    0.122882        False        False
#
#    Hypothermia  Fever  Hyperpyrexia  patient_id
# 0        False  False         False      112636
# 1        False  False         False      112636
# 2        False  False         False      112636
# 3        False  False         False      112636
# 4        False  False         False      112636
#
# [5 rows x 53 columns]

# %%
td_num = []
for i in range(len(train_id)):
    temp = int(train_id[i][1:7])
    td_num.append(temp)
print(td_num)
print(len(td_num))

# %%
engineered_train = engineered_train[engineered_train.patient_id.isin(td_num)]

# %%
engineered_train.to_csv('/content/engineered_train.csv', sep = '|', index = False)

# %%
pd.read_csv('/content/engineered_train.csv', sep = '|')
# Out:
#             HR  O2Sat  Temp    SBP    MAP    DBP  Resp  BaseExcess  HCO3  \
# 0         73.0   95.0  36.7  173.5  146.0  136.5  15.5         0.0   0.0
# 1         73.0   95.0  36.7  173.5  146.0  136.5  15.5         0.0   0.0
# 2         93.5   94.5  36.7  160.0  112.0   99.5  15.5         0.0   0.0
# 3         80.0  100.0  36.7  149.0  101.0   86.0  14.0         0.0   0.0
# 4         97.0   98.0  36.7  148.0  120.0  110.0  16.0         0.0   0.0
# ...        ...    ...   ...    ...    ...    ...   ...         ...   ...
# 1087541   82.0   99.0  35.6   98.0   66.0   48.0  13.0         0.0   0.0
# 1087542   88.0   98.0  35.6   94.0   64.0   48.0  15.0         0.0   0.0
# 1087543   97.0   98.0  36.0   96.0   64.0   46.0  13.5         0.0   0.0
# 1087544  102.0   99.0  36.0   91.0   63.0   46.0  14.0         0.0   0.0
# 1087545   94.0   99.0  36.0   82.0   68.0   52.0  16.0         0.0   0.0
#
#          FiO2  ...  Resp_dev_3  Temp_dev_1  Temp_dev_2  Temp_dev_3  \
# 0         0.0  ...    2.490531    0.258199    0.258199    0.258199
# 1         0.0  ...    2.514364    0.260595    0.260595    0.260595
# 2         0.0  ...    2.538894    0.263060    0.263060    0.263060
# 3         0.0  ...    2.564157    0.265596    0.265596    0.265596
# 4         0.0  ...    2.581251    0.268206    0.268206    0.268206
# ...       ...  ...         ...         ...         ...         ...
# 1087541   0.5  ...    1.204159    0.219089    0.219089    0.219089
# 1087542   0.5  ...    1.108678    0.200000    0.200000    0.200000
# 1087543   0.5  ...    1.322876    0.000000    0.000000    0.000000
# 1087544   0.5  ...    1.414214    0.000000    0.000000    0.000000
# 1087545   0.5  ...    1.414214    0.000000    0.000000    0.000000
#
#          Bradycardia  Tachycardia  Hypothermia  Fever  Hyperpyrexia  \
# 0              False        False        False  False         False
# 1              False        False        False  False         False
# 2              False        False        False  False         False
# 3              False        False        False  False         False
# 4              False        False        False  False         False
# ...              ...          ...          ...    ...           ...
# 1087541        False        False        False  False         False
# 1087542        False        False        False  False         False
# 1087543        False        False        False  False         False
# 1087544        False         True        False  False         False
# 1087545        False        False        False  False         False
#
#          patient_id
# 0            119960
# 1            119960
# 2            119960
# 3            119960
# 4            119960
# ...             ...
# 1087541      101764
# 1087542      101764
# 1087543      101764
# 1087544      101764
# 1087545      101764
#
# [1087546 rows x 53 columns]

# %%
val_num = []
for i in range(len(val_id)):
    temp = int(val_id[i][1:7])
    val_num.append(temp)
    
engineered_val = engineered_val[engineered_val.patient_id.isin(val_num)]

# %%
engineered_val.to_csv('/content/engineered_val.csv', sep = '|', index = False)

# %%
pd.read_csv('/content/engineered_val.csv', sep = '|')
# Out:
#           HR  O2Sat   Temp    SBP    MAP   DBP  Resp  BaseExcess  HCO3  FiO2  \
# 0       72.0  100.0  35.40  105.0  62.50  44.5  15.5        -2.0  22.0   1.0
# 1       80.0  100.0  35.85  117.5  70.50  52.0  14.0        -2.0  22.0   0.7
# 2       80.0  100.0  36.75  112.0  69.00  52.0  16.0        -1.0  22.0   0.7
# 3       80.0  100.0  36.95  104.5  66.50  51.5  16.0        -1.0  22.0   0.6
# 4       80.0  100.0  36.90  100.0  65.00  51.0  16.0        -2.0  22.0   0.6
# ...      ...    ...    ...    ...    ...   ...   ...         ...   ...   ...
# 233242  73.0   98.0  35.72  108.0  80.00  54.0  19.0         0.0  26.0   0.0
# 233243  77.0   98.0  35.72  130.0  88.00  58.0  18.0         0.0  26.0   0.0
# 233244  76.0   99.0  35.72  118.0  77.33  58.0  19.0         0.0  26.0   0.0
# 233245  79.0   99.0  35.72  145.0  95.67  58.0  17.0         0.0  26.0   0.0
# 233246  76.0   99.0  35.72  140.0  83.33  58.0  23.0         0.0  26.0   0.0
#
#         ...  Resp_dev_3  Temp_dev_1  Temp_dev_2  Temp_dev_3  Bradycardia  \
# 0       ...    2.797057    0.826306    0.826306    0.826306        False
# 1       ...    2.878035    0.662799    0.662799    0.662799        False
# 2       ...    2.913868    0.501224    0.501224    0.501224        False
# 3       ...    3.014647    0.445836    0.445836    0.445836        False
# 4       ...    3.126675    0.397390    0.397390    0.397390        False
# ...     ...         ...         ...         ...         ...          ...
# 233242  ...    2.280351    0.000000    0.000000    0.000000        False
# 233243  ...    2.629956    0.000000    0.000000    0.000000        False
# 233244  ...    3.055050    0.000000    0.000000    0.000000        False
# 233245  ...    4.242641    0.000000    0.000000    0.000000        False
# 233246  ...    4.242641    0.000000    0.000000    0.000000        False
#
#         Tachycardia  Hypothermia  Fever  Hyperpyrexia  patient_id
# 0             False        False  False         False          61
# 1             False        False  False         False          61
# 2             False        False  False         False          61
# 3             False        False  False         False          61
# 4             False        False  False         False          61
# ...             ...          ...    ...           ...         ...
# 233242        False        False  False         False        2028
# 233243        False        False  False         False        2028
# 233244        False        False  False         False        2028
# 233245        False        False  False         False        2028
# 233246        False        False  False         False        2028
#
# [233247 rows x 53 columns]

# %%
test_num = []
for i in range(len(test_id)):
    temp = int(list(test_id)[i][1:7])
    test_num.append(temp)
    
engineered_test = engineered_test[engineered_test.patient_id.isin(test_num)]

# %%
engineered_test.to_csv('/content/engineered_test.csv', sep = '|', index = False)

# %%
pd.read_csv('/content/engineered_test.csv', sep = '|')
# Out:
#            HR  O2Sat   Temp     SBP    MAP   DBP  Resp  BaseExcess  HCO3  \
# 0       112.0   99.0  36.80  116.00  81.00  59.0  10.0         0.0   0.0
# 1       112.0   99.0  36.80  116.00  81.00  59.0  10.0         0.0   0.0
# 2       105.0   99.5  36.80  119.00  82.00  60.0  11.0         0.0   0.0
# 3       102.0  100.0  36.80  116.00  83.00  62.0   9.5         0.0   0.0
# 4       100.0  100.0  36.80  116.00  78.00  56.0  10.0         0.0   0.0
# ...       ...    ...    ...     ...    ...   ...   ...         ...   ...
# 231412   97.0   97.0  37.30  103.00  60.67  46.0  16.0        -4.0  18.0
# 231413   98.0   99.0  37.25   87.25  59.83  51.0  20.0        -4.0  18.0
# 231414   90.0  100.0  37.20  100.00  67.33  57.0  21.0        -4.0  18.0
# 231415   93.0   99.0  37.30  117.00  69.67  57.0  23.0        -4.0  18.0
# 231416   99.0   98.0  37.50  114.00  66.67  57.0  17.0        -4.0  18.0
#
#         FiO2  ...  Resp_dev_3  Temp_dev_1  Temp_dev_2  Temp_dev_3  \
# 0        0.0  ...    5.147994    0.125062    0.125062    0.125062
# 1        0.0  ...    5.136883    0.124881    0.124881    0.124881
# 2        0.0  ...    5.116659    0.124493    0.124493    0.124493
# 3        0.0  ...    5.127753    0.123849    0.123849    0.123849
# 4        0.0  ...    5.059809    0.122882    0.122882    0.122882
# ...      ...  ...         ...         ...         ...         ...
# 231412   0.6  ...    2.880972    0.114018    0.114018    0.114018
# 231413   0.6  ...    2.500000    0.131498    0.131498    0.131498
# 231414   0.5  ...    3.055050    0.152753    0.152753    0.152753
# 231415   0.5  ...    4.242641    0.141421    0.141421    0.141421
# 231416   0.5  ...    4.242641    0.141421    0.141421    0.141421
#
#         Bradycardia  Tachycardia  Hypothermia  Fever  Hyperpyrexia  patient_id
# 0             False         True        False  False         False      112636
# 1             False         True        False  False         False      112636
# 2             False         True        False  False         False      112636
# 3             False         True        False  False         False      112636
# 4             False        False        False  False         False      112636
# ...             ...          ...          ...    ...           ...         ...
# 231412        False        False        False  False         False        2749
# 231413        False        False        False  False         False        2749
# 231414        False        False        False  False         False        2749
# 231415        False        False        False  False         False        2749
# 231416        False        False        False  False         False        2749
#
# [231417 rows x 53 columns]

# %% [markdown]
# ### Raw split

# %%
# !mkdir -p /content/raw/training
# !mkdir -p /content/raw/validation
# !mkdir -p /content/raw/test
data_train = '/content/raw/training/'
data_val = '/content/raw/validation/'
data_test = '/content/raw/test/'
Split
for p in train_id:
    df = pd.read_csv(path_all + '/' + p, sep = "|")
    df.to_csv(data_train  + p, sep='|', index = False) 
for p in val_id:
    df = pd.read_csv(path_all + '/' + p, sep = "|")
    df.to_csv(data_val + p, sep='|', index = False) 
for p in test_id:
    df = pd.read_csv(path_all + '/' + p, sep = "|")
    df.to_csv(data_test + p, sep='|', index = False)
Files -> Pickle
#raw data of the whole dataset
raw_data = pd.DataFrame([])

for p in patient_id:

    # read in patient data
    df = pd.read_csv('/content/training_setAB/' + p, sep = "|")
    
    attributes = df.columns[:-1]
    df['patient_id'] = int(p.replace('p', '').replace('.sv', ''))
    
    raw_data = pd.concat([raw_data, df], ignore_index=False)

import pickle
filename = '/content/raw_data.pickle'
with open(filename, "wb") as f:
    pickle.dump(raw_data, f)
raw_train_data = pd.DataFrame([])

for p in train_id:

    # read in patient data
    df = pd.read_csv('/content/raw/training/' + p, sep = "|")

    attributes = df.columns[:-1]
    df['patient_id'] = int(p.replace('p', '').replace('.sv', ''))
    
    raw_train_data = pd.concat([raw_train_data, df], ignore_index=False)
    
import pickle
filename = '/content/raw_train_data.pickle'
with open(filename, "wb") as f:
    pickle.dump(raw_train_data, f)
raw_val_data = pd.DataFrame([])

for p in val_id:

    # read in patient data
    df = pd.read_csv('/content/raw/validation/' + p, sep = "|")

    attributes = df.columns[:-1]
    df['patient_id'] = int(p.replace('p', '').replace('.sv', ''))
    
    raw_val_data = pd.concat([raw_val_data, df], ignore_index=False)
    
import pickle
filename = '/content/raw_val_data.pickle'
with open(filename, "wb") as f:
    pickle.dump(raw_val_data, f)
raw_test_data = pd.DataFrame([])

for p in test_id:

    # read in patient data
    df = pd.read_csv('/content/raw/test/' + p, sep = "|")

    attributes = df.columns[:-1]
    df['patient_id'] = int(p.replace('p', '').replace('.sv', ''))
    
    raw_test_data = pd.concat([raw_test_data, df], ignore_index=False)  #True or False
    
import pickle
filename = '/content/raw_test_data.pickle'
with open(filename, "wb") as f:
    pickle.dump(raw_test_data, f)
Check the shape of traning, val and test dataset
print(raw_data.shape)
print(raw_train_data.shape)
print(raw_val_data.shape)
print(raw_test_data.shape)
Pickle -> CSV
#raw_data
filename = '/content/raw_data.pickle'
with open(filename, 'rb') as f:
    raw = pickle.load(f)

raw.to_csv('/content/raw_data.csv', sep = '|', index = False)
pd.read_csv('/content/raw_data.csv', sep = '|')
#raw_train
filename = '/content/raw_train_data.pickle'
with open(filename, 'rb') as f:
    raw_train = pickle.load(f)

raw_train.to_csv('/content/raw_train.csv', sep = '|', index = False)
pd.read_csv('/content/raw_train.csv', sep = '|')
#raw_val
filename = '/content/raw_val_data.pickle'
with open(filename, 'rb') as f:
    raw_val = pickle.load(f)

raw_val.to_csv('/content/raw_val.csv', sep = '|', index = False)
pd.read_csv('/content/raw_val.csv', sep = '|')
#raw_test
filename = '/content/raw_test_data.pickle'
with open(filename, 'rb') as f:
    raw_test = pickle.load(f)

raw_test.to_csv('/content/raw_test.csv', sep = '|', index = False)
pd.read_csv('/content/raw_test.csv', sep = '|')
