# %% [markdown]
# ## import libs and mount google drive

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# check the system font
import matplotlib.font_manager as font_manager
font_manager.findSystemFonts(fontpaths=None, fontext='ttf')

# add the font wanted
font_dir = ['../Latin-Modern-Roman']
for font in font_manager.findSystemFonts(font_dir):
    font_manager.fontManager.addfont(font)

# Set font family globally
plt.rcParams['font.family'] = 'Latin Modern Roman'
# Out:
# Fontconfig warning: ignoring UTF-8: not a valid region tag

# %% [markdown]
# ## Features

# %%
cinc2019_original_features = sorted((pd.read_csv('../datasets/Cinc2019/data_all/p000001.psv', sep ='|')).columns)
print('Original features in Cinc2019:\n',cinc2019_original_features)
print('\n')

cinc2019_patient_baseline_features = sorted((pd.read_csv('../datasets/Cinc2019/baseline_all/p000001.csv')).columns)
print('Baseline features in Cinc2019:\n',cinc2019_patient_baseline_features)
cinc2019_patient_engineered_features = sorted((pd.read_csv('../datasets/Cinc2019/engineered_all/p000001.csv')).columns)
print('Engineered features in Cinc2019:\n',cinc2019_patient_engineered_features)
print('\n')

mimiciii_adults_original_features = sorted((pd.read_csv('../datasets/MIMICIII/adults/processed_sepsis/9.csv')).columns)
print('Original features in MIMIC-III (adults):\n',mimiciii_adults_original_features)
print('\n')

mimiciii_adults_baseline_features = sorted((pd.read_csv('../datasets/MIMICIII/adults/adults_all/9.csv')).columns)
print('Baseline features in MIMIC-III (adults):\n',mimiciii_adults_baseline_features)
mimiciii_adults_engineered_features = sorted((pd.read_csv('../datasets/MIMICIII/adults/engineered_all/9.csv')).columns)
print('Engineered features in MIMIC-III (adults):\n',mimiciii_adults_engineered_features)
print('\n')

mimiciii_neonates_original_features = sorted((pd.read_csv('../datasets/MIMICIII/neonates/processed_all/8.csv')).columns)
print('Original features in MIMIC-III (neonates):\n',mimiciii_neonates_original_features)
print('\n')

mimiciii_neonates_baseline_features = sorted((pd.read_csv('../datasets/MIMICIII/neonates/baseline_all/8.csv')).columns)
print('Baseline features in MIMIC-III (neonates):\n',mimiciii_neonates_baseline_features)
mimiciii_neonates_engineered_features = sorted((pd.read_csv('../datasets/MIMICIII/neonates/engineered_all/8.csv')).columns)
print('Engineered features in MIMIC-III (neonates):\n',mimiciii_neonates_engineered_features)
print('\n')

artificial_neonates_baseline_features = sorted((pd.read_csv('../artificial_neonatal_data/data/balanced_2000/baseline_all/1001.csv')).columns)
print('Baseline features in Artificial Neonatal Data:\n',artificial_neonates_baseline_features)
artificial_neonates_engineered_features = sorted((pd.read_csv('../artificial_neonatal_data/data/balanced_2000/engineered_all/1001.csv')).columns)
print('Engineered features in Artificial Neonatal Data:\n',artificial_neonates_engineered_features)
# Out:
# Original features in Cinc2019:
#  ['AST', 'Age', 'Alkalinephos', 'BUN', 'BaseExcess', 'Bilirubin_direct', 'Bilirubin_total', 'Calcium', 'Chloride', 'Creatinine', 'DBP', 'EtCO2', 'FiO2', 'Fibrinogen', 'Gender', 'Glucose', 'HCO3', 'HR', 'Hct', 'Hgb', 'HospAdmTime', 'ICULOS', 'Lactate', 'MAP', 'Magnesium', 'O2Sat', 'PTT', 'PaCO2', 'Phosphate', 'Platelets', 'Potassium', 'Resp', 'SBP', 'SaO2', 'SepsisLabel', 'Temp', 'TroponinI', 'Unit1', 'Unit2', 'WBC', 'pH']
#
#
# Baseline features in Cinc2019:
#  ['BUN', 'BaseExcess', 'Calcium', 'Chloride', 'Creatinine', 'DBP', 'Glucose', 'HCO3', 'HR', 'Lactic', 'MAP', 'Magnesium', 'PH', 'PTT', 'Platelet', 'Potassium', 'RR', 'SBP', 'SaO2', 'Temp', 'WBC', 'age', 'gender', 'sepsis', 'subject_id']
# Engineered features in Cinc2019:
# ...

# %% [markdown]
# ## linear and logistic regression

# %%
import math

def sigmoid(x):
    a = []
    for item in x:
        a.append(1/(1+math.exp(-item)))
    return a

# %%
def linear(x):
  a = []
  for item in x:
    a.append(0.05*item +0.5)
  return a

# %%
x = np.arange(-10., 10., 0.2)
sig = sigmoid(x)
lin = linear(x)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

#plot
plt.plot(x,sig)
plt.plot(x,lin)

# # Add title and axis names
# plt.xlabel('X')
# plt.ylabel('Y')

plt.savefig('LRLR.eps')

plt.show()
