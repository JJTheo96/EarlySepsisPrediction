# %% [markdown]
# # Generate adults dataset from MIMIC III using BigQuery

# %% [markdown]
# ## Libraries and Environment

# %%
# Import libraries
from datetime import datetime
import os

import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Make pandas dataframes prettier
from IPython.display import display, HTML, Image
# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams.update({'font.size': 20})

# Access data using Google BigQuery.
from google.colab import drive
from google.colab import auth
from google.cloud import bigquery

# %%
# authenticate
auth.authenticate_user()
# mount
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Set up environment variables
project_id = 'mimic-370210'
os.environ["GOOGLE_CLOUD_PROJECT"] = project_id

# Read data from BigQuery into pandas dataframes.
def run_query(query, project_id=project_id):
  return pd.io.gbq.read_gbq(
      query,
      project_id=project_id,
      dialect='standard')

# test it works
df = run_query("""
SELECT *
FROM `mimic-370210.adults.adults_id`
""")
df
# Out:
#        subject_id
# 0               9
# 1              21
# 2              38
# 3              61
# 4              88
# ...           ...
# 20931       99955
# 20932       99957
# 20933       99985
# 20934       99991
# 20935       99992
#
# [20936 rows x 1 columns]

# %% [markdown]
# ## Query static information

# %%
adults_id = run_query("""
SELECT *
FROM `mimic-370210.adults.adults_id`
""")
adults_id.head()
# Out:
#    subject_id
# 0           9
# 1          21
# 2          38
# 3          61
# 4          88

# %%
adults_static = run_query("""
SELECT *
FROM `mimic-370210.adults.adults_static`
""")
adults_static.head()
# Out:
#    subject_id gender   age           spec diagnoses                time
# 0           3      M  76.0  BLOOD CULTURE     False 2101-10-20 18:00:00
# 1           3      M  76.0  BLOOD CULTURE     False 2101-10-20 18:30:00
# 2           3      M  76.0  BLOOD CULTURE     False 2101-10-21 04:00:00
# 3           3      M  76.0  BLOOD CULTURE     False 2101-10-21 04:00:00
# 4           3      M  76.0  BLOOD CULTURE     False 2101-10-21 04:15:00

# %%
# adults_event = run_query("""
# SELECT *
# FROM `mimic-370210.adults.adults_event`
# """)

# %% [markdown]
# **Don't read neonates_event NOW**\
# **Read it use loop**

# %%
# Function: to perforrm OR operation considering NaN
def f_or(a,b):
    if not np.isnan(a):
        return a
    if not np.isnan(b):
        return b
    return np.nan

# %%
# Function: re-arranege the dataset according to the timepoints
# Input: the DataFrames of static_info and event_info
# Outout: the re-arranged DataFrame


def arrange_time(df_static, df_events, all_columns):
    df_final = pd.DataFrame(columns=all_columns)
    sepsis_indicator = False  #used for storing neonates in different folders
    # read the static data
    subject_id = df_static.subject_id[0]
    gender = df_static.gender[0]
    age = df_static.age[0]
    all_events = df_events
    all_events['sepsis'] = False  #add a new column of sepsis
    for index, row in df_static.iterrows():
      if row['diagnoses'] == "True":
        sepsis_indicator = True
        sepsis_onset_time = row['time']  #only pick the first on-set-time
        all_events = all_events.append({'subject_id':subject_id, 'time':sepsis_onset_time,
                            'value':np.nan,'unit':np.nan, 'abbr':np.nan, 'sepsis':True},
                          ignore_index = True)
        all_events.sort_values('time', inplace = True)
        break #keep the first time of sepsis if there are several

    # Get the time points from events
    time_sequence = all_events.loc[:,"time"]
    time_sequence.drop_duplicates( keep='first',inplace= True)
    time_sequence = time_sequence.reset_index(drop =True)
    len_time = len(time_sequence)
    for index_time, value in time_sequence.items():
        time = str(value)
        df_current = all_events
        df_current = df_current[df_current['time'].astype(str).str.fullmatch(time)]
        # print('Aviliable DataFrame at this time point',df_current)
        # iterrate each row and set values
        sepsis_final = False
        NBPs_final = np.nan
        NBPd_final = np.nan
        NBPm_final = np.nan
        temp_final = np.nan
        hr_final = np.nan
        rr_final = np.nan
        abe_final = np.nan
        FiO2_final = np.nan
        SpO2_final = np.nan
        PCO2_final = np.nan
        ph_final = np.nan
        magnesium_final = np.nan
        calcium_final = np.nan
        latic_final  = np.nan
        sodium_final = np.nan
        potassium_final = np.nan
        creatinine_final = np.nan
        chloride_final = np.nan
        HCO3_final = np.nan
        glucose_final = np.nan
        WBC_final = np.nan
        BUN_final = np.nan
        PTT_final = np.nan
        platelet_final = np.nan
        for index, row in df_current.iterrows():
            if row['sepsis']:
              sepsis_final = True # sepsis positive at current time

            if row['abbr'] == 'SBP':
                NBPs = row['value']
            else: NBPs = np.nan
            NBPs_final = f_or(NBPs_final,NBPs)
            
            if row['abbr'] == 'DBP':
                NBPd = row['value']
            else: NBPd = np.nan
            NBPd_final = f_or(NBPd_final,NBPd)
            
            if row['abbr'] == 'MAP':
                NBPm = row['value']
            else: NBPm = np.nan
            NBPm_final = f_or(NBPm_final,NBPm)
            
            if row['abbr'] == 'Temp':
                temp = row['value']
            else: temp = np.nan
            temp_final = f_or(temp_final,temp)
            
            if row['abbr'] == 'HR':
                hr = row['value']
            else: hr = np.nan
            hr_final = f_or(hr_final,hr)
            
            if row['abbr'] == 'RR':
                rr = row['value']
            else: rr = np.nan
            rr_final = f_or(rr_final,rr)
            
            if row['abbr'] == 'BaseExcess':
                abe = row['value']
            else: abe = np.nan
            abe_final = f_or(abe_final,abe)
            
            # if row['abbr'] == 'FiO2':
            #     FiO2 = row['value']
            # else: FiO2 = np.nan
            # FiO2_final = f_or(FiO2_final,FiO2)

            if row['abbr'] == 'SaO2':
                SpO2 = row['value']
            else: SpO2 = np.nan
            SpO2_final = f_or(SpO2_final,SpO2)
            
            # if row['abbr'] == 'PCO2':
            #     PCO2 = row['value']
            # else: PCO2 = np.nan
            # PCO2_final = f_or(PCO2_final,PCO2)
            
            if row['abbr'] == 'PH':
                ph = row['value']
            else: ph = np.nan
            ph_final = f_or(ph_final,ph)
            
            if row['abbr'] == 'Magnesium':
                magnesium = row['value']
            else: magnesium = np.nan
            magnesium_final = f_or(magnesium_final,magnesium)
            
            if row['abbr'] == 'Calcium':
                calcium = row['value']
            else: calcium = np.nan
            calcium_final = f_or(calcium_final,calcium)
            
            if row['abbr'] == 'Lactic':
                latic = row['value']
            else: latic = np.nan
            latic_final = f_or(latic_final,latic)
            
            if row['abbr'] == 'Sodium':
                sodium = row['value']
            else: sodium = np.nan
            sodium_final = f_or(sodium_final,sodium)
            
            if row['abbr'] == 'Potassium':
                potassium = row['value']
            else: potassium = np.nan
            potassium_final = f_or(potassium_final,potassium)
            
            if row['abbr'] == 'Creatinine':
                creatinine = row['value']
            else: creatinine = np.nan
            creatinine_final = f_or(creatinine_final,creatinine)
            
            if row['abbr'] == 'Chloride':
                chloride = row['value']
            else: chloride = np.nan
            chloride_final = f_or(chloride_final,chloride)
            
            if row['abbr'] == 'HCO3':
                HCO3 = row['value']
            else: HCO3 = np.nan
            HCO3_final = f_or(HCO3_final,HCO3)
            
            if row['abbr'] == 'Glucose':
                glucose = row['value']
            else: glucose = np.nan
            glucose_final = f_or(glucose_final,glucose)
            
            if row['abbr'] == 'WBC':
                WBC = row['value']
            else: WBC = np.nan
            WBC_final = f_or(WBC_final,WBC)
            
            if row['abbr'] == 'BUN':
                BUN = row['value']
            else: BUN = np.nan
            BUN_final = f_or(BUN_final,BUN)
            
            if row['abbr'] == 'PTT':
                PTT = row['value']
            else: PTT = np.nan
            PTT_final = f_or(PTT_final,PTT)
            
            if row['abbr'] == 'Platelet':
                platelet = row['value']
            else: platelet = np.nan
            platelet_final = f_or(platelet_final,platelet)

        new_row={'sepsis':sepsis_final,'subject_id':subject_id, 'gender':gender, 'age':age,
                'SBP':NBPs_final,'DBP':NBPd_final,'MAP':NBPm_final,
                 'Temp':temp_final,'HR':hr_final,'RR':rr_final,
                 'BaseExcess':abe_final,'SaO2':SpO2_final,
                 'PH':ph_final, 'Magnesium':magnesium_final,'Calcium':calcium_final,
                 'Lactic':latic_final,'Sodium':sodium_final,'Potassium':potassium_final,
                'Creatinine':creatinine_final,'Chloride':chloride_final,'HCO3':HCO3_final,
                 'Glucose':glucose_final, 'WBC':WBC_final, 'BUN':BUN_final,
                 'PTT': PTT_final,'Platelet':platelet_final,'time':time}
        # print('The new row:',new_row)
        # new_row=pd.Series(new_row)
        df_final = df_final.append(new_row, ignore_index=True)
 
    return df_final, sepsis_indicator

# %% [markdown]
# ## Main function

# %%
# Main

# compared with the adults, age is removed and los is unavailable.
all_columns = ['sepsis','subject_id', 'gender','age',
                'SBP','DBP','MAP','Temp','HR','RR','BaseExcess',
                'SaO2','PH','Magnesium','Lactic',
                'Calcium','Sodium','Potassium','HCO3',
                'Creatinine','Chloride', 'Glucose',
                'WBC','BUN','PTT','Platelet','time']   # the features from events are renamed


for index, row in adults_id.iterrows():
    index += 1
    # if index <=6343: continue
    print('-----------Processing the {}th/20936 adult-----------'.format(index))

    current_id = row['subject_id']

    # to generate the static dataset 
    query_static = f"""
      SELECT *
      FROM `mimic-370210.adults.adults_static`
      WHERE subject_id = {current_id}
    """
    static_info = run_query(query_static)
    static_info.drop_duplicates(keep = 'first', inplace = True)

    # to generate the event dataset
    query_event = f"""
    SELECT *
    FROM `mimic-370210.adults.adults_event`
    WHERE subject_id = {current_id}
    """
    event_info = run_query(query_event)
    event_info.drop_duplicates(keep = 'first', inplace = True)

    # to generate the datasheet in one table
    all_info, sepsis_indicator = arrange_time(static_info,event_info,all_columns)

    if len(all_info) < 10:
      print('Fewer than 10 points -> Discard')
      continue

    print(all_info.subject_id[0], sepsis_indicator)
    if sepsis_indicator:
        all_info.to_csv('/content/drive/MyDrive/MIMIC/Results/adults/sepsis/'+str(all_info.subject_id[0])+'.csv', index = False)
    else:
        all_info.to_csv('/content/drive/MyDrive/MIMIC/Results/adults/non_sepsis/'+str(all_info.subject_id[0])+'.csv', index = False)
# Out:
# -----------Processing the 1th/20936 adult-----------
# 9 True
# -----------Processing the 2th/20936 adult-----------
# 21 True
# -----------Processing the 3th/20936 adult-----------
# 38 True
# -----------Processing the 4th/20936 adult-----------
# 61 True
# -----------Processing the 5th/20936 adult-----------
# 88 True
# -----------Processing the 6th/20936 adult-----------
# 109 True
# -----------Processing the 7th/20936 adult-----------
# 111 True
# -----------Processing the 8th/20936 adult-----------
# 124 True
# -----------Processing the 9th/20936 adult-----------
# 130 True
# -----------Processing the 10th/20936 adult-----------
# 145 True
# -----------Processing the 11th/20936 adult-----------
# 161 True
# -----------Processing the 12th/20936 adult-----------
# 166 True
# -----------Processing the 13th/20936 adult-----------
# 177 True
# -----------Processing the 14th/20936 adult-----------
# 187 True
# -----------Processing the 15th/20936 adult-----------
# 188 True
# -----------Processing the 16th/20936 adult-----------
# 191 True
# -----------Processing the 17th/20936 adult-----------
# 203 True
# -----------Processing the 18th/20936 adult-----------
# 221 True
# -----------Processing the 19th/20936 adult-----------
# 223 True
# -----------Processing the 20th/20936 adult-----------
# 226 True
# -----------Processing the 21th/20936 adult-----------
# 243 True
# -----------Processing the 22th/20936 adult-----------
# 261 True
# -----------Processing the 23th/20936 adult-----------
# 268 True
# -----------Processing the 24th/20936 adult-----------
# 269 True
# -----------Processing the 25th/20936 adult-----------
# 285 True
# -----------Processing the 26th/20936 adult-----------
# 292 True
# -----------Processing the 27th/20936 adult-----------
# 305 True
# -----------Processing the 28th/20936 adult-----------
# 308 True
# -----------Processing the 29th/20936 adult-----------
# 314 True
# -----------Processing the 30th/20936 adult-----------
# 330 True
# -----------Processing the 31th/20936 adult-----------
# 339 True
# -----------Processing the 32th/20936 adult-----------
# 340 True
# -----------Processing the 33th/20936 adult-----------
# 345 True
# -----------Processing the 34th/20936 adult-----------
# 353 True
# -----------Processing the 35th/20936 adult-----------
# 356 True
# -----------Processing the 36th/20936 adult-----------
# 357 True
# -----------Processing the 37th/20936 adult-----------
# 364 True
# -----------Processing the 38th/20936 adult-----------
# 402 True
# -----------Processing the 39th/20936 adult-----------
# 406 True
# -----------Processing the 40th/20936 adult-----------
# 414 True
# -----------Processing the 41th/20936 adult-----------
# 419 True
# 2045 True
# -----------Processing the 201th/20936 adult-----------
# 2049 True
# -----------Processing the 202th/20936 adult-----------
# 2053 True
# -----------Processing the 203th/20936 adult-----------
# 2090 True
# -----------Processing the 204th/20936 adult-----------
# 2092 True
# -----------Processing the 205th/20936 adult-----------
# 2093 True
# -----------Processing the 206th/20936 adult-----------
# 2111 True
# -----------Processing the 207th/20936 adult-----------
# 2136 True
# -----------Processing the 208th/20936 adult-----------
# 2144 True
# -----------Processing the 209th/20936 adult-----------
# 2165 True
# -----------Processing the 210th/20936 adult-----------
# 2177 True
# -----------Processing the 211th/20936 adult-----------
# 2187 True
# -----------Processing the 212th/20936 adult-----------
# 2197 True
# -----------Processing the 213th/20936 adult-----------
# 2207 True
# -----------Processing the 214th/20936 adult-----------
# 2208 True
# -----------Processing the 215th/20936 adult-----------
# 2214 True
# -----------Processing the 216th/20936 adult-----------
# 2220 True
# -----------Processing the 217th/20936 adult-----------
# 2222 True
# -----------Processing the 218th/20936 adult-----------
# 2223 True
# -----------Processing the 219th/20936 adult-----------
# 2225 True
# -----------Processing the 220th/20936 adult-----------
# 2234 True
# -----------Processing the 221th/20936 adult-----------
# 2245 True
# -----------Processing the 222th/20936 adult-----------
# 2263 True
# -----------Processing the 223th/20936 adult-----------
# 2265 True
# -----------Processing the 224th/20936 adult-----------
# 2284 True
# -----------Processing the 225th/20936 adult-----------
# 2310 True
# -----------Processing the 226th/20936 adult-----------
# 2322 True
# -----------Processing the 227th/20936 adult-----------
# 2324 True
# -----------Processing the 228th/20936 adult-----------
# 2330 True
# -----------Processing the 229th/20936 adult-----------
# 2336 True
# -----------Processing the 230th/20936 adult-----------
# 2338 True
# -----------Processing the 231th/20936 adult-----------
# 2341 True
# -----------Processing the 232th/20936 adult-----------
# 2365 True
# -----------Processing the 233th/20936 adult-----------
# 2366 True
# -----------Processing the 234th/20936 adult-----------
# 2369 True
# -----------Processing the 235th/20936 adult-----------
# 2372 True
# -----------Processing the 236th/20936 adult-----------
# 2377 True
# -----------Processing the 237th/20936 adult-----------
# 2394 True
# -----------Processing the 238th/20936 adult-----------
# 2413 True
# -----------Processing the 239th/20936 adult-----------
# 2428 True
# -----------Processing the 240th/20936 adult-----------
# 2456 True
# -----------Processing the 241th/20936 adult-----------
# 2460 True
# -----------Processing the 242th/20936 adult-----------
# 2476 True
# -----------Processing the 243th/20936 adult-----------
# 2478 True
# -----------Processing the 244th/20936 adult-----------
# 2496 True
# -----------Processing the 245th/20936 adult-----------
# 2512 True
# -----------Processing the 246th/20936 adult-----------
# 2513 True
# -----------Processing the 247th/20936 adult-----------
# 2540 True
# -----------Processing the 248th/20936 adult-----------
# 2547 True
# -----------Processing the 249th/20936 adult-----------
# 2553 True
# -----------Processing the 250th/20936 adult-----------
# 2559 True
# -----------Processing the 251th/20936 adult-----------
# 2561 True
# -----------Processing the 252th/20936 adult-----------
# 2570 True
# -----------Processing the 253th/20936 adult-----------
# 2580 True
# -----------Processing the 254th/20936 adult-----------
# 2582 True
# -----------Processing the 255th/20936 adult-----------
# 2587 True
# -----------Processing the 256th/20936 adult-----------
# 2589 True
# -----------Processing the 257th/20936 adult-----------
# 2592 True
# -----------Processing the 258th/20936 adult-----------
# 2593 True
# -----------Processing the 259th/20936 adult-----------
# 2598 True
# -----------Processing the 260th/20936 adult-----------
# 2603 True
# -----------Processing the 261th/20936 adult-----------
# 2617 True
# -----------Processing the 262th/20936 adult-----------
# 2630 True
# -----------Processing the 263th/20936 adult-----------
# 2635 True
# -----------Processing the 264th/20936 adult-----------
# 2638 True
# -----------Processing the 265th/20936 adult-----------
# 2639 True
# -----------Processing the 266th/20936 adult-----------
# 2640 True
# -----------Processing the 267th/20936 adult-----------
# 2648 True
# -----------Processing the 268th/20936 adult-----------
# 2666 True
# -----------Processing the 269th/20936 adult-----------
# 2674 True
# -----------Processing the 270th/20936 adult-----------
# 2690 True
# -----------Processing the 271th/20936 adult-----------
# 2691 True
# -----------Processing the 272th/20936 adult-----------
# 2704 True
# -----------Processing the 273th/20936 adult-----------
# 2712 True
# -----------Processing the 274th/20936 adult-----------
# 2718 True
# -----------Processing the 275th/20936 adult-----------
# 2734 True
# -----------Processing the 276th/20936 adult-----------
# 2743 True
# -----------Processing the 277th/20936 adult-----------
# 2758 True
# -----------Processing the 278th/20936 adult-----------
# 2759 True
# -----------Processing the 279th/20936 adult-----------
# 2775 True
# -----------Processing the 280th/20936 adult-----------
# 2791 True
# -----------Processing the 281th/20936 adult-----------
# 2809 True
# -----------Processing the 282th/20936 adult-----------
# 2819 True
# -----------Processing the 283th/20936 adult-----------
# 2825 True
# -----------Processing the 284th/20936 adult-----------
# 2840 True
# -----------Processing the 285th/20936 adult-----------
# 2871 True
# -----------Processing the 286th/20936 adult-----------
# 2872 True
# -----------Processing the 287th/20936 adult-----------
# 2882 True
# -----------Processing the 288th/20936 adult-----------
# 2897 True
# -----------Processing the 289th/20936 adult-----------
# 2905 True
# -----------Processing the 290th/20936 adult-----------
# 2912 True
# -----------Processing the 291th/20936 adult-----------
# 2919 True
# -----------Processing the 292th/20936 adult-----------
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas_gbq/gbq.py in run_query(self, query, max_results, progress_bar_type, **kwargs)
#     516         try:
# --> 517             query_reply.result()
#     518         except self.http_error as ex:
#
# /usr/local/lib/python3.8/dist-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1498
# -> 1499             do_get_result()
#    1500
#
# /usr/local/lib/python3.8/dist-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     282             )
# --> 283             return retry_target(
#     284                 target,
#
# /usr/local/lib/python3.8/dist-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     189         try:
# --> 190             return target()
#     191
#
# /usr/local/lib/python3.8/dist-packages/google/cloud/bigquery/job/query.py in do_get_result()
#    1488
# -> 1489                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1490
#
# /usr/local/lib/python3.8/dist-packages/google/cloud/bigquery/job/base.py in result(self, retry, timeout)
#     727         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     729
#
# /usr/local/lib/python3.8/dist-packages/google/api_core/future/polling.py in result(self, timeout, retry)
#     136             # Pylint doesn't recognize that this is valid in this case.
# --> 137             raise self._exception
#     138
#
# Forbidden: 403 Quota exceeded: Your project exceeded quota for free query bytes scanned. For more information, see https://cloud.google.com/bigquery/docs/troubleshoot-quotas
#
# Location: US
# Job ID: e7dfe22f-bfe2-49ab-b931-27d8edd2fa9e
#
#
# During handling of the above exception, another exception occurred:
#
# GenericGBQException                       Traceback (most recent call last)
# <ipython-input-14-7b62b6ed2cbd> in <module>
#      32     WHERE subject_id = {current_id}
#      33     """
# ---> 34     event_info = run_query(query_event)
#      35     event_info.drop_duplicates(keep = 'first', inplace = True)
#      36
#
# <ipython-input-7-cdb08b1b0358> in run_query(query, project_id)
#       5 # Read data from BigQuery into pandas dataframes.
#       6 def run_query(query, project_id=project_id):
# ----> 7   return pd.io.gbq.read_gbq(
#       8       query,
#       9       project_id=project_id,
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/gbq.py in read_gbq(query, project_id, index_col, col_order, reauth, auth_local_webserver, dialect, location, configuration, credentials, use_bqstorage_api, max_results, progress_bar_type)
#     181     # END: new kwargs
#     182
# --> 183     return pandas_gbq.read_gbq(
#     184         query,
#     185         project_id=project_id,
#
# /usr/local/lib/python3.8/dist-packages/pandas_gbq/gbq.py in read_gbq(query_or_table, project_id, index_col, col_order, reauth, auth_local_webserver, dialect, location, configuration, credentials, use_bqstorage_api, max_results, verbose, private_key, progress_bar_type, dtypes)
#     919
#     920     if _is_query(query_or_table):
# --> 921         final_df = connector.run_query(
#     922             query_or_table,
#     923             configuration=configuration,
#
# /usr/local/lib/python3.8/dist-packages/pandas_gbq/gbq.py in run_query(self, query, max_results, progress_bar_type, **kwargs)
#     517             query_reply.result()
#     518         except self.http_error as ex:
# --> 519             self.process_http_error(ex)
#     520
#     521         # Avoid attempting to download results from DML queries, which have no
#
# /usr/local/lib/python3.8/dist-packages/pandas_gbq/gbq.py in process_http_error(ex)
#     384             raise QueryTimeout("Reason: {0}".format(ex))
#     385
# --> 386         raise GenericGBQException("Reason: {0}".format(ex))
#     387
#     388     def download_table(
#
# GenericGBQException: Reason: 403 Quota exceeded: Your project exceeded quota for free query bytes scanned. For more information, see https://cloud.google.com/bigquery/docs/troubleshoot-quotas
#
# Location: US
# Job ID: e7dfe22f-bfe2-49ab-b931-27d8edd2fa9e
