# %% [markdown]
# # Post processing the data after generation
# ## Import libraries and mount Google drive

# %%
import os
from datetime import datetime
from datetime import timedelta
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Read data path

# %%
patients_sepsis = '/content/drive/MyDrive/MIMIC/Results/adults/sepsis/' #change path here 
sepsis_dir = os.listdir(patients_sepsis)
patients_non_sepsis = '/content/drive/MyDrive/MIMIC/Results/adults/non_sepsis/' #change path here
non_sepsis_dir = os.listdir(patients_non_sepsis)

# %%
#test
a_neonate = '/content/drive/MyDrive/MIMIC/Results/neonates/sepsis/10055.csv'
a_neonate = pd.read_csv(a_neonate)
a_neonate

# %%
#test
an_adult = '/content/drive/MyDrive/MIMIC/Results/adults/sepsis/1000.csv'
an_adult = pd.read_csv(an_adult)
an_adult
# Out:
#       sepsis  subject_id gender   age  SBP  DBP  MAP       Temp    HR    RR  \
# 0      False        1000      M  70.0  NaN  NaN  NaN  97.500000  85.0  21.0
# 1      False        1000      M  70.0  NaN  NaN  NaN  97.399943  81.0  16.0
# 2      False        1000      M  70.0  NaN  NaN  NaN  97.300003  89.0  21.0
# 3      False        1000      M  70.0  NaN  NaN  NaN  96.400043  86.0  16.0
# 4      False        1000      M  70.0  NaN  NaN  NaN        NaN  82.0  20.0
# ...      ...         ...    ...   ...  ...  ...  ...        ...   ...   ...
# 1064   False        1000      M  70.0  NaN  NaN  NaN        NaN  59.0  20.0
# 1065   False        1000      M  70.0  NaN  NaN  NaN        NaN  60.0  24.0
# 1066   False        1000      M  70.0  NaN  NaN  NaN  96.800000  70.0  18.0
# 1067   False        1000      M  70.0  NaN  NaN  NaN        NaN  78.0  24.0
# 1068   False        1000      M  70.0  NaN  NaN  NaN        NaN  80.0  26.0
#
#       ...  Potassium  HCO3  Creatinine  Chloride  Glucose  WBC  BUN  PTT  \
# 0     ...        NaN   NaN         NaN       NaN      NaN  NaN  NaN  NaN
# 1     ...        NaN   NaN         NaN       NaN      NaN  NaN  NaN  NaN
# 2     ...        NaN   NaN         NaN       NaN      NaN  NaN  NaN  NaN
# 3     ...        NaN   NaN         NaN       NaN      NaN  NaN  NaN  NaN
# 4     ...        NaN   NaN         NaN       NaN      NaN  NaN  NaN  NaN
# ...   ...        ...   ...         ...       ...      ...  ...  ...  ...
# 1064  ...        NaN   NaN         NaN       NaN      NaN  NaN  NaN  NaN
# 1065  ...        NaN   NaN         NaN       NaN      NaN  NaN  NaN  NaN
# 1066  ...        NaN   NaN         NaN       NaN      NaN  NaN  NaN  NaN
# 1067  ...        NaN   NaN         NaN       NaN      NaN  NaN  NaN  NaN
# 1068  ...        NaN   NaN         NaN       NaN      NaN  NaN  NaN  NaN
#
#       Platelet                 time
# 0          NaN  2144-01-20 13:15:00
# 1          NaN  2144-01-20 14:00:00
# 2          NaN  2144-01-20 14:30:00
# 3          NaN  2144-01-20 15:00:00
# 4          NaN  2144-01-20 15:15:00
# ...        ...                  ...
# 1064       NaN  2144-02-25 16:45:00
# 1065       NaN  2144-02-25 16:50:00
# 1066       NaN  2144-02-25 17:00:00
# 1067       NaN  2144-02-25 17:15:00
# 1068       NaN  2144-02-25 18:00:00
#
# [1069 rows x 27 columns]

# %% [markdown]
# ## Help functions

# %%
# this function round the time to the nearest hour
# used for new_start > start, then round the new_start
def rounder_nearest(t):
    if t.minute >= 30:
        return t.replace(second=0, microsecond=0, minute=0, hour=t.hour+1)
    else:
        return t.replace(second=0, microsecond=0, minute=0)

# this function round the time to the current hour
# used for new_start <= start, then round the start
def rounder_forward(t):
      return t.replace(second=0, microsecond=0, minute=0)

# %%
def merge_values(value_1, value_2):
  if type(value_1) == bool:
    return value_1 or value_2
  elif type(value_1) ==str:
    return value_1  # always keep the time point of the hour
  else:
    if pd.isnull(value_1) and pd.isnull(value_2):
      return np.nan
    elif pd.isnull(value_1):
      return value_2
    elif pd.isnull(value_2):
      return value_1
    else:
      return value_2  #retun the later value if both are not nan

# %%
# columns_info = a_neonate.columns
columns_info = an_adult.columns

def merge_rows(row_1, row_2):
  for column in columns_info:
    row_1[column] = merge_values(row_1[column], row_2[column])
  return row_1

# %% [markdown]
# ## This block processes the neonates/adults with sepsis
#
#
# 1.   discard when the los before sepsis onset is < 6 hours
# 2.   discard when there is no recording within the 6 hours before sepsis onset
# 3.   maximun recodring hours will be limited to 100 hours
# 3.   missingh hours will be compensated by empty row with only static info

# %%
step = 0  # for indicating processing step
type_1 = 0  # neonates/adults with less than 6 hours los before sepsis onset
type_2 = 0  # neonates/adults with no recordings within the 6 hours before sepsis onset
type_3 = 0  # neonates/adults with successful generation of table

for csv_file in sepsis_dir:
  patient = pd.read_csv(patients_sepsis+csv_file)

  step +=1
  print("processing {}/{}, subject_id = {}".format(step,len(sepsis_dir),patient.subject_id[0]))

  new_df = pd.DataFrame(columns = patient.columns)

  # empty_row = {'subject_id':patient.subject_id[0], 'gender':patient.gender[0],
  #              'sepsis':False, 'SBP':np.nan, 'DBP':np.nan, 'MAP':np.nan, 'Temp':np.nan, 'HR':np.nan,
  #              'RR':np.nan, 'BaseExcess':np.nan, 'FiO2':np.nan, 'SaO2':np.nan, 'PCO2':np.nan, 
  #              'PH':np.nan, 'Calcium':np.nan, 'Sodium':np.nan, 'Potassium':np.nan, 'Creatinine':np.nan, 
  #              'Chloride':np.nan, 'Glucose':np.nan, 'WBC':np.nan, 'BUN':np.nan, 'PTT':np.nan,
  #              'Platelet':np.nan, 'time':np.nan}  # for neonates

  empty_row = {'subject_id':patient.subject_id[0], 'gender':patient.gender[0], 'age':patient.age[0],
               'sepsis':False, 'SBP':np.nan, 'DBP':np.nan, 'MAP':np.nan, 'Temp':np.nan, 'HR':np.nan,
               'RR':np.nan, 'BaseExcess':np.nan, 'SaO2':np.nan, 'PH':np.nan, 'Magnesium':np.nan,
               'Lactic':np.nan, 'Calcium':np.nan, 'Sodium':np.nan, 'Potassium':np.nan, 'HCO3':np.nan,
               'Creatinine':np.nan, 'Chloride':np.nan, 'Glucose':np.nan, 'WBC':np.nan, 'BUN':np.nan, 
               'PTT':np.nan, 'Platelet':np.nan, 'time':np.nan}  # for adults

  time_points = len(patient)
  start_time = patient.time[0]
  end_time = patient.time[time_points-1]
  onset_index = patient.index[patient['sepsis']][0]
  onset_time = patient.time[onset_index]
  FMT = '%Y-%m-%d %H:%M:%S'
  los = ( datetime.strptime( end_time, FMT) - datetime.strptime(start_time, FMT) ).total_seconds()/3600 #in hours
  los_before_sepsis = ( datetime.strptime(onset_time, FMT) - datetime.strptime(start_time, FMT) ).total_seconds()/3600  #in hours
  if los_before_sepsis < 6:
    print("Patient {} has less then 6 hours recordings, discard from the final dataset".format(patient.subject_id[0]))
    type_1 += 1
    continue
  last_record_before_sepsis_time = patient.time[onset_index-1]
  last_record_before_sepsis = ( datetime.strptime(onset_time, FMT) - datetime.strptime(last_record_before_sepsis_time, FMT) ).total_seconds()/3600  #in hours
  if last_record_before_sepsis >= 6:
    print("Patient {} has no recordings within the 6 hours before onset, discard from the final dataset".format(patient.subject_id[0]))
    type_2 += 1
    continue

  type_3 += 1

  # determine the start time
  start = datetime.strptime(start_time,FMT)
  onset = datetime.strptime(onset_time,FMT)
  delta = timedelta(hours = 100)  #maximun 100 hours before onset for each neonate
  new_start = onset - delta
  # get the starting index and starting time
  if new_start < start: 
    new_start = rounder_forward(start)
    new_start_index = 0
  else:
    new_start = rounder_forward(new_start)
    for index, row in patient.iterrows():
      current  = datetime.strptime(row.time, FMT)
      if current < new_start: 
        continue
      else: 
        new_start_index = index
        break

  time_diff = (onset - new_start).total_seconds()/3600  # in hours
  for i in range(int(time_diff)+1):
    new_row = pd.Series(empty_row)
    new_row['time'] = new_start
    for index in range(new_start_index, onset_index+1):
      if datetime.strptime( patient.iloc[index].time, FMT) >= new_start and datetime.strptime( patient.iloc[index].time, FMT) < new_start + timedelta(hours = 1):
        new_row = merge_rows(new_row,patient.iloc[index])
    new_df = new_df.append(new_row, ignore_index = True)
    new_start = new_start + timedelta(hours = 1)

  new_df.to_csv('/content/drive/MyDrive/MIMIC/Results/adults/processed_sepsis/'+ str(patient.subject_id[0]) + '.csv', index = False)
# Out:
# Streaming output truncated to the last 5000 lines.
# processing 1540/4709, subject_id = 28278
# Patient 28278 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1541/4709, subject_id = 28292
# Patient 28292 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1542/4709, subject_id = 28304
# Patient 28304 has less then 6 hours recordings, discard from the final dataset
# processing 1543/4709, subject_id = 28309
# Patient 28309 has less then 6 hours recordings, discard from the final dataset
# processing 1544/4709, subject_id = 28315
# processing 1545/4709, subject_id = 28325
# Patient 28325 has less then 6 hours recordings, discard from the final dataset
# processing 1546/4709, subject_id = 28329
# Patient 28329 has less then 6 hours recordings, discard from the final dataset
# processing 1547/4709, subject_id = 28345
# Patient 28345 has less then 6 hours recordings, discard from the final dataset
# processing 1548/4709, subject_id = 28356
# processing 1549/4709, subject_id = 28361
# Patient 28361 has less then 6 hours recordings, discard from the final dataset
# processing 1550/4709, subject_id = 28409
# Patient 28409 has less then 6 hours recordings, discard from the final dataset
# processing 1551/4709, subject_id = 28419
# processing 1552/4709, subject_id = 28426
# Patient 28426 has less then 6 hours recordings, discard from the final dataset
# processing 1553/4709, subject_id = 28453
# Patient 28453 has less then 6 hours recordings, discard from the final dataset
# processing 1554/4709, subject_id = 28457
# Patient 28457 has less then 6 hours recordings, discard from the final dataset
# processing 1555/4709, subject_id = 28458
# Patient 28458 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1556/4709, subject_id = 28477
# Patient 28477 has less then 6 hours recordings, discard from the final dataset
# processing 1557/4709, subject_id = 28505
# processing 1558/4709, subject_id = 28508
# Patient 28508 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1559/4709, subject_id = 28515
# processing 1560/4709, subject_id = 28599
# Patient 28599 has less then 6 hours recordings, discard from the final dataset
# processing 1561/4709, subject_id = 28613
# processing 1562/4709, subject_id = 28621
# Patient 28621 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1563/4709, subject_id = 28628
# processing 1564/4709, subject_id = 28629
# Patient 28629 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1565/4709, subject_id = 28668
# Patient 28668 has less then 6 hours recordings, discard from the final dataset
# processing 1566/4709, subject_id = 28669
# processing 1567/4709, subject_id = 28698
# Patient 28698 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1568/4709, subject_id = 28702
# Patient 28702 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1569/4709, subject_id = 28707
# Patient 28707 has less then 6 hours recordings, discard from the final dataset
# processing 1570/4709, subject_id = 28749
# Patient 28749 has less then 6 hours recordings, discard from the final dataset
# processing 1571/4709, subject_id = 28750
# Patient 28750 has less then 6 hours recordings, discard from the final dataset
# processing 1572/4709, subject_id = 28752
# processing 1573/4709, subject_id = 28754
# Patient 28754 has less then 6 hours recordings, discard from the final dataset
# processing 1574/4709, subject_id = 28765
# Patient 28765 has less then 6 hours recordings, discard from the final dataset
# processing 1575/4709, subject_id = 28775
# Patient 28775 has less then 6 hours recordings, discard from the final dataset
# processing 1576/4709, subject_id = 28779
# Patient 28779 has less then 6 hours recordings, discard from the final dataset
# processing 1577/4709, subject_id = 28794
# processing 1578/4709, subject_id = 28801
# processing 1579/4709, subject_id = 28805
# Patient 28805 has less then 6 hours recordings, discard from the final dataset
# processing 1580/4709, subject_id = 28807
# Patient 28807 has less then 6 hours recordings, discard from the final dataset
# processing 1581/4709, subject_id = 28814
# Patient 28814 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1582/4709, subject_id = 28828
# Patient 28828 has less then 6 hours recordings, discard from the final dataset
# processing 1583/4709, subject_id = 28829
# Patient 28829 has less then 6 hours recordings, discard from the final dataset
# processing 1584/4709, subject_id = 28868
# processing 1585/4709, subject_id = 28889
# Patient 28889 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1586/4709, subject_id = 28898
# processing 1587/4709, subject_id = 28933
# Patient 28933 has less then 6 hours recordings, discard from the final dataset
# processing 1588/4709, subject_id = 28941
# Patient 28941 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1589/4709, subject_id = 28946
# processing 1590/4709, subject_id = 28960
# Patient 28960 has less then 6 hours recordings, discard from the final dataset
# processing 1591/4709, subject_id = 28964
# processing 1592/4709, subject_id = 28972
# Patient 28972 has less then 6 hours recordings, discard from the final dataset
# processing 1593/4709, subject_id = 29027
# Patient 29027 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1594/4709, subject_id = 29041
# Patient 29041 has less then 6 hours recordings, discard from the final dataset
# processing 1595/4709, subject_id = 29070
# Patient 29070 has less then 6 hours recordings, discard from the final dataset
# processing 1596/4709, subject_id = 29075
# Patient 29075 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1597/4709, subject_id = 29110
# Patient 29110 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1598/4709, subject_id = 29115
# processing 1599/4709, subject_id = 29129
# Patient 29129 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1600/4709, subject_id = 29135
# processing 1601/4709, subject_id = 29142
# processing 1602/4709, subject_id = 29198
# Patient 29198 has less then 6 hours recordings, discard from the final dataset
# processing 1603/4709, subject_id = 29209
# Patient 29209 has less then 6 hours recordings, discard from the final dataset
# processing 1604/4709, subject_id = 29210
# Patient 29210 has less then 6 hours recordings, discard from the final dataset
# processing 1605/4709, subject_id = 29263
# Patient 29263 has less then 6 hours recordings, discard from the final dataset
# processing 1606/4709, subject_id = 29268
# Patient 29268 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1607/4709, subject_id = 29279
# processing 1608/4709, subject_id = 29284
# Patient 29284 has less then 6 hours recordings, discard from the final dataset
# processing 1609/4709, subject_id = 29290
# Patient 29290 has less then 6 hours recordings, discard from the final dataset
# processing 1610/4709, subject_id = 29299
# processing 1611/4709, subject_id = 29304
# processing 1612/4709, subject_id = 29338
# Patient 29338 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1613/4709, subject_id = 29350
# Patient 29350 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1614/4709, subject_id = 29360
# Patient 29360 has less then 6 hours recordings, discard from the final dataset
# processing 1615/4709, subject_id = 29361
# Patient 29361 has less then 6 hours recordings, discard from the final dataset
# processing 1616/4709, subject_id = 29375
# Patient 29375 has less then 6 hours recordings, discard from the final dataset
# processing 1617/4709, subject_id = 29382
# Patient 29382 has less then 6 hours recordings, discard from the final dataset
# processing 1618/4709, subject_id = 29390
# processing 1619/4709, subject_id = 29391
# Patient 29391 has less then 6 hours recordings, discard from the final dataset
# processing 1620/4709, subject_id = 29395
# Patient 29395 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1621/4709, subject_id = 29398
# Patient 29398 has less then 6 hours recordings, discard from the final dataset
# processing 1622/4709, subject_id = 29426
# Patient 29426 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1623/4709, subject_id = 29436
# Patient 29436 has less then 6 hours recordings, discard from the final dataset
# processing 1624/4709, subject_id = 29467
# Patient 29467 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1625/4709, subject_id = 29483
# processing 1626/4709, subject_id = 29493
# Patient 29493 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1627/4709, subject_id = 29495
# Patient 29495 has less then 6 hours recordings, discard from the final dataset
# processing 1628/4709, subject_id = 29502
# Patient 29502 has less then 6 hours recordings, discard from the final dataset
# processing 1629/4709, subject_id = 29504
# Patient 29504 has less then 6 hours recordings, discard from the final dataset
# processing 1630/4709, subject_id = 29517
# processing 1631/4709, subject_id = 29528
# Patient 29528 has less then 6 hours recordings, discard from the final dataset
# processing 1632/4709, subject_id = 29542
# processing 1633/4709, subject_id = 29556
# Patient 29556 has less then 6 hours recordings, discard from the final dataset
# processing 1634/4709, subject_id = 29558
# processing 1635/4709, subject_id = 29559
# Patient 29559 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1636/4709, subject_id = 29571
# Patient 29571 has less then 6 hours recordings, discard from the final dataset
# processing 1637/4709, subject_id = 29574
# processing 1638/4709, subject_id = 29589
# processing 1639/4709, subject_id = 29601
# processing 1640/4709, subject_id = 29603
# processing 1641/4709, subject_id = 29626
# processing 1642/4709, subject_id = 29636
# Patient 29636 has less then 6 hours recordings, discard from the final dataset
# processing 1643/4709, subject_id = 29647
# Patient 29647 has less then 6 hours recordings, discard from the final dataset
# processing 1644/4709, subject_id = 29657
# processing 1645/4709, subject_id = 29660
# processing 1646/4709, subject_id = 29664
# processing 1647/4709, subject_id = 29668
# processing 1648/4709, subject_id = 29692
# Patient 29692 has less then 6 hours recordings, discard from the final dataset
# processing 1649/4709, subject_id = 29755
# Patient 29755 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1650/4709, subject_id = 29769
# processing 1651/4709, subject_id = 29812
# Patient 29812 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1652/4709, subject_id = 29823
# Patient 29823 has less then 6 hours recordings, discard from the final dataset
# processing 1653/4709, subject_id = 29841
# Patient 29841 has less then 6 hours recordings, discard from the final dataset
# processing 1654/4709, subject_id = 29845
# processing 1655/4709, subject_id = 29860
# Patient 29860 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1656/4709, subject_id = 29861
# processing 1657/4709, subject_id = 29893
# processing 1658/4709, subject_id = 29946
# Patient 29946 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1659/4709, subject_id = 29968
# Patient 29968 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1660/4709, subject_id = 29972
# Patient 29972 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1661/4709, subject_id = 30015
# Patient 30015 has less then 6 hours recordings, discard from the final dataset
# processing 1662/4709, subject_id = 30026
# Patient 30026 has less then 6 hours recordings, discard from the final dataset
# processing 1663/4709, subject_id = 30047
# processing 1664/4709, subject_id = 30054
# Patient 30054 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1665/4709, subject_id = 30070
# Patient 30070 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1666/4709, subject_id = 30075
# processing 1667/4709, subject_id = 30084
# processing 1668/4709, subject_id = 30094
# Patient 30094 has less then 6 hours recordings, discard from the final dataset
# processing 1669/4709, subject_id = 30101
# Patient 30101 has less then 6 hours recordings, discard from the final dataset
# processing 1670/4709, subject_id = 30110
# Patient 30110 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1671/4709, subject_id = 30111
# Patient 30111 has less then 6 hours recordings, discard from the final dataset
# processing 1672/4709, subject_id = 30139
# Patient 30139 has less then 6 hours recordings, discard from the final dataset
# processing 1673/4709, subject_id = 30142
# Patient 30142 has less then 6 hours recordings, discard from the final dataset
# processing 1674/4709, subject_id = 30176
# processing 1675/4709, subject_id = 30184
# Patient 30184 has less then 6 hours recordings, discard from the final dataset
# processing 1676/4709, subject_id = 30198
# Patient 30198 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1677/4709, subject_id = 30208
# processing 1678/4709, subject_id = 30227
# Patient 30227 has less then 6 hours recordings, discard from the final dataset
# processing 1679/4709, subject_id = 30256
# Patient 30256 has less then 6 hours recordings, discard from the final dataset
# processing 1680/4709, subject_id = 30262
# Patient 30262 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1681/4709, subject_id = 30273
# Patient 30273 has less then 6 hours recordings, discard from the final dataset
# processing 1682/4709, subject_id = 30275
# Patient 30275 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1683/4709, subject_id = 30298
# Patient 30298 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1684/4709, subject_id = 30299
# Patient 30299 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1685/4709, subject_id = 30300
# Patient 30300 has less then 6 hours recordings, discard from the final dataset
# processing 1686/4709, subject_id = 30301
# processing 1687/4709, subject_id = 30341
# Patient 30341 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1688/4709, subject_id = 30352
# Patient 30352 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1689/4709, subject_id = 30359
# processing 1690/4709, subject_id = 30362
# processing 1691/4709, subject_id = 30395
# Patient 30395 has less then 6 hours recordings, discard from the final dataset
# processing 1692/4709, subject_id = 30420
# Patient 30420 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1693/4709, subject_id = 30460
# Patient 30460 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1694/4709, subject_id = 30461
# Patient 30461 has less then 6 hours recordings, discard from the final dataset
# processing 1695/4709, subject_id = 30477
# Patient 30477 has less then 6 hours recordings, discard from the final dataset
# processing 1696/4709, subject_id = 30504
# processing 1697/4709, subject_id = 30550
# Patient 30550 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1698/4709, subject_id = 30575
# Patient 30575 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1699/4709, subject_id = 30579
# processing 1700/4709, subject_id = 30588
# processing 1701/4709, subject_id = 30595
# Patient 30595 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1702/4709, subject_id = 30599
# Patient 30599 has less then 6 hours recordings, discard from the final dataset
# processing 1703/4709, subject_id = 30603
# processing 1704/4709, subject_id = 30614
# Patient 30614 has less then 6 hours recordings, discard from the final dataset
# processing 1705/4709, subject_id = 30636
# Patient 30636 has less then 6 hours recordings, discard from the final dataset
# processing 1706/4709, subject_id = 30637
# Patient 30637 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1707/4709, subject_id = 30638
# Patient 30638 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1708/4709, subject_id = 30646
# Patient 30646 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1709/4709, subject_id = 30650
# Patient 30650 has less then 6 hours recordings, discard from the final dataset
# processing 1710/4709, subject_id = 30659
# processing 1711/4709, subject_id = 30667
# Patient 30667 has less then 6 hours recordings, discard from the final dataset
# processing 1712/4709, subject_id = 30668
# Patient 30668 has less then 6 hours recordings, discard from the final dataset
# processing 1713/4709, subject_id = 30678
# processing 1714/4709, subject_id = 30682
# Patient 30682 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1715/4709, subject_id = 30695
# processing 1716/4709, subject_id = 30696
# processing 1717/4709, subject_id = 30707
# Patient 30707 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1718/4709, subject_id = 30731
# processing 1719/4709, subject_id = 30755
# Patient 30755 has less then 6 hours recordings, discard from the final dataset
# processing 1720/4709, subject_id = 30795
# processing 1721/4709, subject_id = 30819
# Patient 30819 has less then 6 hours recordings, discard from the final dataset
# processing 1722/4709, subject_id = 30845
# processing 1723/4709, subject_id = 30915
# Patient 30915 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1724/4709, subject_id = 30924
# processing 1725/4709, subject_id = 30954
# Patient 30954 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1726/4709, subject_id = 30962
# Patient 30962 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1727/4709, subject_id = 30969
# processing 1728/4709, subject_id = 31003
# Patient 31003 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1729/4709, subject_id = 31030
# processing 1730/4709, subject_id = 31038
# Patient 31038 has less then 6 hours recordings, discard from the final dataset
# processing 1731/4709, subject_id = 31044
# Patient 31044 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1732/4709, subject_id = 31051
# Patient 31051 has less then 6 hours recordings, discard from the final dataset
# processing 1733/4709, subject_id = 31083
# processing 1734/4709, subject_id = 31141
# processing 1735/4709, subject_id = 31153
# Patient 31153 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1736/4709, subject_id = 31165
# processing 1737/4709, subject_id = 31198
# Patient 31198 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1738/4709, subject_id = 31261
# processing 1739/4709, subject_id = 31284
# Patient 31284 has less then 6 hours recordings, discard from the final dataset
# processing 1740/4709, subject_id = 31289
# Patient 31289 has less then 6 hours recordings, discard from the final dataset
# processing 1741/4709, subject_id = 31290
# processing 1742/4709, subject_id = 31320
# Patient 31320 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1743/4709, subject_id = 31361
# Patient 31361 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1744/4709, subject_id = 31383
# Patient 31383 has less then 6 hours recordings, discard from the final dataset
# processing 1745/4709, subject_id = 31385
# processing 1746/4709, subject_id = 31441
# Patient 31441 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1747/4709, subject_id = 31469
# Patient 31469 has less then 6 hours recordings, discard from the final dataset
# processing 1748/4709, subject_id = 31489
# processing 1749/4709, subject_id = 31493
# processing 1750/4709, subject_id = 31502
# Patient 31502 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1751/4709, subject_id = 31514
# Patient 31514 has less then 6 hours recordings, discard from the final dataset
# processing 1752/4709, subject_id = 31520
# processing 1753/4709, subject_id = 31528
# Patient 31528 has less then 6 hours recordings, discard from the final dataset
# processing 1754/4709, subject_id = 31558
# processing 1755/4709, subject_id = 31583
# Patient 31583 has less then 6 hours recordings, discard from the final dataset
# processing 1756/4709, subject_id = 31585
# Patient 31585 has less then 6 hours recordings, discard from the final dataset
# processing 1757/4709, subject_id = 31636
# Patient 31636 has less then 6 hours recordings, discard from the final dataset
# processing 1758/4709, subject_id = 31651
# Patient 31651 has less then 6 hours recordings, discard from the final dataset
# processing 1759/4709, subject_id = 31662
# Patient 31662 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1760/4709, subject_id = 31664
# Patient 31664 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1761/4709, subject_id = 31697
# Patient 31697 has less then 6 hours recordings, discard from the final dataset
# processing 1762/4709, subject_id = 31717
# processing 1763/4709, subject_id = 31813
# processing 1764/4709, subject_id = 31820
# Patient 31820 has less then 6 hours recordings, discard from the final dataset
# processing 1765/4709, subject_id = 31842
# Patient 31842 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1766/4709, subject_id = 31856
# processing 1767/4709, subject_id = 31880
# Patient 31880 has less then 6 hours recordings, discard from the final dataset
# processing 1768/4709, subject_id = 31904
# Patient 31904 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1769/4709, subject_id = 31935
# processing 1770/4709, subject_id = 31936
# Patient 31936 has less then 6 hours recordings, discard from the final dataset
# processing 1771/4709, subject_id = 31942
# processing 1772/4709, subject_id = 31951
# Patient 31951 has less then 6 hours recordings, discard from the final dataset
# processing 1773/4709, subject_id = 31964
# Patient 31964 has less then 6 hours recordings, discard from the final dataset
# processing 1774/4709, subject_id = 31969
# Patient 31969 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1775/4709, subject_id = 31974
# Patient 31974 has less then 6 hours recordings, discard from the final dataset
# processing 1776/4709, subject_id = 32047
# processing 1777/4709, subject_id = 32054
# Patient 32054 has less then 6 hours recordings, discard from the final dataset
# processing 1778/4709, subject_id = 32058
# Patient 32058 has less then 6 hours recordings, discard from the final dataset
# processing 1779/4709, subject_id = 32059
# Patient 32059 has less then 6 hours recordings, discard from the final dataset
# processing 1780/4709, subject_id = 32135
# Patient 32135 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1781/4709, subject_id = 32193
# processing 1782/4709, subject_id = 32205
# processing 1783/4709, subject_id = 32210
# Patient 32210 has less then 6 hours recordings, discard from the final dataset
# processing 1784/4709, subject_id = 32216
# processing 1785/4709, subject_id = 32228
# processing 1786/4709, subject_id = 32252
# Patient 32252 has less then 6 hours recordings, discard from the final dataset
# processing 1787/4709, subject_id = 32253
# processing 1788/4709, subject_id = 32261
# processing 1789/4709, subject_id = 32287
# processing 1790/4709, subject_id = 32308
# processing 1791/4709, subject_id = 32351
# processing 1792/4709, subject_id = 32368
# processing 1793/4709, subject_id = 32393
# Patient 32393 has less then 6 hours recordings, discard from the final dataset
# processing 1794/4709, subject_id = 32410
# Patient 32410 has less then 6 hours recordings, discard from the final dataset
# processing 1795/4709, subject_id = 32412
# Patient 32412 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1796/4709, subject_id = 32414
# processing 1797/4709, subject_id = 32421
# processing 1798/4709, subject_id = 32425
# Patient 32425 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1799/4709, subject_id = 32438
# Patient 32438 has less then 6 hours recordings, discard from the final dataset
# processing 1800/4709, subject_id = 32440
# Patient 32440 has less then 6 hours recordings, discard from the final dataset
# processing 1801/4709, subject_id = 32447
# processing 1802/4709, subject_id = 32457
# Patient 32457 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1803/4709, subject_id = 32476
# processing 1804/4709, subject_id = 32489
# Patient 32489 has less then 6 hours recordings, discard from the final dataset
# processing 1805/4709, subject_id = 32496
# processing 1806/4709, subject_id = 32500
# Patient 32500 has less then 6 hours recordings, discard from the final dataset
# processing 1807/4709, subject_id = 32502
# Patient 32502 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1808/4709, subject_id = 32504
# Patient 32504 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1809/4709, subject_id = 32529
# processing 1810/4709, subject_id = 32568
# processing 1811/4709, subject_id = 32605
# processing 1812/4709, subject_id = 32624
# Patient 32624 has less then 6 hours recordings, discard from the final dataset
# processing 1813/4709, subject_id = 32627
# processing 1814/4709, subject_id = 32645
# processing 1815/4709, subject_id = 32650
# Patient 32650 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1816/4709, subject_id = 32661
# processing 1817/4709, subject_id = 32664
# processing 1818/4709, subject_id = 32683
# processing 1819/4709, subject_id = 32697
# Patient 32697 has less then 6 hours recordings, discard from the final dataset
# processing 1820/4709, subject_id = 32713
# Patient 32713 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1821/4709, subject_id = 32714
# Patient 32714 has less then 6 hours recordings, discard from the final dataset
# processing 1822/4709, subject_id = 32725
# processing 1823/4709, subject_id = 32754
# Patient 32754 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1824/4709, subject_id = 40000
# Patient 40000 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1825/4709, subject_id = 40004
# processing 1826/4709, subject_id = 40013
# processing 1827/4709, subject_id = 40057
# processing 1828/4709, subject_id = 40085
# processing 1829/4709, subject_id = 40287
# processing 1830/4709, subject_id = 40310
# processing 1831/4709, subject_id = 40461
# Patient 40461 has less then 6 hours recordings, discard from the final dataset
# processing 1832/4709, subject_id = 40474
# Patient 40474 has less then 6 hours recordings, discard from the final dataset
# processing 1833/4709, subject_id = 40573
# Patient 40573 has less then 6 hours recordings, discard from the final dataset
# processing 1834/4709, subject_id = 40622
# Patient 40622 has less then 6 hours recordings, discard from the final dataset
# processing 1835/4709, subject_id = 40624
# processing 1836/4709, subject_id = 40655
# Patient 40655 has less then 6 hours recordings, discard from the final dataset
# processing 1837/4709, subject_id = 40724
# processing 1838/4709, subject_id = 40822
# Patient 40822 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1839/4709, subject_id = 40833
# Patient 40833 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1840/4709, subject_id = 40850
# Patient 40850 has less then 6 hours recordings, discard from the final dataset
# processing 1841/4709, subject_id = 40904
# Patient 40904 has less then 6 hours recordings, discard from the final dataset
# processing 1842/4709, subject_id = 40911
# Patient 40911 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1843/4709, subject_id = 40934
# Patient 40934 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1844/4709, subject_id = 41014
# Patient 41014 has less then 6 hours recordings, discard from the final dataset
# processing 1845/4709, subject_id = 41022
# Patient 41022 has less then 6 hours recordings, discard from the final dataset
# processing 1846/4709, subject_id = 41024
# Patient 41024 has less then 6 hours recordings, discard from the final dataset
# processing 1847/4709, subject_id = 41078
# Patient 41078 has less then 6 hours recordings, discard from the final dataset
# processing 1848/4709, subject_id = 41252
# Patient 41252 has less then 6 hours recordings, discard from the final dataset
# processing 1849/4709, subject_id = 41287
# processing 1850/4709, subject_id = 41361
# Patient 41361 has less then 6 hours recordings, discard from the final dataset
# processing 1851/4709, subject_id = 41384
# Patient 41384 has less then 6 hours recordings, discard from the final dataset
# processing 1852/4709, subject_id = 41403
# processing 1853/4709, subject_id = 41438
# processing 1854/4709, subject_id = 41439
# Patient 41439 has less then 6 hours recordings, discard from the final dataset
# processing 1855/4709, subject_id = 41562
# Patient 41562 has less then 6 hours recordings, discard from the final dataset
# processing 1856/4709, subject_id = 41607
# Patient 41607 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1857/4709, subject_id = 41670
# Patient 41670 has less then 6 hours recordings, discard from the final dataset
# processing 1858/4709, subject_id = 41678
# Patient 41678 has less then 6 hours recordings, discard from the final dataset
# processing 1859/4709, subject_id = 41719
# Patient 41719 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1860/4709, subject_id = 41783
# Patient 41783 has less then 6 hours recordings, discard from the final dataset
# processing 1861/4709, subject_id = 41899
# Patient 41899 has less then 6 hours recordings, discard from the final dataset
# processing 1862/4709, subject_id = 41929
# processing 1863/4709, subject_id = 42020
# Patient 42020 has less then 6 hours recordings, discard from the final dataset
# processing 1864/4709, subject_id = 42055
# processing 1865/4709, subject_id = 42070
# Patient 42070 has less then 6 hours recordings, discard from the final dataset
# processing 1866/4709, subject_id = 42073
# Patient 42073 has less then 6 hours recordings, discard from the final dataset
# processing 1867/4709, subject_id = 42075
# processing 1868/4709, subject_id = 42110
# Patient 42110 has less then 6 hours recordings, discard from the final dataset
# processing 1869/4709, subject_id = 42141
# processing 1870/4709, subject_id = 42199
# processing 1871/4709, subject_id = 42364
# Patient 42364 has less then 6 hours recordings, discard from the final dataset
# processing 1872/4709, subject_id = 42366
# Patient 42366 has less then 6 hours recordings, discard from the final dataset
# processing 1873/4709, subject_id = 42404
# Patient 42404 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1874/4709, subject_id = 42491
# Patient 42491 has less then 6 hours recordings, discard from the final dataset
# processing 1875/4709, subject_id = 42515
# Patient 42515 has less then 6 hours recordings, discard from the final dataset
# processing 1876/4709, subject_id = 42530
# processing 1877/4709, subject_id = 42624
# Patient 42624 has less then 6 hours recordings, discard from the final dataset
# processing 1878/4709, subject_id = 42683
# Patient 42683 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1879/4709, subject_id = 42753
# processing 1880/4709, subject_id = 42757
# Patient 42757 has less then 6 hours recordings, discard from the final dataset
# processing 1881/4709, subject_id = 42782
# Patient 42782 has less then 6 hours recordings, discard from the final dataset
# processing 1882/4709, subject_id = 42815
# processing 1883/4709, subject_id = 42829
# Patient 42829 has less then 6 hours recordings, discard from the final dataset
# processing 1884/4709, subject_id = 42892
# Patient 42892 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1885/4709, subject_id = 42904
# Patient 42904 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1886/4709, subject_id = 43038
# processing 1887/4709, subject_id = 43061
# Patient 43061 has less then 6 hours recordings, discard from the final dataset
# processing 1888/4709, subject_id = 43065
# processing 1889/4709, subject_id = 43078
# processing 1890/4709, subject_id = 43086
# Patient 43086 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1891/4709, subject_id = 43112
# processing 1892/4709, subject_id = 43126
# Patient 43126 has less then 6 hours recordings, discard from the final dataset
# processing 1893/4709, subject_id = 43128
# Patient 43128 has less then 6 hours recordings, discard from the final dataset
# processing 1894/4709, subject_id = 43147
# Patient 43147 has less then 6 hours recordings, discard from the final dataset
# processing 1895/4709, subject_id = 43151
# Patient 43151 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1896/4709, subject_id = 43183
# Patient 43183 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1897/4709, subject_id = 43254
# Patient 43254 has less then 6 hours recordings, discard from the final dataset
# processing 1898/4709, subject_id = 43257
# Patient 43257 has less then 6 hours recordings, discard from the final dataset
# processing 1899/4709, subject_id = 43305
# Patient 43305 has less then 6 hours recordings, discard from the final dataset
# processing 1900/4709, subject_id = 43320
# Patient 43320 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1901/4709, subject_id = 43431
# Patient 43431 has less then 6 hours recordings, discard from the final dataset
# processing 1902/4709, subject_id = 43437
# processing 1903/4709, subject_id = 43450
# processing 1904/4709, subject_id = 43453
# Patient 43453 has less then 6 hours recordings, discard from the final dataset
# processing 1905/4709, subject_id = 43563
# Patient 43563 has less then 6 hours recordings, discard from the final dataset
# processing 1906/4709, subject_id = 43599
# Patient 43599 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1907/4709, subject_id = 43613
# Patient 43613 has less then 6 hours recordings, discard from the final dataset
# processing 1908/4709, subject_id = 43632
# Patient 43632 has less then 6 hours recordings, discard from the final dataset
# processing 1909/4709, subject_id = 43673
# processing 1910/4709, subject_id = 43676
# processing 1911/4709, subject_id = 43690
# Patient 43690 has less then 6 hours recordings, discard from the final dataset
# processing 1912/4709, subject_id = 43776
# Patient 43776 has less then 6 hours recordings, discard from the final dataset
# processing 1913/4709, subject_id = 43856
# Patient 43856 has less then 6 hours recordings, discard from the final dataset
# processing 1914/4709, subject_id = 43937
# Patient 43937 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1915/4709, subject_id = 43969
# Patient 43969 has less then 6 hours recordings, discard from the final dataset
# processing 1916/4709, subject_id = 44036
# Patient 44036 has less then 6 hours recordings, discard from the final dataset
# processing 1917/4709, subject_id = 44136
# processing 1918/4709, subject_id = 44228
# Patient 44228 has less then 6 hours recordings, discard from the final dataset
# processing 1919/4709, subject_id = 44298
# processing 1920/4709, subject_id = 44320
# Patient 44320 has less then 6 hours recordings, discard from the final dataset
# processing 1921/4709, subject_id = 44323
# Patient 44323 has less then 6 hours recordings, discard from the final dataset
# processing 1922/4709, subject_id = 44328
# processing 1923/4709, subject_id = 44413
# Patient 44413 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1924/4709, subject_id = 44546
# Patient 44546 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1925/4709, subject_id = 44630
# Patient 44630 has less then 6 hours recordings, discard from the final dataset
# processing 1926/4709, subject_id = 44722
# processing 1927/4709, subject_id = 44771
# processing 1928/4709, subject_id = 44788
# Patient 44788 has less then 6 hours recordings, discard from the final dataset
# processing 1929/4709, subject_id = 44799
# Patient 44799 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1930/4709, subject_id = 44829
# Patient 44829 has less then 6 hours recordings, discard from the final dataset
# processing 1931/4709, subject_id = 44833
# processing 1932/4709, subject_id = 44878
# processing 1933/4709, subject_id = 44894
# Patient 44894 has less then 6 hours recordings, discard from the final dataset
# processing 1934/4709, subject_id = 44941
# processing 1935/4709, subject_id = 44969
# Patient 44969 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1936/4709, subject_id = 44973
# processing 1937/4709, subject_id = 45126
# Patient 45126 has less then 6 hours recordings, discard from the final dataset
# processing 1938/4709, subject_id = 45169
# processing 1939/4709, subject_id = 45186
# Patient 45186 has less then 6 hours recordings, discard from the final dataset
# processing 1940/4709, subject_id = 45193
# Patient 45193 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1941/4709, subject_id = 45202
# Patient 45202 has less then 6 hours recordings, discard from the final dataset
# processing 1942/4709, subject_id = 45249
# processing 1943/4709, subject_id = 45269
# Patient 45269 has less then 6 hours recordings, discard from the final dataset
# processing 1944/4709, subject_id = 45271
# Patient 45271 has less then 6 hours recordings, discard from the final dataset
# processing 1945/4709, subject_id = 45317
# Patient 45317 has less then 6 hours recordings, discard from the final dataset
# processing 1946/4709, subject_id = 45339
# Patient 45339 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1947/4709, subject_id = 45393
# processing 1948/4709, subject_id = 45419
# processing 1949/4709, subject_id = 45425
# Patient 45425 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1950/4709, subject_id = 45460
# Patient 45460 has less then 6 hours recordings, discard from the final dataset
# processing 1951/4709, subject_id = 45677
# Patient 45677 has less then 6 hours recordings, discard from the final dataset
# processing 1952/4709, subject_id = 45783
# Patient 45783 has less then 6 hours recordings, discard from the final dataset
# processing 1953/4709, subject_id = 45851
# processing 1954/4709, subject_id = 45910
# Patient 45910 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1955/4709, subject_id = 46041
# processing 1956/4709, subject_id = 46092
# Patient 46092 has less then 6 hours recordings, discard from the final dataset
# processing 1957/4709, subject_id = 46105
# Patient 46105 has less then 6 hours recordings, discard from the final dataset
# processing 1958/4709, subject_id = 46156
# Patient 46156 has less then 6 hours recordings, discard from the final dataset
# processing 1959/4709, subject_id = 46251
# Patient 46251 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1960/4709, subject_id = 46411
# processing 1961/4709, subject_id = 46423
# Patient 46423 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1962/4709, subject_id = 46441
# processing 1963/4709, subject_id = 46466
# processing 1964/4709, subject_id = 46589
# Patient 46589 has less then 6 hours recordings, discard from the final dataset
# processing 1965/4709, subject_id = 46614
# processing 1966/4709, subject_id = 46676
# Patient 46676 has less then 6 hours recordings, discard from the final dataset
# processing 1967/4709, subject_id = 46693
# Patient 46693 has less then 6 hours recordings, discard from the final dataset
# processing 1968/4709, subject_id = 46775
# Patient 46775 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1969/4709, subject_id = 46955
# Patient 46955 has less then 6 hours recordings, discard from the final dataset
# processing 1970/4709, subject_id = 46968
# Patient 46968 has less then 6 hours recordings, discard from the final dataset
# processing 1971/4709, subject_id = 47101
# Patient 47101 has less then 6 hours recordings, discard from the final dataset
# processing 1972/4709, subject_id = 47118
# processing 1973/4709, subject_id = 47183
# Patient 47183 has less then 6 hours recordings, discard from the final dataset
# processing 1974/4709, subject_id = 47234
# Patient 47234 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1975/4709, subject_id = 47255
# processing 1976/4709, subject_id = 47286
# processing 1977/4709, subject_id = 47305
# Patient 47305 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1978/4709, subject_id = 47312
# Patient 47312 has less then 6 hours recordings, discard from the final dataset
# processing 1979/4709, subject_id = 47430
# Patient 47430 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1980/4709, subject_id = 47520
# Patient 47520 has less then 6 hours recordings, discard from the final dataset
# processing 1981/4709, subject_id = 47577
# Patient 47577 has less then 6 hours recordings, discard from the final dataset
# processing 1982/4709, subject_id = 47613
# Patient 47613 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1983/4709, subject_id = 47677
# Patient 47677 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1984/4709, subject_id = 47687
# Patient 47687 has less then 6 hours recordings, discard from the final dataset
# processing 1985/4709, subject_id = 47746
# Patient 47746 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1986/4709, subject_id = 47775
# Patient 47775 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1987/4709, subject_id = 47785
# Patient 47785 has less then 6 hours recordings, discard from the final dataset
# processing 1988/4709, subject_id = 47790
# Patient 47790 has less then 6 hours recordings, discard from the final dataset
# processing 1989/4709, subject_id = 47816
# Patient 47816 has less then 6 hours recordings, discard from the final dataset
# processing 1990/4709, subject_id = 47827
# Patient 47827 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1991/4709, subject_id = 47886
# processing 1992/4709, subject_id = 47912
# Patient 47912 has less then 6 hours recordings, discard from the final dataset
# processing 1993/4709, subject_id = 47914
# processing 1994/4709, subject_id = 47941
# Patient 47941 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1995/4709, subject_id = 47956
# processing 1996/4709, subject_id = 47983
# Patient 47983 has less then 6 hours recordings, discard from the final dataset
# processing 1997/4709, subject_id = 48011
# processing 1998/4709, subject_id = 48038
# Patient 48038 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 1999/4709, subject_id = 48042
# Patient 48042 has less then 6 hours recordings, discard from the final dataset
# processing 2000/4709, subject_id = 48076
# Patient 48076 has less then 6 hours recordings, discard from the final dataset
# processing 2001/4709, subject_id = 48124
# Patient 48124 has less then 6 hours recordings, discard from the final dataset
# processing 2002/4709, subject_id = 48239
# Patient 48239 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 2003/4709, subject_id = 48268
# Patient 48268 has less then 6 hours recordings, discard from the final dataset
# processing 2004/4709, subject_id = 48320
# processing 2005/4709, subject_id = 48340
# Patient 48340 has less then 6 hours recordings, discard from the final dataset
# processing 2006/4709, subject_id = 48388
# Patient 48388 has less then 6 hours recordings, discard from the final dataset
# processing 2007/4709, subject_id = 48453
# Patient 48453 has less then 6 hours recordings, discard from the final dataset
# processing 2008/4709, subject_id = 48468
# Patient 48468 has less then 6 hours recordings, discard from the final dataset
# processing 2009/4709, subject_id = 48483
# Patient 48483 has less then 6 hours recordings, discard from the final dataset
# processing 2010/4709, subject_id = 48636
# Patient 48636 has less then 6 hours recordings, discard from the final dataset
# processing 2011/4709, subject_id = 48660
# processing 2012/4709, subject_id = 48730
# Patient 48730 has less then 6 hours recordings, discard from the final dataset
# processing 2013/4709, subject_id = 48779
# Patient 48779 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 2014/4709, subject_id = 48872
# processing 2015/4709, subject_id = 48876
# Patient 48876 has less then 6 hours recordings, discard from the final dataset
# processing 2016/4709, subject_id = 48882
# Patient 48882 has less then 6 hours recordings, discard from the final dataset
# processing 2017/4709, subject_id = 48886
# Patient 48886 has less then 6 hours recordings, discard from the final dataset
# processing 2018/4709, subject_id = 48925
# processing 2019/4709, subject_id = 49008
# processing 2020/4709, subject_id = 49023
# processing 2021/4709, subject_id = 49029
# processing 2022/4709, subject_id = 49068
# processing 2023/4709, subject_id = 49092
# Patient 49092 has less then 6 hours recordings, discard from the final dataset
# processing 2024/4709, subject_id = 49164
# processing 2025/4709, subject_id = 49247
# Patient 49247 has less then 6 hours recordings, discard from the final dataset
# processing 2026/4709, subject_id = 49311
# Patient 49311 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 2027/4709, subject_id = 49327
# processing 2028/4709, subject_id = 49358
# processing 2029/4709, subject_id = 49359
# Patient 49359 has less then 6 hours recordings, discard from the final dataset
# processing 2030/4709, subject_id = 49431
# Patient 49431 has less then 6 hours recordings, discard from the final dataset
# processing 2031/4709, subject_id = 49453
# ...
# processing 4534/4709, subject_id = 11427
# Patient 11427 has less then 6 hours recordings, discard from the final dataset
# processing 4535/4709, subject_id = 31910
# Patient 31910 has less then 6 hours recordings, discard from the final dataset
# processing 4536/4709, subject_id = 2825
# processing 4537/4709, subject_id = 26429
# processing 4538/4709, subject_id = 18633
# Patient 18633 has less then 6 hours recordings, discard from the final dataset
# processing 4539/4709, subject_id = 70380
# Patient 70380 has less then 6 hours recordings, discard from the final dataset
# processing 4540/4709, subject_id = 43551
# Patient 43551 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4541/4709, subject_id = 13495
# Patient 13495 has less then 6 hours recordings, discard from the final dataset
# processing 4542/4709, subject_id = 98220
# Patient 98220 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4543/4709, subject_id = 23097
# processing 4544/4709, subject_id = 15230
# processing 4545/4709, subject_id = 27935
# Patient 27935 has less then 6 hours recordings, discard from the final dataset
# processing 4546/4709, subject_id = 14026
# Patient 14026 has less then 6 hours recordings, discard from the final dataset
# processing 4547/4709, subject_id = 49603
# Patient 49603 has less then 6 hours recordings, discard from the final dataset
# processing 4548/4709, subject_id = 14123
# Patient 14123 has less then 6 hours recordings, discard from the final dataset
# processing 4549/4709, subject_id = 8485
# Patient 8485 has less then 6 hours recordings, discard from the final dataset
# processing 4550/4709, subject_id = 17976
# processing 4551/4709, subject_id = 24693
# processing 4552/4709, subject_id = 8395
# Patient 8395 has less then 6 hours recordings, discard from the final dataset
# processing 4553/4709, subject_id = 10532
# Patient 10532 has less then 6 hours recordings, discard from the final dataset
# processing 4554/4709, subject_id = 46373
# processing 4555/4709, subject_id = 18944
# Patient 18944 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4556/4709, subject_id = 20904
# Patient 20904 has less then 6 hours recordings, discard from the final dataset
# processing 4557/4709, subject_id = 58433
# Patient 58433 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4558/4709, subject_id = 19632
# Patient 19632 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4559/4709, subject_id = 14477
# Patient 14477 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4560/4709, subject_id = 67906
# processing 4561/4709, subject_id = 11091
# Patient 11091 has less then 6 hours recordings, discard from the final dataset
# processing 4562/4709, subject_id = 26844
# processing 4563/4709, subject_id = 22808
# processing 4564/4709, subject_id = 540
# Patient 540 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4565/4709, subject_id = 31779
# processing 4566/4709, subject_id = 7977
# Patient 7977 has less then 6 hours recordings, discard from the final dataset
# processing 4567/4709, subject_id = 24892
# processing 4568/4709, subject_id = 10425
# Patient 10425 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4569/4709, subject_id = 3486
# Patient 3486 has less then 6 hours recordings, discard from the final dataset
# processing 4570/4709, subject_id = 95387
# processing 4571/4709, subject_id = 24262
# Patient 24262 has less then 6 hours recordings, discard from the final dataset
# processing 4572/4709, subject_id = 11589
# processing 4573/4709, subject_id = 88099
# Patient 88099 has less then 6 hours recordings, discard from the final dataset
# processing 4574/4709, subject_id = 25286
# processing 4575/4709, subject_id = 5385
# Patient 5385 has less then 6 hours recordings, discard from the final dataset
# processing 4576/4709, subject_id = 67480
# processing 4577/4709, subject_id = 30590
# processing 4578/4709, subject_id = 46230
# processing 4579/4709, subject_id = 27400
# Patient 27400 has less then 6 hours recordings, discard from the final dataset
# processing 4580/4709, subject_id = 12772
# processing 4581/4709, subject_id = 2819
# processing 4582/4709, subject_id = 45326
# Patient 45326 has less then 6 hours recordings, discard from the final dataset
# processing 4583/4709, subject_id = 4071
# Patient 4071 has less then 6 hours recordings, discard from the final dataset
# processing 4584/4709, subject_id = 78418
# Patient 78418 has less then 6 hours recordings, discard from the final dataset
# processing 4585/4709, subject_id = 30322
# Patient 30322 has less then 6 hours recordings, discard from the final dataset
# processing 4586/4709, subject_id = 10686
# Patient 10686 has less then 6 hours recordings, discard from the final dataset
# processing 4587/4709, subject_id = 794
# Patient 794 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4588/4709, subject_id = 10635
# Patient 10635 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4589/4709, subject_id = 27132
# Patient 27132 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4590/4709, subject_id = 24285
# Patient 24285 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4591/4709, subject_id = 15747
# Patient 15747 has less then 6 hours recordings, discard from the final dataset
# processing 4592/4709, subject_id = 22794
# processing 4593/4709, subject_id = 25711
# Patient 25711 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4594/4709, subject_id = 63364
# Patient 63364 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4595/4709, subject_id = 16375
# processing 4596/4709, subject_id = 21451
# Patient 21451 has less then 6 hours recordings, discard from the final dataset
# processing 4597/4709, subject_id = 14517
# Patient 14517 has less then 6 hours recordings, discard from the final dataset
# processing 4598/4709, subject_id = 47385
# Patient 47385 has less then 6 hours recordings, discard from the final dataset
# processing 4599/4709, subject_id = 7029
# Patient 7029 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4600/4709, subject_id = 45576
# processing 4601/4709, subject_id = 6082
# Patient 6082 has less then 6 hours recordings, discard from the final dataset
# processing 4602/4709, subject_id = 1283
# Patient 1283 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4603/4709, subject_id = 1423
# processing 4604/4709, subject_id = 10370
# Patient 10370 has less then 6 hours recordings, discard from the final dataset
# processing 4605/4709, subject_id = 15974
# processing 4606/4709, subject_id = 1785
# processing 4607/4709, subject_id = 43644
# Patient 43644 has less then 6 hours recordings, discard from the final dataset
# processing 4608/4709, subject_id = 75517
# Patient 75517 has less then 6 hours recordings, discard from the final dataset
# processing 4609/4709, subject_id = 92393
# Patient 92393 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4610/4709, subject_id = 17413
# processing 4611/4709, subject_id = 2603
# Patient 2603 has less then 6 hours recordings, discard from the final dataset
# processing 4612/4709, subject_id = 56985
# Patient 56985 has less then 6 hours recordings, discard from the final dataset
# processing 4613/4709, subject_id = 24638
# Patient 24638 has less then 6 hours recordings, discard from the final dataset
# processing 4614/4709, subject_id = 21678
# processing 4615/4709, subject_id = 2639
# Patient 2639 has less then 6 hours recordings, discard from the final dataset
# processing 4616/4709, subject_id = 2691
# processing 4617/4709, subject_id = 27024
# processing 4618/4709, subject_id = 17610
# processing 4619/4709, subject_id = 4651
# processing 4620/4709, subject_id = 4816
# Patient 4816 has less then 6 hours recordings, discard from the final dataset
# processing 4621/4709, subject_id = 12542
# Patient 12542 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4622/4709, subject_id = 94765
# Patient 94765 has less then 6 hours recordings, discard from the final dataset
# processing 4623/4709, subject_id = 10237
# Patient 10237 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4624/4709, subject_id = 32247
# Patient 32247 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4625/4709, subject_id = 16574
# processing 4626/4709, subject_id = 5081
# Patient 5081 has less then 6 hours recordings, discard from the final dataset
# processing 4627/4709, subject_id = 21727
# Patient 21727 has less then 6 hours recordings, discard from the final dataset
# processing 4628/4709, subject_id = 23811
# processing 4629/4709, subject_id = 24414
# processing 4630/4709, subject_id = 14565
# Patient 14565 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4631/4709, subject_id = 20679
# processing 4632/4709, subject_id = 46588
# Patient 46588 has less then 6 hours recordings, discard from the final dataset
# processing 4633/4709, subject_id = 69447
# processing 4634/4709, subject_id = 86824
# processing 4635/4709, subject_id = 82770
# processing 4636/4709, subject_id = 31062
# Patient 31062 has less then 6 hours recordings, discard from the final dataset
# processing 4637/4709, subject_id = 25811
# processing 4638/4709, subject_id = 95201
# processing 4639/4709, subject_id = 24386
# processing 4640/4709, subject_id = 2897
# processing 4641/4709, subject_id = 27506
# Patient 27506 has less then 6 hours recordings, discard from the final dataset
# processing 4642/4709, subject_id = 340
# processing 4643/4709, subject_id = 98481
# Patient 98481 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4644/4709, subject_id = 60637
# processing 4645/4709, subject_id = 12450
# processing 4646/4709, subject_id = 2053
# Patient 2053 has less then 6 hours recordings, discard from the final dataset
# processing 4647/4709, subject_id = 4968
# processing 4648/4709, subject_id = 13993
# processing 4649/4709, subject_id = 25713
# Patient 25713 has less then 6 hours recordings, discard from the final dataset
# processing 4650/4709, subject_id = 77511
# Patient 77511 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4651/4709, subject_id = 11167
# Patient 11167 has less then 6 hours recordings, discard from the final dataset
# processing 4652/4709, subject_id = 50822
# processing 4653/4709, subject_id = 27766
# Patient 27766 has less then 6 hours recordings, discard from the final dataset
# processing 4654/4709, subject_id = 20838
# Patient 20838 has less then 6 hours recordings, discard from the final dataset
# processing 4655/4709, subject_id = 6718
# Patient 6718 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4656/4709, subject_id = 9278
# processing 4657/4709, subject_id = 74566
# Patient 74566 has less then 6 hours recordings, discard from the final dataset
# processing 4658/4709, subject_id = 88676
# Patient 88676 has less then 6 hours recordings, discard from the final dataset
# processing 4659/4709, subject_id = 24573
# processing 4660/4709, subject_id = 10687
# Patient 10687 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4661/4709, subject_id = 402
# processing 4662/4709, subject_id = 72328
# processing 4663/4709, subject_id = 2973
# Patient 2973 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4664/4709, subject_id = 58055
# Patient 58055 has less then 6 hours recordings, discard from the final dataset
# processing 4665/4709, subject_id = 8163
# Patient 8163 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4666/4709, subject_id = 54197
# processing 4667/4709, subject_id = 83210
# processing 4668/4709, subject_id = 73039
# processing 4669/4709, subject_id = 26283
# processing 4670/4709, subject_id = 27902
# processing 4671/4709, subject_id = 77067
# processing 4672/4709, subject_id = 30207
# Patient 30207 has less then 6 hours recordings, discard from the final dataset
# processing 4673/4709, subject_id = 80580
# processing 4674/4709, subject_id = 29274
# Patient 29274 has less then 6 hours recordings, discard from the final dataset
# processing 4675/4709, subject_id = 22311
# processing 4676/4709, subject_id = 28244
# Patient 28244 has less then 6 hours recordings, discard from the final dataset
# processing 4677/4709, subject_id = 75640
# Patient 75640 has less then 6 hours recordings, discard from the final dataset
# processing 4678/4709, subject_id = 69438
# processing 4679/4709, subject_id = 27347
# Patient 27347 has less then 6 hours recordings, discard from the final dataset
# processing 4680/4709, subject_id = 31801
# Patient 31801 has less then 6 hours recordings, discard from the final dataset
# processing 4681/4709, subject_id = 91294
# Patient 91294 has less then 6 hours recordings, discard from the final dataset
# processing 4682/4709, subject_id = 28528
# processing 4683/4709, subject_id = 80641
# Patient 80641 has less then 6 hours recordings, discard from the final dataset
# processing 4684/4709, subject_id = 6131
# Patient 6131 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4685/4709, subject_id = 5175
# processing 4686/4709, subject_id = 49623
# Patient 49623 has less then 6 hours recordings, discard from the final dataset
# processing 4687/4709, subject_id = 23171
# Patient 23171 has less then 6 hours recordings, discard from the final dataset
# processing 4688/4709, subject_id = 4267
# Patient 4267 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4689/4709, subject_id = 82202
# Patient 82202 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4690/4709, subject_id = 3392
# Patient 3392 has less then 6 hours recordings, discard from the final dataset
# processing 4691/4709, subject_id = 27065
# Patient 27065 has less then 6 hours recordings, discard from the final dataset
# processing 4692/4709, subject_id = 16365
# processing 4693/4709, subject_id = 93325
# processing 4694/4709, subject_id = 87552
# Patient 87552 has less then 6 hours recordings, discard from the final dataset
# processing 4695/4709, subject_id = 6470
# processing 4696/4709, subject_id = 5752
# processing 4697/4709, subject_id = 52254
# Patient 52254 has less then 6 hours recordings, discard from the final dataset
# processing 4698/4709, subject_id = 57654
# Patient 57654 has less then 6 hours recordings, discard from the final dataset
# processing 4699/4709, subject_id = 3619
# Patient 3619 has less then 6 hours recordings, discard from the final dataset
# processing 4700/4709, subject_id = 94525
# Patient 94525 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4701/4709, subject_id = 24030
# processing 4702/4709, subject_id = 14302
# processing 4703/4709, subject_id = 87989
# Patient 87989 has less then 6 hours recordings, discard from the final dataset
# processing 4704/4709, subject_id = 62495
# Patient 62495 has less then 6 hours recordings, discard from the final dataset
# processing 4705/4709, subject_id = 453
# Patient 453 has less then 6 hours recordings, discard from the final dataset
# processing 4706/4709, subject_id = 11920
# Patient 11920 has less then 6 hours recordings, discard from the final dataset
# processing 4707/4709, subject_id = 19911
# Patient 19911 has less then 6 hours recordings, discard from the final dataset
# processing 4708/4709, subject_id = 21003
# Patient 21003 has no recordings within the 6 hours before onset, discard from the final dataset
# processing 4709/4709, subject_id = 41217

# %%
print(type_1)
print(type_2)
print(type_3)
# Out:
# 1764
# 1059
# 1886

# %% [markdown]
# ## This block process the neonates/adults with no sepsis
#
# 1.   always starting with the first row
# 2.   if the whole los < 6 hrs, discard
# 2.   if the los is longer than 100 hours, only keep the first 100 hours
# 3.   aggregate the data into hourly time points

# %%
step = 0  # for indicating processing step
type_4 = 0  # neonates/adults with less than 6 hrs of recordings (non_sepsis)
type_5 = 0  # neonates/adults with successful generation of table (non_sepsis)

for csv_file in non_sepsis_dir:
  patient = pd.read_csv(patients_non_sepsis + csv_file)

  step +=1
  print("processing {}/{}, subject_id = {}".format(step,len(non_sepsis_dir),patient.subject_id[0]))

  new_df = pd.DataFrame(columns=patient.columns)

  # empty_row = {'subject_id':patient.subject_id[0], 'gender':patient.gender[0],
  #              'sepsis':False, 'SBP':np.nan, 'DBP':np.nan, 'MAP':np.nan, 'Temp':np.nan, 'HR':np.nan,
  #              'RR':np.nan, 'BaseExcess':np.nan, 'FiO2':np.nan, 'SaO2':np.nan, 'PCO2':np.nan, 
  #              'PH':np.nan, 'Calcium':np.nan, 'Sodium':np.nan, 'Potassium':np.nan, 'Creatinine':np.nan, 
  #              'Chloride':np.nan, 'Glucose':np.nan, 'WBC':np.nan, 'BUN':np.nan, 'PTT':np.nan,
  #              'Platelet':np.nan, 'time':np.nan}  # for neonates

  empty_row = {'subject_id':patient.subject_id[0], 'gender':patient.gender[0], 'age':patient.age[0],
               'sepsis':False, 'SBP':np.nan, 'DBP':np.nan, 'MAP':np.nan, 'Temp':np.nan, 'HR':np.nan,
               'RR':np.nan, 'BaseExcess':np.nan, 'SaO2':np.nan, 'PH':np.nan, 'Magnesium':np.nan,
               'Lactic':np.nan, 'Calcium':np.nan, 'Sodium':np.nan, 'Potassium':np.nan, 'HCO3':np.nan,
               'Creatinine':np.nan, 'Chloride':np.nan, 'Glucose':np.nan, 'WBC':np.nan, 'BUN':np.nan, 
               'PTT':np.nan, 'Platelet':np.nan, 'time':np.nan}  # for adults

  time_points = len(patient)
  start_time = patient.time[0]
  end_time = patient.time[time_points-1]
  FMT = '%Y-%m-%d %H:%M:%S'
  los = ( datetime.strptime( end_time, FMT) - datetime.strptime(start_time, FMT) ).total_seconds()/3600 #in hours
  if los < 6:
    print("Patient{} has less then 6 hours recordings, discard from the final dataset".format(patient.subject_id[0]))
    type_4 += 1
    continue

  type_5 += 1

  # determine the start time
  start = datetime.strptime(start_time,FMT)
  end = datetime.strptime(end_time,FMT)
  delta = timedelta(hours = 100)  #maximun 100 hours before onset for each neonate
  new_end = start + delta
  # get the ending index and ending time
  if new_end > end: 
    new_end = rounder_forward(end)
    new_end_index = time_points - 1
  else:
    new_end = rounder_forward(new_end)
    for index, row in patient.iterrows():
      current  = datetime.strptime(row.time, FMT)
      if current < new_end: 
        continue
      else: 
        new_end_index = index
        break

  time_diff = (new_end - start).total_seconds()/3600  # in hours
  for i in range(int(time_diff)+1):
    new_row = pd.Series(empty_row)
    new_row['time'] = start
    for index in range(0, new_end_index+1):
      if datetime.strptime( patient.iloc[index].time, FMT) >= start and datetime.strptime( patient.iloc[index].time, FMT) < start + timedelta(hours = 1):
        new_row = merge_rows(new_row,patient.iloc[index])
    new_df = new_df.append(new_row, ignore_index = True)
    start = start + timedelta(hours = 1)

  new_df.to_csv('/content/drive/MyDrive/MIMIC/Results/adults/processed_non_sepsis/'+ str(patient.subject_id[0]) + '.csv', index = False)
# Out:
# Streaming output truncated to the last 5000 lines.
# processing 4287/7499, subject_id = 13646
# Patient13646 has less then 6 hours recordings, discard from the final dataset
# processing 4288/7499, subject_id = 13648
# Patient13648 has less then 6 hours recordings, discard from the final dataset
# processing 4289/7499, subject_id = 13654
# Patient13654 has less then 6 hours recordings, discard from the final dataset
# processing 4290/7499, subject_id = 13657
# Patient13657 has less then 6 hours recordings, discard from the final dataset
# processing 4291/7499, subject_id = 13660
# processing 4292/7499, subject_id = 13664
# processing 4293/7499, subject_id = 13666
# Patient13666 has less then 6 hours recordings, discard from the final dataset
# processing 4294/7499, subject_id = 13668
# processing 4295/7499, subject_id = 13669
# Patient13669 has less then 6 hours recordings, discard from the final dataset
# processing 4296/7499, subject_id = 13672
# Patient13672 has less then 6 hours recordings, discard from the final dataset
# processing 4297/7499, subject_id = 13675
# Patient13675 has less then 6 hours recordings, discard from the final dataset
# processing 4298/7499, subject_id = 13677
# processing 4299/7499, subject_id = 13683
# Patient13683 has less then 6 hours recordings, discard from the final dataset
# processing 4300/7499, subject_id = 13686
# processing 4301/7499, subject_id = 13690
# processing 4302/7499, subject_id = 13693
# Patient13693 has less then 6 hours recordings, discard from the final dataset
# processing 4303/7499, subject_id = 13694
# Patient13694 has less then 6 hours recordings, discard from the final dataset
# processing 4304/7499, subject_id = 13695
# processing 4305/7499, subject_id = 13696
# Patient13696 has less then 6 hours recordings, discard from the final dataset
# processing 4306/7499, subject_id = 13699
# Patient13699 has less then 6 hours recordings, discard from the final dataset
# processing 4307/7499, subject_id = 13702
# Patient13702 has less then 6 hours recordings, discard from the final dataset
# processing 4308/7499, subject_id = 13710
# Patient13710 has less then 6 hours recordings, discard from the final dataset
# processing 4309/7499, subject_id = 13719
# processing 4310/7499, subject_id = 13731
# Patient13731 has less then 6 hours recordings, discard from the final dataset
# processing 4311/7499, subject_id = 13733
# Patient13733 has less then 6 hours recordings, discard from the final dataset
# processing 4312/7499, subject_id = 13736
# processing 4313/7499, subject_id = 13737
# processing 4314/7499, subject_id = 13739
# processing 4315/7499, subject_id = 13747
# Patient13747 has less then 6 hours recordings, discard from the final dataset
# processing 4316/7499, subject_id = 13748
# Patient13748 has less then 6 hours recordings, discard from the final dataset
# processing 4317/7499, subject_id = 13753
# Patient13753 has less then 6 hours recordings, discard from the final dataset
# processing 4318/7499, subject_id = 13759
# processing 4319/7499, subject_id = 13761
# processing 4320/7499, subject_id = 13767
# Patient13767 has less then 6 hours recordings, discard from the final dataset
# processing 4321/7499, subject_id = 13772
# Patient13772 has less then 6 hours recordings, discard from the final dataset
# processing 4322/7499, subject_id = 13776
# Patient13776 has less then 6 hours recordings, discard from the final dataset
# processing 4323/7499, subject_id = 13788
# processing 4324/7499, subject_id = 13790
# processing 4325/7499, subject_id = 13800
# processing 4326/7499, subject_id = 13826
# processing 4327/7499, subject_id = 13830
# processing 4328/7499, subject_id = 13835
# Patient13835 has less then 6 hours recordings, discard from the final dataset
# processing 4329/7499, subject_id = 13836
# Patient13836 has less then 6 hours recordings, discard from the final dataset
# processing 4330/7499, subject_id = 13843
# Patient13843 has less then 6 hours recordings, discard from the final dataset
# processing 4331/7499, subject_id = 13845
# Patient13845 has less then 6 hours recordings, discard from the final dataset
# processing 4332/7499, subject_id = 13847
# Patient13847 has less then 6 hours recordings, discard from the final dataset
# processing 4333/7499, subject_id = 13849
# Patient13849 has less then 6 hours recordings, discard from the final dataset
# processing 4334/7499, subject_id = 13853
# processing 4335/7499, subject_id = 13855
# processing 4336/7499, subject_id = 13856
# Patient13856 has less then 6 hours recordings, discard from the final dataset
# processing 4337/7499, subject_id = 13859
# Patient13859 has less then 6 hours recordings, discard from the final dataset
# processing 4338/7499, subject_id = 13864
# processing 4339/7499, subject_id = 13866
# processing 4340/7499, subject_id = 13867
# Patient13867 has less then 6 hours recordings, discard from the final dataset
# processing 4341/7499, subject_id = 13871
# processing 4342/7499, subject_id = 13881
# processing 4343/7499, subject_id = 13882
# processing 4344/7499, subject_id = 13887
# processing 4345/7499, subject_id = 13888
# Patient13888 has less then 6 hours recordings, discard from the final dataset
# processing 4346/7499, subject_id = 13897
# Patient13897 has less then 6 hours recordings, discard from the final dataset
# processing 4347/7499, subject_id = 13901
# Patient13901 has less then 6 hours recordings, discard from the final dataset
# processing 4348/7499, subject_id = 13906
# Patient13906 has less then 6 hours recordings, discard from the final dataset
# processing 4349/7499, subject_id = 13917
# Patient13917 has less then 6 hours recordings, discard from the final dataset
# processing 4350/7499, subject_id = 13919
# processing 4351/7499, subject_id = 13920
# Patient13920 has less then 6 hours recordings, discard from the final dataset
# processing 4352/7499, subject_id = 13922
# processing 4353/7499, subject_id = 13931
# Patient13931 has less then 6 hours recordings, discard from the final dataset
# processing 4354/7499, subject_id = 13933
# processing 4355/7499, subject_id = 13934
# Patient13934 has less then 6 hours recordings, discard from the final dataset
# processing 4356/7499, subject_id = 13936
# Patient13936 has less then 6 hours recordings, discard from the final dataset
# processing 4357/7499, subject_id = 13940
# Patient13940 has less then 6 hours recordings, discard from the final dataset
# processing 4358/7499, subject_id = 13948
# processing 4359/7499, subject_id = 13952
# processing 4360/7499, subject_id = 13956
# Patient13956 has less then 6 hours recordings, discard from the final dataset
# processing 4361/7499, subject_id = 13957
# Patient13957 has less then 6 hours recordings, discard from the final dataset
# processing 4362/7499, subject_id = 13969
# processing 4363/7499, subject_id = 13979
# processing 4364/7499, subject_id = 13984
# Patient13984 has less then 6 hours recordings, discard from the final dataset
# processing 4365/7499, subject_id = 13985
# processing 4366/7499, subject_id = 13990
# Patient13990 has less then 6 hours recordings, discard from the final dataset
# processing 4367/7499, subject_id = 13992
# Patient13992 has less then 6 hours recordings, discard from the final dataset
# processing 4368/7499, subject_id = 13994
# Patient13994 has less then 6 hours recordings, discard from the final dataset
# processing 4369/7499, subject_id = 14008
# processing 4370/7499, subject_id = 14021
# Patient14021 has less then 6 hours recordings, discard from the final dataset
# processing 4371/7499, subject_id = 14031
# processing 4372/7499, subject_id = 14035
# processing 4373/7499, subject_id = 14041
# processing 4374/7499, subject_id = 14048
# Patient14048 has less then 6 hours recordings, discard from the final dataset
# processing 4375/7499, subject_id = 14052
# Patient14052 has less then 6 hours recordings, discard from the final dataset
# processing 4376/7499, subject_id = 14057
# Patient14057 has less then 6 hours recordings, discard from the final dataset
# processing 4377/7499, subject_id = 14058
# processing 4378/7499, subject_id = 14069
# Patient14069 has less then 6 hours recordings, discard from the final dataset
# processing 4379/7499, subject_id = 14071
# processing 4380/7499, subject_id = 14078
# Patient14078 has less then 6 hours recordings, discard from the final dataset
# processing 4381/7499, subject_id = 14082
# processing 4382/7499, subject_id = 14084
# Patient14084 has less then 6 hours recordings, discard from the final dataset
# processing 4383/7499, subject_id = 14087
# processing 4384/7499, subject_id = 14092
# Patient14092 has less then 6 hours recordings, discard from the final dataset
# processing 4385/7499, subject_id = 14094
# Patient14094 has less then 6 hours recordings, discard from the final dataset
# processing 4386/7499, subject_id = 14102
# Patient14102 has less then 6 hours recordings, discard from the final dataset
# processing 4387/7499, subject_id = 14104
# processing 4388/7499, subject_id = 14106
# processing 4389/7499, subject_id = 14109
# Patient14109 has less then 6 hours recordings, discard from the final dataset
# processing 4390/7499, subject_id = 14112
# Patient14112 has less then 6 hours recordings, discard from the final dataset
# processing 4391/7499, subject_id = 14116
# processing 4392/7499, subject_id = 14118
# processing 4393/7499, subject_id = 14124
# Patient14124 has less then 6 hours recordings, discard from the final dataset
# processing 4394/7499, subject_id = 14125
# Patient14125 has less then 6 hours recordings, discard from the final dataset
# processing 4395/7499, subject_id = 14126
# processing 4396/7499, subject_id = 14129
# processing 4397/7499, subject_id = 14131
# Patient14131 has less then 6 hours recordings, discard from the final dataset
# processing 4398/7499, subject_id = 14134
# Patient14134 has less then 6 hours recordings, discard from the final dataset
# processing 4399/7499, subject_id = 14139
# Patient14139 has less then 6 hours recordings, discard from the final dataset
# processing 4400/7499, subject_id = 14146
# processing 4401/7499, subject_id = 14157
# Patient14157 has less then 6 hours recordings, discard from the final dataset
# processing 4402/7499, subject_id = 14160
# Patient14160 has less then 6 hours recordings, discard from the final dataset
# processing 4403/7499, subject_id = 14169
# processing 4404/7499, subject_id = 14180
# Patient14180 has less then 6 hours recordings, discard from the final dataset
# processing 4405/7499, subject_id = 14183
# processing 4406/7499, subject_id = 14193
# Patient14193 has less then 6 hours recordings, discard from the final dataset
# processing 4407/7499, subject_id = 14195
# processing 4408/7499, subject_id = 14197
# Patient14197 has less then 6 hours recordings, discard from the final dataset
# processing 4409/7499, subject_id = 14209
# Patient14209 has less then 6 hours recordings, discard from the final dataset
# processing 4410/7499, subject_id = 14218
# processing 4411/7499, subject_id = 14219
# processing 4412/7499, subject_id = 14222
# Patient14222 has less then 6 hours recordings, discard from the final dataset
# processing 4413/7499, subject_id = 14227
# Patient14227 has less then 6 hours recordings, discard from the final dataset
# processing 4414/7499, subject_id = 14240
# Patient14240 has less then 6 hours recordings, discard from the final dataset
# processing 4415/7499, subject_id = 14244
# Patient14244 has less then 6 hours recordings, discard from the final dataset
# processing 4416/7499, subject_id = 14245
# Patient14245 has less then 6 hours recordings, discard from the final dataset
# processing 4417/7499, subject_id = 14248
# processing 4418/7499, subject_id = 14253
# processing 4419/7499, subject_id = 14256
# processing 4420/7499, subject_id = 14259
# processing 4421/7499, subject_id = 14266
# processing 4422/7499, subject_id = 14267
# Patient14267 has less then 6 hours recordings, discard from the final dataset
# processing 4423/7499, subject_id = 14268
# processing 4424/7499, subject_id = 14269
# Patient14269 has less then 6 hours recordings, discard from the final dataset
# processing 4425/7499, subject_id = 14271
# Patient14271 has less then 6 hours recordings, discard from the final dataset
# processing 4426/7499, subject_id = 14276
# Patient14276 has less then 6 hours recordings, discard from the final dataset
# processing 4427/7499, subject_id = 14279
# processing 4428/7499, subject_id = 14282
# Patient14282 has less then 6 hours recordings, discard from the final dataset
# processing 4429/7499, subject_id = 14285
# Patient14285 has less then 6 hours recordings, discard from the final dataset
# processing 4430/7499, subject_id = 14290
# Patient14290 has less then 6 hours recordings, discard from the final dataset
# processing 4431/7499, subject_id = 14291
# processing 4432/7499, subject_id = 14294
# processing 4433/7499, subject_id = 14299
# processing 4434/7499, subject_id = 14311
# Patient14311 has less then 6 hours recordings, discard from the final dataset
# processing 4435/7499, subject_id = 14314
# processing 4436/7499, subject_id = 14316
# processing 4437/7499, subject_id = 14320
# Patient14320 has less then 6 hours recordings, discard from the final dataset
# processing 4438/7499, subject_id = 14321
# Patient14321 has less then 6 hours recordings, discard from the final dataset
# processing 4439/7499, subject_id = 14323
# processing 4440/7499, subject_id = 14328
# Patient14328 has less then 6 hours recordings, discard from the final dataset
# processing 4441/7499, subject_id = 14332
# Patient14332 has less then 6 hours recordings, discard from the final dataset
# processing 4442/7499, subject_id = 14334
# processing 4443/7499, subject_id = 14346
# processing 4444/7499, subject_id = 14347
# processing 4445/7499, subject_id = 14354
# Patient14354 has less then 6 hours recordings, discard from the final dataset
# processing 4446/7499, subject_id = 14355
# Patient14355 has less then 6 hours recordings, discard from the final dataset
# processing 4447/7499, subject_id = 14379
# Patient14379 has less then 6 hours recordings, discard from the final dataset
# processing 4448/7499, subject_id = 14380
# processing 4449/7499, subject_id = 14381
# Patient14381 has less then 6 hours recordings, discard from the final dataset
# processing 4450/7499, subject_id = 14385
# Patient14385 has less then 6 hours recordings, discard from the final dataset
# processing 4451/7499, subject_id = 14386
# processing 4452/7499, subject_id = 14389
# processing 4453/7499, subject_id = 14395
# Patient14395 has less then 6 hours recordings, discard from the final dataset
# processing 4454/7499, subject_id = 14419
# Patient14419 has less then 6 hours recordings, discard from the final dataset
# processing 4455/7499, subject_id = 14427
# processing 4456/7499, subject_id = 14434
# processing 4457/7499, subject_id = 14443
# Patient14443 has less then 6 hours recordings, discard from the final dataset
# processing 4458/7499, subject_id = 14444
# Patient14444 has less then 6 hours recordings, discard from the final dataset
# processing 4459/7499, subject_id = 14446
# processing 4460/7499, subject_id = 14447
# Patient14447 has less then 6 hours recordings, discard from the final dataset
# processing 4461/7499, subject_id = 14450
# Patient14450 has less then 6 hours recordings, discard from the final dataset
# processing 4462/7499, subject_id = 14451
# Patient14451 has less then 6 hours recordings, discard from the final dataset
# processing 4463/7499, subject_id = 14452
# processing 4464/7499, subject_id = 14456
# processing 4465/7499, subject_id = 14458
# Patient14458 has less then 6 hours recordings, discard from the final dataset
# processing 4466/7499, subject_id = 14461
# processing 4467/7499, subject_id = 14465
# Patient14465 has less then 6 hours recordings, discard from the final dataset
# processing 4468/7499, subject_id = 14467
# processing 4469/7499, subject_id = 14475
# Patient14475 has less then 6 hours recordings, discard from the final dataset
# processing 4470/7499, subject_id = 14476
# Patient14476 has less then 6 hours recordings, discard from the final dataset
# processing 4471/7499, subject_id = 14478
# processing 4472/7499, subject_id = 14492
# Patient14492 has less then 6 hours recordings, discard from the final dataset
# processing 4473/7499, subject_id = 14493
# Patient14493 has less then 6 hours recordings, discard from the final dataset
# processing 4474/7499, subject_id = 14496
# Patient14496 has less then 6 hours recordings, discard from the final dataset
# processing 4475/7499, subject_id = 14497
# Patient14497 has less then 6 hours recordings, discard from the final dataset
# processing 4476/7499, subject_id = 14507
# processing 4477/7499, subject_id = 14514
# processing 4478/7499, subject_id = 14522
# Patient14522 has less then 6 hours recordings, discard from the final dataset
# processing 4479/7499, subject_id = 14531
# processing 4480/7499, subject_id = 14532
# Patient14532 has less then 6 hours recordings, discard from the final dataset
# processing 4481/7499, subject_id = 14533
# Patient14533 has less then 6 hours recordings, discard from the final dataset
# processing 4482/7499, subject_id = 14542
# Patient14542 has less then 6 hours recordings, discard from the final dataset
# processing 4483/7499, subject_id = 14543
# processing 4484/7499, subject_id = 14551
# processing 4485/7499, subject_id = 14553
# Patient14553 has less then 6 hours recordings, discard from the final dataset
# processing 4486/7499, subject_id = 14558
# Patient14558 has less then 6 hours recordings, discard from the final dataset
# processing 4487/7499, subject_id = 14568
# processing 4488/7499, subject_id = 14578
# Patient14578 has less then 6 hours recordings, discard from the final dataset
# processing 4489/7499, subject_id = 14579
# processing 4490/7499, subject_id = 14582
# Patient14582 has less then 6 hours recordings, discard from the final dataset
# processing 4491/7499, subject_id = 14584
# Patient14584 has less then 6 hours recordings, discard from the final dataset
# processing 4492/7499, subject_id = 14592
# Patient14592 has less then 6 hours recordings, discard from the final dataset
# processing 4493/7499, subject_id = 14593
# processing 4494/7499, subject_id = 14612
# Patient14612 has less then 6 hours recordings, discard from the final dataset
# processing 4495/7499, subject_id = 14620
# Patient14620 has less then 6 hours recordings, discard from the final dataset
# processing 4496/7499, subject_id = 14621
# processing 4497/7499, subject_id = 14622
# Patient14622 has less then 6 hours recordings, discard from the final dataset
# processing 4498/7499, subject_id = 14627
# processing 4499/7499, subject_id = 14641
# Patient14641 has less then 6 hours recordings, discard from the final dataset
# processing 4500/7499, subject_id = 14646
# processing 4501/7499, subject_id = 14648
# processing 4502/7499, subject_id = 14651
# Patient14651 has less then 6 hours recordings, discard from the final dataset
# processing 4503/7499, subject_id = 14655
# processing 4504/7499, subject_id = 14659
# Patient14659 has less then 6 hours recordings, discard from the final dataset
# processing 4505/7499, subject_id = 14662
# Patient14662 has less then 6 hours recordings, discard from the final dataset
# processing 4506/7499, subject_id = 14667
# processing 4507/7499, subject_id = 14669
# processing 4508/7499, subject_id = 14670
# processing 4509/7499, subject_id = 14676
# Patient14676 has less then 6 hours recordings, discard from the final dataset
# processing 4510/7499, subject_id = 14677
# processing 4511/7499, subject_id = 14679
# Patient14679 has less then 6 hours recordings, discard from the final dataset
# processing 4512/7499, subject_id = 14683
# Patient14683 has less then 6 hours recordings, discard from the final dataset
# processing 4513/7499, subject_id = 14689
# Patient14689 has less then 6 hours recordings, discard from the final dataset
# processing 4514/7499, subject_id = 14692
# processing 4515/7499, subject_id = 14695
# Patient14695 has less then 6 hours recordings, discard from the final dataset
# processing 4516/7499, subject_id = 14699
# processing 4517/7499, subject_id = 14703
# processing 4518/7499, subject_id = 14705
# Patient14705 has less then 6 hours recordings, discard from the final dataset
# processing 4519/7499, subject_id = 14711
# processing 4520/7499, subject_id = 14720
# processing 4521/7499, subject_id = 14723
# processing 4522/7499, subject_id = 14730
# processing 4523/7499, subject_id = 14741
# Patient14741 has less then 6 hours recordings, discard from the final dataset
# processing 4524/7499, subject_id = 14744
# Patient14744 has less then 6 hours recordings, discard from the final dataset
# processing 4525/7499, subject_id = 14747
# processing 4526/7499, subject_id = 14753
# processing 4527/7499, subject_id = 14754
# processing 4528/7499, subject_id = 14755
# processing 4529/7499, subject_id = 14756
# processing 4530/7499, subject_id = 14757
# processing 4531/7499, subject_id = 14772
# Patient14772 has less then 6 hours recordings, discard from the final dataset
# processing 4532/7499, subject_id = 14779
# Patient14779 has less then 6 hours recordings, discard from the final dataset
# processing 4533/7499, subject_id = 14797
# processing 4534/7499, subject_id = 14802
# processing 4535/7499, subject_id = 14805
# Patient14805 has less then 6 hours recordings, discard from the final dataset
# processing 4536/7499, subject_id = 14806
# processing 4537/7499, subject_id = 14807
# Patient14807 has less then 6 hours recordings, discard from the final dataset
# processing 4538/7499, subject_id = 14813
# Patient14813 has less then 6 hours recordings, discard from the final dataset
# processing 4539/7499, subject_id = 14816
# Patient14816 has less then 6 hours recordings, discard from the final dataset
# processing 4540/7499, subject_id = 14835
# processing 4541/7499, subject_id = 14838
# Patient14838 has less then 6 hours recordings, discard from the final dataset
# processing 4542/7499, subject_id = 14840
# processing 4543/7499, subject_id = 14841
# processing 4544/7499, subject_id = 14843
# Patient14843 has less then 6 hours recordings, discard from the final dataset
# processing 4545/7499, subject_id = 14849
# Patient14849 has less then 6 hours recordings, discard from the final dataset
# processing 4546/7499, subject_id = 14854
# Patient14854 has less then 6 hours recordings, discard from the final dataset
# processing 4547/7499, subject_id = 14855
# Patient14855 has less then 6 hours recordings, discard from the final dataset
# processing 4548/7499, subject_id = 14860
# processing 4549/7499, subject_id = 14861
# Patient14861 has less then 6 hours recordings, discard from the final dataset
# processing 4550/7499, subject_id = 14862
# Patient14862 has less then 6 hours recordings, discard from the final dataset
# processing 4551/7499, subject_id = 14863
# processing 4552/7499, subject_id = 14864
# Patient14864 has less then 6 hours recordings, discard from the final dataset
# processing 4553/7499, subject_id = 14869
# processing 4554/7499, subject_id = 14886
# processing 4555/7499, subject_id = 14887
# Patient14887 has less then 6 hours recordings, discard from the final dataset
# processing 4556/7499, subject_id = 14888
# processing 4557/7499, subject_id = 14890
# Patient14890 has less then 6 hours recordings, discard from the final dataset
# processing 4558/7499, subject_id = 14901
# Patient14901 has less then 6 hours recordings, discard from the final dataset
# processing 4559/7499, subject_id = 14905
# Patient14905 has less then 6 hours recordings, discard from the final dataset
# processing 4560/7499, subject_id = 14918
# Patient14918 has less then 6 hours recordings, discard from the final dataset
# processing 4561/7499, subject_id = 14932
# processing 4562/7499, subject_id = 14933
# processing 4563/7499, subject_id = 14936
# Patient14936 has less then 6 hours recordings, discard from the final dataset
# processing 4564/7499, subject_id = 14937
# Patient14937 has less then 6 hours recordings, discard from the final dataset
# processing 4565/7499, subject_id = 14938
# processing 4566/7499, subject_id = 14955
# Patient14955 has less then 6 hours recordings, discard from the final dataset
# processing 4567/7499, subject_id = 14962
# processing 4568/7499, subject_id = 14965
# Patient14965 has less then 6 hours recordings, discard from the final dataset
# processing 4569/7499, subject_id = 14966
# Patient14966 has less then 6 hours recordings, discard from the final dataset
# processing 4570/7499, subject_id = 14967
# Patient14967 has less then 6 hours recordings, discard from the final dataset
# processing 4571/7499, subject_id = 14972
# processing 4572/7499, subject_id = 14973
# processing 4573/7499, subject_id = 14998
# processing 4574/7499, subject_id = 14999
# Patient14999 has less then 6 hours recordings, discard from the final dataset
# processing 4575/7499, subject_id = 15003
# processing 4576/7499, subject_id = 15004
# processing 4577/7499, subject_id = 15011
# Patient15011 has less then 6 hours recordings, discard from the final dataset
# processing 4578/7499, subject_id = 15012
# processing 4579/7499, subject_id = 15015
# Patient15015 has less then 6 hours recordings, discard from the final dataset
# processing 4580/7499, subject_id = 15017
# processing 4581/7499, subject_id = 15023
# processing 4582/7499, subject_id = 15025
# processing 4583/7499, subject_id = 15026
# Patient15026 has less then 6 hours recordings, discard from the final dataset
# processing 4584/7499, subject_id = 15033
# Patient15033 has less then 6 hours recordings, discard from the final dataset
# processing 4585/7499, subject_id = 15038
# Patient15038 has less then 6 hours recordings, discard from the final dataset
# processing 4586/7499, subject_id = 15039
# Patient15039 has less then 6 hours recordings, discard from the final dataset
# processing 4587/7499, subject_id = 15048
# Patient15048 has less then 6 hours recordings, discard from the final dataset
# processing 4588/7499, subject_id = 15061
# processing 4589/7499, subject_id = 15062
# Patient15062 has less then 6 hours recordings, discard from the final dataset
# processing 4590/7499, subject_id = 15066
# processing 4591/7499, subject_id = 15103
# processing 4592/7499, subject_id = 15105
# processing 4593/7499, subject_id = 15106
# processing 4594/7499, subject_id = 15117
# Patient15117 has less then 6 hours recordings, discard from the final dataset
# processing 4595/7499, subject_id = 15128
# processing 4596/7499, subject_id = 15134
# Patient15134 has less then 6 hours recordings, discard from the final dataset
# processing 4597/7499, subject_id = 15138
# processing 4598/7499, subject_id = 15147
# Patient15147 has less then 6 hours recordings, discard from the final dataset
# processing 4599/7499, subject_id = 15156
# processing 4600/7499, subject_id = 15166
# Patient15166 has less then 6 hours recordings, discard from the final dataset
# processing 4601/7499, subject_id = 15168
# Patient15168 has less then 6 hours recordings, discard from the final dataset
# processing 4602/7499, subject_id = 15170
# processing 4603/7499, subject_id = 15174
# processing 4604/7499, subject_id = 15175
# Patient15175 has less then 6 hours recordings, discard from the final dataset
# processing 4605/7499, subject_id = 15182
# Patient15182 has less then 6 hours recordings, discard from the final dataset
# processing 4606/7499, subject_id = 15185
# processing 4607/7499, subject_id = 15193
# Patient15193 has less then 6 hours recordings, discard from the final dataset
# processing 4608/7499, subject_id = 15194
# processing 4609/7499, subject_id = 15207
# Patient15207 has less then 6 hours recordings, discard from the final dataset
# processing 4610/7499, subject_id = 15208
# processing 4611/7499, subject_id = 15209
# processing 4612/7499, subject_id = 15216
# processing 4613/7499, subject_id = 15219
# processing 4614/7499, subject_id = 15221
# processing 4615/7499, subject_id = 15223
# Patient15223 has less then 6 hours recordings, discard from the final dataset
# processing 4616/7499, subject_id = 15227
# Patient15227 has less then 6 hours recordings, discard from the final dataset
# processing 4617/7499, subject_id = 15228
# Patient15228 has less then 6 hours recordings, discard from the final dataset
# processing 4618/7499, subject_id = 15235
# processing 4619/7499, subject_id = 15259
# Patient15259 has less then 6 hours recordings, discard from the final dataset
# processing 4620/7499, subject_id = 15264
# processing 4621/7499, subject_id = 15265
# processing 4622/7499, subject_id = 15267
# processing 4623/7499, subject_id = 15270
# processing 4624/7499, subject_id = 15275
# processing 4625/7499, subject_id = 15277
# processing 4626/7499, subject_id = 15295
# Patient15295 has less then 6 hours recordings, discard from the final dataset
# processing 4627/7499, subject_id = 15304
# Patient15304 has less then 6 hours recordings, discard from the final dataset
# processing 4628/7499, subject_id = 15311
# processing 4629/7499, subject_id = 15312
# Patient15312 has less then 6 hours recordings, discard from the final dataset
# processing 4630/7499, subject_id = 15313
# Patient15313 has less then 6 hours recordings, discard from the final dataset
# processing 4631/7499, subject_id = 15314
# processing 4632/7499, subject_id = 15322
# Patient15322 has less then 6 hours recordings, discard from the final dataset
# processing 4633/7499, subject_id = 15336
# Patient15336 has less then 6 hours recordings, discard from the final dataset
# processing 4634/7499, subject_id = 15347
# Patient15347 has less then 6 hours recordings, discard from the final dataset
# processing 4635/7499, subject_id = 15351
# Patient15351 has less then 6 hours recordings, discard from the final dataset
# processing 4636/7499, subject_id = 15352
# processing 4637/7499, subject_id = 15353
# Patient15353 has less then 6 hours recordings, discard from the final dataset
# processing 4638/7499, subject_id = 15355
# Patient15355 has less then 6 hours recordings, discard from the final dataset
# processing 4639/7499, subject_id = 15356
# Patient15356 has less then 6 hours recordings, discard from the final dataset
# processing 4640/7499, subject_id = 15357
# Patient15357 has less then 6 hours recordings, discard from the final dataset
# processing 4641/7499, subject_id = 15358
# Patient15358 has less then 6 hours recordings, discard from the final dataset
# processing 4642/7499, subject_id = 15361
# processing 4643/7499, subject_id = 15364
# Patient15364 has less then 6 hours recordings, discard from the final dataset
# processing 4644/7499, subject_id = 15365
# Patient15365 has less then 6 hours recordings, discard from the final dataset
# processing 4645/7499, subject_id = 15369
# Patient15369 has less then 6 hours recordings, discard from the final dataset
# processing 4646/7499, subject_id = 15374
# Patient15374 has less then 6 hours recordings, discard from the final dataset
# processing 4647/7499, subject_id = 15375
# processing 4648/7499, subject_id = 15378
# Patient15378 has less then 6 hours recordings, discard from the final dataset
# processing 4649/7499, subject_id = 15379
# Patient15379 has less then 6 hours recordings, discard from the final dataset
# processing 4650/7499, subject_id = 15382
# Patient15382 has less then 6 hours recordings, discard from the final dataset
# processing 4651/7499, subject_id = 15386
# processing 4652/7499, subject_id = 15387
# processing 4653/7499, subject_id = 15392
# processing 4654/7499, subject_id = 15394
# processing 4655/7499, subject_id = 15401
# processing 4656/7499, subject_id = 15404
# processing 4657/7499, subject_id = 15421
# processing 4658/7499, subject_id = 15423
# processing 4659/7499, subject_id = 15426
# processing 4660/7499, subject_id = 15428
# processing 4661/7499, subject_id = 15438
# processing 4662/7499, subject_id = 15461
# processing 4663/7499, subject_id = 15464
# processing 4664/7499, subject_id = 15470
# processing 4665/7499, subject_id = 15473
# Patient15473 has less then 6 hours recordings, discard from the final dataset
# processing 4666/7499, subject_id = 15474
# Patient15474 has less then 6 hours recordings, discard from the final dataset
# processing 4667/7499, subject_id = 15475
# Patient15475 has less then 6 hours recordings, discard from the final dataset
# processing 4668/7499, subject_id = 15477
# processing 4669/7499, subject_id = 15489
# Patient15489 has less then 6 hours recordings, discard from the final dataset
# processing 4670/7499, subject_id = 15498
# Patient15498 has less then 6 hours recordings, discard from the final dataset
# processing 4671/7499, subject_id = 15504
# processing 4672/7499, subject_id = 15505
# processing 4673/7499, subject_id = 15511
# processing 4674/7499, subject_id = 15513
# Patient15513 has less then 6 hours recordings, discard from the final dataset
# processing 4675/7499, subject_id = 15524
# processing 4676/7499, subject_id = 15538
# processing 4677/7499, subject_id = 15541
# Patient15541 has less then 6 hours recordings, discard from the final dataset
# processing 4678/7499, subject_id = 15544
# processing 4679/7499, subject_id = 15547
# processing 4680/7499, subject_id = 15548
# processing 4681/7499, subject_id = 15557
# processing 4682/7499, subject_id = 15558
# processing 4683/7499, subject_id = 15562
# Patient15562 has less then 6 hours recordings, discard from the final dataset
# processing 4684/7499, subject_id = 15570
# processing 4685/7499, subject_id = 15573
# Patient15573 has less then 6 hours recordings, discard from the final dataset
# processing 4686/7499, subject_id = 15582
# Patient15582 has less then 6 hours recordings, discard from the final dataset
# processing 4687/7499, subject_id = 15590
# processing 4688/7499, subject_id = 15594
# Patient15594 has less then 6 hours recordings, discard from the final dataset
# processing 4689/7499, subject_id = 15596
# processing 4690/7499, subject_id = 15605
# processing 4691/7499, subject_id = 15610
# Patient15610 has less then 6 hours recordings, discard from the final dataset
# processing 4692/7499, subject_id = 15623
# Patient15623 has less then 6 hours recordings, discard from the final dataset
# processing 4693/7499, subject_id = 15626
# Patient15626 has less then 6 hours recordings, discard from the final dataset
# processing 4694/7499, subject_id = 15629
# processing 4695/7499, subject_id = 15630
# Patient15630 has less then 6 hours recordings, discard from the final dataset
# processing 4696/7499, subject_id = 15632
# processing 4697/7499, subject_id = 15639
# processing 4698/7499, subject_id = 15648
# Patient15648 has less then 6 hours recordings, discard from the final dataset
# processing 4699/7499, subject_id = 15664
# Patient15664 has less then 6 hours recordings, discard from the final dataset
# processing 4700/7499, subject_id = 15665
# Patient15665 has less then 6 hours recordings, discard from the final dataset
# processing 4701/7499, subject_id = 15666
# Patient15666 has less then 6 hours recordings, discard from the final dataset
# processing 4702/7499, subject_id = 15671
# Patient15671 has less then 6 hours recordings, discard from the final dataset
# processing 4703/7499, subject_id = 15688
# Patient15688 has less then 6 hours recordings, discard from the final dataset
# processing 4704/7499, subject_id = 15691
# Patient15691 has less then 6 hours recordings, discard from the final dataset
# processing 4705/7499, subject_id = 15701
# processing 4706/7499, subject_id = 15703
# Patient15703 has less then 6 hours recordings, discard from the final dataset
# processing 4707/7499, subject_id = 15706
# Patient15706 has less then 6 hours recordings, discard from the final dataset
# processing 4708/7499, subject_id = 15713
# Patient15713 has less then 6 hours recordings, discard from the final dataset
# processing 4709/7499, subject_id = 15728
# processing 4710/7499, subject_id = 15749
# Patient15749 has less then 6 hours recordings, discard from the final dataset
# processing 4711/7499, subject_id = 15755
# Patient15755 has less then 6 hours recordings, discard from the final dataset
# processing 4712/7499, subject_id = 15758
# Patient15758 has less then 6 hours recordings, discard from the final dataset
# processing 4713/7499, subject_id = 15759
# processing 4714/7499, subject_id = 15761
# processing 4715/7499, subject_id = 15763
# Patient15763 has less then 6 hours recordings, discard from the final dataset
# processing 4716/7499, subject_id = 15773
# Patient15773 has less then 6 hours recordings, discard from the final dataset
# processing 4717/7499, subject_id = 15782
# Patient15782 has less then 6 hours recordings, discard from the final dataset
# processing 4718/7499, subject_id = 15784
# processing 4719/7499, subject_id = 15786
# Patient15786 has less then 6 hours recordings, discard from the final dataset
# processing 4720/7499, subject_id = 15794
# Patient15794 has less then 6 hours recordings, discard from the final dataset
# processing 4721/7499, subject_id = 15803
# Patient15803 has less then 6 hours recordings, discard from the final dataset
# processing 4722/7499, subject_id = 15809
# processing 4723/7499, subject_id = 15811
# processing 4724/7499, subject_id = 15815
# Patient15815 has less then 6 hours recordings, discard from the final dataset
# processing 4725/7499, subject_id = 15819
# Patient15819 has less then 6 hours recordings, discard from the final dataset
# processing 4726/7499, subject_id = 15821
# processing 4727/7499, subject_id = 15829
# Patient15829 has less then 6 hours recordings, discard from the final dataset
# processing 4728/7499, subject_id = 15832
# Patient15832 has less then 6 hours recordings, discard from the final dataset
# processing 4729/7499, subject_id = 15838
# Patient15838 has less then 6 hours recordings, discard from the final dataset
# processing 4730/7499, subject_id = 15841
# processing 4731/7499, subject_id = 15843
# Patient15843 has less then 6 hours recordings, discard from the final dataset
# processing 4732/7499, subject_id = 15846
# Patient15846 has less then 6 hours recordings, discard from the final dataset
# processing 4733/7499, subject_id = 15847
# processing 4734/7499, subject_id = 15852
# processing 4735/7499, subject_id = 15861
# Patient15861 has less then 6 hours recordings, discard from the final dataset
# processing 4736/7499, subject_id = 15875
# processing 4737/7499, subject_id = 15883
# processing 4738/7499, subject_id = 15887
# Patient15887 has less then 6 hours recordings, discard from the final dataset
# processing 4739/7499, subject_id = 15891
# processing 4740/7499, subject_id = 15894
# processing 4741/7499, subject_id = 15918
# Patient15918 has less then 6 hours recordings, discard from the final dataset
# processing 4742/7499, subject_id = 15922
# processing 4743/7499, subject_id = 15941
# Patient15941 has less then 6 hours recordings, discard from the final dataset
# processing 4744/7499, subject_id = 15945
# Patient15945 has less then 6 hours recordings, discard from the final dataset
# processing 4745/7499, subject_id = 15954
# processing 4746/7499, subject_id = 15959
# Patient15959 has less then 6 hours recordings, discard from the final dataset
# processing 4747/7499, subject_id = 15963
# Patient15963 has less then 6 hours recordings, discard from the final dataset
# processing 4748/7499, subject_id = 15964
# processing 4749/7499, subject_id = 15969
# processing 4750/7499, subject_id = 15971
# processing 4751/7499, subject_id = 15975
# Patient15975 has less then 6 hours recordings, discard from the final dataset
# processing 4752/7499, subject_id = 15976
# processing 4753/7499, subject_id = 15977
# Patient15977 has less then 6 hours recordings, discard from the final dataset
# processing 4754/7499, subject_id = 15986
# Patient15986 has less then 6 hours recordings, discard from the final dataset
# processing 4755/7499, subject_id = 15987
# Patient15987 has less then 6 hours recordings, discard from the final dataset
# processing 4756/7499, subject_id = 15991
# processing 4757/7499, subject_id = 15997
# Patient15997 has less then 6 hours recordings, discard from the final dataset
# processing 4758/7499, subject_id = 16011
# Patient16011 has less then 6 hours recordings, discard from the final dataset
# processing 4759/7499, subject_id = 16022
# processing 4760/7499, subject_id = 16026
# processing 4761/7499, subject_id = 16032
# processing 4762/7499, subject_id = 16037
# processing 4763/7499, subject_id = 16040
# Patient16040 has less then 6 hours recordings, discard from the final dataset
# processing 4764/7499, subject_id = 16042
# processing 4765/7499, subject_id = 16044
# processing 4766/7499, subject_id = 16045
# Patient16045 has less then 6 hours recordings, discard from the final dataset
# processing 4767/7499, subject_id = 16046
# Patient16046 has less then 6 hours recordings, discard from the final dataset
# processing 4768/7499, subject_id = 16049
# processing 4769/7499, subject_id = 16053
# Patient16053 has less then 6 hours recordings, discard from the final dataset
# processing 4770/7499, subject_id = 16058
# Patient16058 has less then 6 hours recordings, discard from the final dataset
# processing 4771/7499, subject_id = 16066
# processing 4772/7499, subject_id = 16069
# Patient16069 has less then 6 hours recordings, discard from the final dataset
# processing 4773/7499, subject_id = 16071
# Patient16071 has less then 6 hours recordings, discard from the final dataset
# processing 4774/7499, subject_id = 16074
# processing 4775/7499, subject_id = 16075
# Patient16075 has less then 6 hours recordings, discard from the final dataset
# processing 4776/7499, subject_id = 16077
# Patient16077 has less then 6 hours recordings, discard from the final dataset
# processing 4777/7499, subject_id = 16080
# processing 4778/7499, subject_id = 16081
# processing 4779/7499, subject_id = 16085
# Patient16085 has less then 6 hours recordings, discard from the final dataset
# processing 4780/7499, subject_id = 16087
# processing 4781/7499, subject_id = 16088
# processing 4782/7499, subject_id = 16102
# processing 4783/7499, subject_id = 16105
# Patient16105 has less then 6 hours recordings, discard from the final dataset
# processing 4784/7499, subject_id = 16106
# processing 4785/7499, subject_id = 16111
# processing 4786/7499, subject_id = 16115
# processing 4787/7499, subject_id = 16119
# processing 4788/7499, subject_id = 16121
# processing 4789/7499, subject_id = 16128
# processing 4790/7499, subject_id = 16139
# Patient16139 has less then 6 hours recordings, discard from the final dataset
# processing 4791/7499, subject_id = 16141
# Patient16141 has less then 6 hours recordings, discard from the final dataset
# processing 4792/7499, subject_id = 16142
# processing 4793/7499, subject_id = 16145
# Patient16145 has less then 6 hours recordings, discard from the final dataset
# processing 4794/7499, subject_id = 16147
# Patient16147 has less then 6 hours recordings, discard from the final dataset
# processing 4795/7499, subject_id = 16150
# Patient16150 has less then 6 hours recordings, discard from the final dataset
# processing 4796/7499, subject_id = 16156
# Patient16156 has less then 6 hours recordings, discard from the final dataset
# processing 4797/7499, subject_id = 16159
# processing 4798/7499, subject_id = 16178
# processing 4799/7499, subject_id = 16179
# Patient16179 has less then 6 hours recordings, discard from the final dataset
# processing 4800/7499, subject_id = 16180
# processing 4801/7499, subject_id = 16186
# processing 4802/7499, subject_id = 16192
# processing 4803/7499, subject_id = 16194
# Patient16194 has less then 6 hours recordings, discard from the final dataset
# processing 4804/7499, subject_id = 16195
# processing 4805/7499, subject_id = 16196
# Patient16196 has less then 6 hours recordings, discard from the final dataset
# processing 4806/7499, subject_id = 16209
# processing 4807/7499, subject_id = 16221
# Patient16221 has less then 6 hours recordings, discard from the final dataset
# processing 4808/7499, subject_id = 16224
# processing 4809/7499, subject_id = 16227
# processing 4810/7499, subject_id = 16232
# Patient16232 has less then 6 hours recordings, discard from the final dataset
# processing 4811/7499, subject_id = 16236
# Patient16236 has less then 6 hours recordings, discard from the final dataset
# processing 4812/7499, subject_id = 16240
# processing 4813/7499, subject_id = 16241
# Patient16241 has less then 6 hours recordings, discard from the final dataset
# processing 4814/7499, subject_id = 16243
# Patient16243 has less then 6 hours recordings, discard from the final dataset
# processing 4815/7499, subject_id = 16258
# processing 4816/7499, subject_id = 16260
# Patient16260 has less then 6 hours recordings, discard from the final dataset
# processing 4817/7499, subject_id = 16264
# Patient16264 has less then 6 hours recordings, discard from the final dataset
# processing 4818/7499, subject_id = 16269
# processing 4819/7499, subject_id = 16270
# Patient16270 has less then 6 hours recordings, discard from the final dataset
# processing 4820/7499, subject_id = 16271
# Patient16271 has less then 6 hours recordings, discard from the final dataset
# processing 4821/7499, subject_id = 16275
# processing 4822/7499, subject_id = 16278
# Patient16278 has less then 6 hours recordings, discard from the final dataset
# processing 4823/7499, subject_id = 16279
# processing 4824/7499, subject_id = 16293
# processing 4825/7499, subject_id = 16294
# Patient16294 has less then 6 hours recordings, discard from the final dataset
# processing 4826/7499, subject_id = 16296
# processing 4827/7499, subject_id = 16298
# processing 4828/7499, subject_id = 16301
# processing 4829/7499, subject_id = 16302
# processing 4830/7499, subject_id = 16305
# processing 4831/7499, subject_id = 16307
# processing 4832/7499, subject_id = 16312
# Patient16312 has less then 6 hours recordings, discard from the final dataset
# processing 4833/7499, subject_id = 16317
# Patient16317 has less then 6 hours recordings, discard from the final dataset
# processing 4834/7499, subject_id = 16318
# processing 4835/7499, subject_id = 16326
# Patient16326 has less then 6 hours recordings, discard from the final dataset
# processing 4836/7499, subject_id = 16329
# Patient16329 has less then 6 hours recordings, discard from the final dataset
# processing 4837/7499, subject_id = 16332
# processing 4838/7499, subject_id = 16334
# Patient16334 has less then 6 hours recordings, discard from the final dataset
# processing 4839/7499, subject_id = 16335
# processing 4840/7499, subject_id = 16337
# processing 4841/7499, subject_id = 16342
# Patient16342 has less then 6 hours recordings, discard from the final dataset
# processing 4842/7499, subject_id = 16344
# Patient16344 has less then 6 hours recordings, discard from the final dataset
# processing 4843/7499, subject_id = 16369
# Patient16369 has less then 6 hours recordings, discard from the final dataset
# processing 4844/7499, subject_id = 16373
# Patient16373 has less then 6 hours recordings, discard from the final dataset
# processing 4845/7499, subject_id = 16379
# processing 4846/7499, subject_id = 16381
# Patient16381 has less then 6 hours recordings, discard from the final dataset
# processing 4847/7499, subject_id = 16387
# Patient16387 has less then 6 hours recordings, discard from the final dataset
# processing 4848/7499, subject_id = 16391
# Patient16391 has less then 6 hours recordings, discard from the final dataset
# processing 4849/7499, subject_id = 16393
# Patient16393 has less then 6 hours recordings, discard from the final dataset
# processing 4850/7499, subject_id = 16394
# Patient16394 has less then 6 hours recordings, discard from the final dataset
# processing 4851/7499, subject_id = 16409
# Patient16409 has less then 6 hours recordings, discard from the final dataset
# processing 4852/7499, subject_id = 16415
# Patient16415 has less then 6 hours recordings, discard from the final dataset
# processing 4853/7499, subject_id = 16419
# processing 4854/7499, subject_id = 16435
# processing 4855/7499, subject_id = 16446
# Patient16446 has less then 6 hours recordings, discard from the final dataset
# processing 4856/7499, subject_id = 16447
# Patient16447 has less then 6 hours recordings, discard from the final dataset
# processing 4857/7499, subject_id = 16449
# processing 4858/7499, subject_id = 16457
# Patient16457 has less then 6 hours recordings, discard from the final dataset
# processing 4859/7499, subject_id = 16462
# processing 4860/7499, subject_id = 16463
# Patient16463 has less then 6 hours recordings, discard from the final dataset
# processing 4861/7499, subject_id = 16468
# processing 4862/7499, subject_id = 16469
# Patient16469 has less then 6 hours recordings, discard from the final dataset
# processing 4863/7499, subject_id = 16476
# processing 4864/7499, subject_id = 16478
# Patient16478 has less then 6 hours recordings, discard from the final dataset
# processing 4865/7499, subject_id = 16479
# Patient16479 has less then 6 hours recordings, discard from the final dataset
# processing 4866/7499, subject_id = 16480
# processing 4867/7499, subject_id = 16481
# Patient16481 has less then 6 hours recordings, discard from the final dataset
# ...
# processing 7303/7499, subject_id = 1473
# Patient1473 has less then 6 hours recordings, discard from the final dataset
# processing 7304/7499, subject_id = 1478
# processing 7305/7499, subject_id = 1485
# Patient1485 has less then 6 hours recordings, discard from the final dataset
# processing 7306/7499, subject_id = 1488
# Patient1488 has less then 6 hours recordings, discard from the final dataset
# processing 7307/7499, subject_id = 1494
# Patient1494 has less then 6 hours recordings, discard from the final dataset
# processing 7308/7499, subject_id = 1496
# Patient1496 has less then 6 hours recordings, discard from the final dataset
# processing 7309/7499, subject_id = 1498
# processing 7310/7499, subject_id = 1500
# Patient1500 has less then 6 hours recordings, discard from the final dataset
# processing 7311/7499, subject_id = 1501
# Patient1501 has less then 6 hours recordings, discard from the final dataset
# processing 7312/7499, subject_id = 1508
# processing 7313/7499, subject_id = 1517
# processing 7314/7499, subject_id = 1521
# Patient1521 has less then 6 hours recordings, discard from the final dataset
# processing 7315/7499, subject_id = 1522
# Patient1522 has less then 6 hours recordings, discard from the final dataset
# processing 7316/7499, subject_id = 1528
# processing 7317/7499, subject_id = 1530
# Patient1530 has less then 6 hours recordings, discard from the final dataset
# processing 7318/7499, subject_id = 1532
# Patient1532 has less then 6 hours recordings, discard from the final dataset
# processing 7319/7499, subject_id = 1537
# Patient1537 has less then 6 hours recordings, discard from the final dataset
# processing 7320/7499, subject_id = 1544
# Patient1544 has less then 6 hours recordings, discard from the final dataset
# processing 7321/7499, subject_id = 1546
# processing 7322/7499, subject_id = 1547
# Patient1547 has less then 6 hours recordings, discard from the final dataset
# processing 7323/7499, subject_id = 1551
# processing 7324/7499, subject_id = 1556
# Patient1556 has less then 6 hours recordings, discard from the final dataset
# processing 7325/7499, subject_id = 1568
# Patient1568 has less then 6 hours recordings, discard from the final dataset
# processing 7326/7499, subject_id = 1578
# Patient1578 has less then 6 hours recordings, discard from the final dataset
# processing 7327/7499, subject_id = 1580
# processing 7328/7499, subject_id = 1593
# Patient1593 has less then 6 hours recordings, discard from the final dataset
# processing 7329/7499, subject_id = 1594
# Patient1594 has less then 6 hours recordings, discard from the final dataset
# processing 7330/7499, subject_id = 1597
# processing 7331/7499, subject_id = 1609
# processing 7332/7499, subject_id = 1634
# processing 7333/7499, subject_id = 1637
# Patient1637 has less then 6 hours recordings, discard from the final dataset
# processing 7334/7499, subject_id = 1641
# Patient1641 has less then 6 hours recordings, discard from the final dataset
# processing 7335/7499, subject_id = 1642
# processing 7336/7499, subject_id = 1645
# processing 7337/7499, subject_id = 1651
# Patient1651 has less then 6 hours recordings, discard from the final dataset
# processing 7338/7499, subject_id = 1652
# Patient1652 has less then 6 hours recordings, discard from the final dataset
# processing 7339/7499, subject_id = 1656
# processing 7340/7499, subject_id = 1658
# processing 7341/7499, subject_id = 1660
# processing 7342/7499, subject_id = 1662
# processing 7343/7499, subject_id = 1663
# Patient1663 has less then 6 hours recordings, discard from the final dataset
# processing 7344/7499, subject_id = 1672
# Patient1672 has less then 6 hours recordings, discard from the final dataset
# processing 7345/7499, subject_id = 1675
# processing 7346/7499, subject_id = 1676
# Patient1676 has less then 6 hours recordings, discard from the final dataset
# processing 7347/7499, subject_id = 1679
# Patient1679 has less then 6 hours recordings, discard from the final dataset
# processing 7348/7499, subject_id = 1683
# Patient1683 has less then 6 hours recordings, discard from the final dataset
# processing 7349/7499, subject_id = 1691
# processing 7350/7499, subject_id = 1692
# processing 7351/7499, subject_id = 1695
# Patient1695 has less then 6 hours recordings, discard from the final dataset
# processing 7352/7499, subject_id = 1701
# processing 7353/7499, subject_id = 1704
# processing 7354/7499, subject_id = 1707
# Patient1707 has less then 6 hours recordings, discard from the final dataset
# processing 7355/7499, subject_id = 1709
# Patient1709 has less then 6 hours recordings, discard from the final dataset
# processing 7356/7499, subject_id = 1713
# processing 7357/7499, subject_id = 1714
# processing 7358/7499, subject_id = 1715
# processing 7359/7499, subject_id = 1739
# processing 7360/7499, subject_id = 1744
# processing 7361/7499, subject_id = 1757
# processing 7362/7499, subject_id = 1758
# Patient1758 has less then 6 hours recordings, discard from the final dataset
# processing 7363/7499, subject_id = 1780
# processing 7364/7499, subject_id = 1786
# processing 7365/7499, subject_id = 1787
# Patient1787 has less then 6 hours recordings, discard from the final dataset
# processing 7366/7499, subject_id = 1795
# Patient1795 has less then 6 hours recordings, discard from the final dataset
# processing 7367/7499, subject_id = 1797
# Patient1797 has less then 6 hours recordings, discard from the final dataset
# processing 7368/7499, subject_id = 1803
# processing 7369/7499, subject_id = 1804
# processing 7370/7499, subject_id = 1807
# processing 7371/7499, subject_id = 1811
# Patient1811 has less then 6 hours recordings, discard from the final dataset
# processing 7372/7499, subject_id = 1813
# Patient1813 has less then 6 hours recordings, discard from the final dataset
# processing 7373/7499, subject_id = 1816
# processing 7374/7499, subject_id = 1817
# Patient1817 has less then 6 hours recordings, discard from the final dataset
# processing 7375/7499, subject_id = 1837
# processing 7376/7499, subject_id = 1840
# processing 7377/7499, subject_id = 1847
# processing 7378/7499, subject_id = 1849
# processing 7379/7499, subject_id = 1854
# processing 7380/7499, subject_id = 1859
# processing 7381/7499, subject_id = 1860
# Patient1860 has less then 6 hours recordings, discard from the final dataset
# processing 7382/7499, subject_id = 1862
# processing 7383/7499, subject_id = 1872
# processing 7384/7499, subject_id = 1873
# Patient1873 has less then 6 hours recordings, discard from the final dataset
# processing 7385/7499, subject_id = 1882
# processing 7386/7499, subject_id = 1888
# processing 7387/7499, subject_id = 1890
# Patient1890 has less then 6 hours recordings, discard from the final dataset
# processing 7388/7499, subject_id = 1891
# Patient1891 has less then 6 hours recordings, discard from the final dataset
# processing 7389/7499, subject_id = 1893
# Patient1893 has less then 6 hours recordings, discard from the final dataset
# processing 7390/7499, subject_id = 1895
# processing 7391/7499, subject_id = 1899
# Patient1899 has less then 6 hours recordings, discard from the final dataset
# processing 7392/7499, subject_id = 1901
# Patient1901 has less then 6 hours recordings, discard from the final dataset
# processing 7393/7499, subject_id = 1902
# Patient1902 has less then 6 hours recordings, discard from the final dataset
# processing 7394/7499, subject_id = 1905
# processing 7395/7499, subject_id = 1909
# Patient1909 has less then 6 hours recordings, discard from the final dataset
# processing 7396/7499, subject_id = 1912
# processing 7397/7499, subject_id = 1915
# processing 7398/7499, subject_id = 1918
# Patient1918 has less then 6 hours recordings, discard from the final dataset
# processing 7399/7499, subject_id = 1923
# Patient1923 has less then 6 hours recordings, discard from the final dataset
# processing 7400/7499, subject_id = 1931
# processing 7401/7499, subject_id = 1932
# processing 7402/7499, subject_id = 1935
# processing 7403/7499, subject_id = 1937
# processing 7404/7499, subject_id = 1938
# Patient1938 has less then 6 hours recordings, discard from the final dataset
# processing 7405/7499, subject_id = 1949
# processing 7406/7499, subject_id = 1964
# processing 7407/7499, subject_id = 1974
# Patient1974 has less then 6 hours recordings, discard from the final dataset
# processing 7408/7499, subject_id = 1989
# Patient1989 has less then 6 hours recordings, discard from the final dataset
# processing 7409/7499, subject_id = 1999
# Patient1999 has less then 6 hours recordings, discard from the final dataset
# processing 7410/7499, subject_id = 2004
# processing 7411/7499, subject_id = 2005
# processing 7412/7499, subject_id = 2012
# Patient2012 has less then 6 hours recordings, discard from the final dataset
# processing 7413/7499, subject_id = 2014
# Patient2014 has less then 6 hours recordings, discard from the final dataset
# processing 7414/7499, subject_id = 2015
# processing 7415/7499, subject_id = 2018
# processing 7416/7499, subject_id = 2021
# Patient2021 has less then 6 hours recordings, discard from the final dataset
# processing 7417/7499, subject_id = 2022
# processing 7418/7499, subject_id = 2029
# processing 7419/7499, subject_id = 2031
# Patient2031 has less then 6 hours recordings, discard from the final dataset
# processing 7420/7499, subject_id = 2034
# Patient2034 has less then 6 hours recordings, discard from the final dataset
# processing 7421/7499, subject_id = 2038
# Patient2038 has less then 6 hours recordings, discard from the final dataset
# processing 7422/7499, subject_id = 2048
# Patient2048 has less then 6 hours recordings, discard from the final dataset
# processing 7423/7499, subject_id = 2061
# Patient2061 has less then 6 hours recordings, discard from the final dataset
# processing 7424/7499, subject_id = 2063
# Patient2063 has less then 6 hours recordings, discard from the final dataset
# processing 7425/7499, subject_id = 2064
# Patient2064 has less then 6 hours recordings, discard from the final dataset
# processing 7426/7499, subject_id = 2067
# processing 7427/7499, subject_id = 2071
# Patient2071 has less then 6 hours recordings, discard from the final dataset
# processing 7428/7499, subject_id = 2074
# Patient2074 has less then 6 hours recordings, discard from the final dataset
# processing 7429/7499, subject_id = 2075
# processing 7430/7499, subject_id = 2076
# Patient2076 has less then 6 hours recordings, discard from the final dataset
# processing 7431/7499, subject_id = 2098
# processing 7432/7499, subject_id = 2100
# processing 7433/7499, subject_id = 2103
# Patient2103 has less then 6 hours recordings, discard from the final dataset
# processing 7434/7499, subject_id = 2104
# processing 7435/7499, subject_id = 2105
# processing 7436/7499, subject_id = 2113
# Patient2113 has less then 6 hours recordings, discard from the final dataset
# processing 7437/7499, subject_id = 2114
# Patient2114 has less then 6 hours recordings, discard from the final dataset
# processing 7438/7499, subject_id = 2115
# Patient2115 has less then 6 hours recordings, discard from the final dataset
# processing 7439/7499, subject_id = 2116
# processing 7440/7499, subject_id = 2127
# Patient2127 has less then 6 hours recordings, discard from the final dataset
# processing 7441/7499, subject_id = 2128
# Patient2128 has less then 6 hours recordings, discard from the final dataset
# processing 7442/7499, subject_id = 2143
# processing 7443/7499, subject_id = 2146
# processing 7444/7499, subject_id = 2148
# processing 7445/7499, subject_id = 2150
# processing 7446/7499, subject_id = 2151
# processing 7447/7499, subject_id = 2156
# processing 7448/7499, subject_id = 2158
# Patient2158 has less then 6 hours recordings, discard from the final dataset
# processing 7449/7499, subject_id = 2159
# Patient2159 has less then 6 hours recordings, discard from the final dataset
# processing 7450/7499, subject_id = 2164
# Patient2164 has less then 6 hours recordings, discard from the final dataset
# processing 7451/7499, subject_id = 2167
# Patient2167 has less then 6 hours recordings, discard from the final dataset
# processing 7452/7499, subject_id = 2169
# Patient2169 has less then 6 hours recordings, discard from the final dataset
# processing 7453/7499, subject_id = 2170
# processing 7454/7499, subject_id = 2172
# Patient2172 has less then 6 hours recordings, discard from the final dataset
# processing 7455/7499, subject_id = 2176
# Patient2176 has less then 6 hours recordings, discard from the final dataset
# processing 7456/7499, subject_id = 2178
# processing 7457/7499, subject_id = 2179
# Patient2179 has less then 6 hours recordings, discard from the final dataset
# processing 7458/7499, subject_id = 2180
# Patient2180 has less then 6 hours recordings, discard from the final dataset
# processing 7459/7499, subject_id = 2186
# Patient2186 has less then 6 hours recordings, discard from the final dataset
# processing 7460/7499, subject_id = 2188
# Patient2188 has less then 6 hours recordings, discard from the final dataset
# processing 7461/7499, subject_id = 2195
# Patient2195 has less then 6 hours recordings, discard from the final dataset
# processing 7462/7499, subject_id = 2196
# Patient2196 has less then 6 hours recordings, discard from the final dataset
# processing 7463/7499, subject_id = 2200
# Patient2200 has less then 6 hours recordings, discard from the final dataset
# processing 7464/7499, subject_id = 2201
# processing 7465/7499, subject_id = 2205
# processing 7466/7499, subject_id = 2211
# Patient2211 has less then 6 hours recordings, discard from the final dataset
# processing 7467/7499, subject_id = 2215
# Patient2215 has less then 6 hours recordings, discard from the final dataset
# processing 7468/7499, subject_id = 2219
# processing 7469/7499, subject_id = 2224
# processing 7470/7499, subject_id = 2228
# processing 7471/7499, subject_id = 2229
# Patient2229 has less then 6 hours recordings, discard from the final dataset
# processing 7472/7499, subject_id = 2237
# Patient2237 has less then 6 hours recordings, discard from the final dataset
# processing 7473/7499, subject_id = 2238
# processing 7474/7499, subject_id = 2258
# Patient2258 has less then 6 hours recordings, discard from the final dataset
# processing 7475/7499, subject_id = 2262
# processing 7476/7499, subject_id = 2270
# Patient2270 has less then 6 hours recordings, discard from the final dataset
# processing 7477/7499, subject_id = 2274
# processing 7478/7499, subject_id = 2286
# processing 7479/7499, subject_id = 2289
# Patient2289 has less then 6 hours recordings, discard from the final dataset
# processing 7480/7499, subject_id = 2298
# Patient2298 has less then 6 hours recordings, discard from the final dataset
# processing 7481/7499, subject_id = 2301
# Patient2301 has less then 6 hours recordings, discard from the final dataset
# processing 7482/7499, subject_id = 2306
# Patient2306 has less then 6 hours recordings, discard from the final dataset
# processing 7483/7499, subject_id = 2314
# processing 7484/7499, subject_id = 2317
# processing 7485/7499, subject_id = 2343
# processing 7486/7499, subject_id = 2344
# Patient2344 has less then 6 hours recordings, discard from the final dataset
# processing 7487/7499, subject_id = 2346
# processing 7488/7499, subject_id = 2349
# Patient2349 has less then 6 hours recordings, discard from the final dataset
# processing 7489/7499, subject_id = 2357
# Patient2357 has less then 6 hours recordings, discard from the final dataset
# processing 7490/7499, subject_id = 2363
# Patient2363 has less then 6 hours recordings, discard from the final dataset
# processing 7491/7499, subject_id = 2374
# processing 7492/7499, subject_id = 2378
# processing 7493/7499, subject_id = 2379
# processing 7494/7499, subject_id = 2381
# processing 7495/7499, subject_id = 2385
# Patient2385 has less then 6 hours recordings, discard from the final dataset
# processing 7496/7499, subject_id = 2386
# Patient2386 has less then 6 hours recordings, discard from the final dataset
# processing 7497/7499, subject_id = 2387
# Patient2387 has less then 6 hours recordings, discard from the final dataset
# processing 7498/7499, subject_id = 2388
# Patient2388 has less then 6 hours recordings, discard from the final dataset
# processing 7499/7499, subject_id = 2397
# Patient2397 has less then 6 hours recordings, discard from the final dataset

# %%
print(type_4)
print(type_5)
# Out:
# 4119
# 3380
